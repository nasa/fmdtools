# %% [markdown]
# # Degradation Modelling
#
# This rover shows how degradation modelling can be performed to model the resilience of an engineered system over its entire lifecycle.

# %%
import fmdtools.analyze as an
import fmdtools.sim.propagate as prop
import numpy as np
import matplotlib.pyplot as plt
import multiprocessing as mp

# %%
from examples.rover.rover_degradation import DriveDegradation, PSFDegradationLong, PSFDegradationShort

# %% [markdown]
# Degradation models are defined independently of the fault model, but have attributes (e.g., functions) which may correspond to it directly.
#
# Because degradation may only occur in specific functions/flows (and may not have inter-functional dependencies), it is not necessary for the degradation model to have the same

# %%
deg_mdl = DriveDegradation()
deg_mdl
# Out:
# drivedegradation DriveDegradation
# - DriveDegradationStates(wear=0.0, corrosion=0.0, friction=0.0, drift=0.0)

# %%
deg_mdl_hum_long = PSFDegradationLong()
deg_mdl_hum_long
# Out:
# psfdegradationlong PSFDegradationLong
# - PSFDegradationLongStates(experience=0.0)

# %%
deg_mdl_hum_short = PSFDegradationShort()
deg_mdl_hum_short
# Out:
# psfdegradationshort PSFDegradationShort
# - PSFDegradationShortStates(fatigue=0.0, stress=0.0, experience=1.0)

# %%
from examples.rover.rover_model import Rover, plot_map
fault_mdl = Rover(p={'ground':{'linetype': 'turn'}})
graph = fault_mdl.as_modelgraph()
fig, ax = graph.draw()

# %%
fig.savefig("func_model.pdf", format="pdf", bbox_inches = 'tight', pad_inches = 0)

# %%
endresults, mdlhist = prop.nominal(fault_mdl)
fig, ax = plot_map(fault_mdl, mdlhist)

# %%
fig.savefig("sine_rover_environment.pdf", format="pdf", bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# As shown, there are two degradation models here:
# - one which focusses solely on faults in the drive system, and
# - one which focusses on the human degradation of fatigue
# Below we simulate these to model to the degradation behaviors being modelled in this drive system.

# %% [markdown]
# ## Drive Degradation

# %%
deg_mdl = DriveDegradation()
endresults, mdlhist = prop.nominal(deg_mdl)
fig, ax = mdlhist.plot_line('s.wear', 's.corrosion', 's.friction', 's.drift', 'r.s.corrode_rate', 'r.s.wear_rate', 'r.s.yaw_load')

# %% [markdown]
# The major behaviors are:
# - wear
# - corrosion
# - friction
# - drift
#
# These behaviors result from the accumulation of the following rates over each time-step:
# - yaw_load
# - corrode_rate
# - wear_rate
#
# These degradation behaviors have additionally been defined to simulate stochastically if desired:

# %%
deg_mdl = DriveDegradation()
endresults, mdlhist = prop.nominal(deg_mdl, run_stochastic=True)
fig, ax = mdlhist.plot_line('s.wear', 's.corrosion', 's.friction', 's.drift', 'r.s.corrode_rate', 'r.s.wear_rate', 'r.s.yaw_load')

# %% [markdown]
# To get averages/percentages over a number of scenarios, we can view these behaviors over a given number of random seeds:

# %%
from fmdtools.sim.sample import ParameterSample
ps = ParameterSample()
ps.add_variable_replicates([], replicates=100, seed_comb='independent')
endclasses_deg, mdlhists_deg = prop.parameter_sample(deg_mdl, ps, run_stochastic=True)
# Out:
# SCENARIOS COMPLETE:   0%|          | 0/100 [00:00<?, ?it/s]
# SCENARIOS COMPLETE:   8%|▊         | 8/100 [00:00<00:01, 79.77it/s]
# SCENARIOS COMPLETE:  16%|█▌        | 16/100 [00:00<00:01, 79.15it/s]
# SCENARIOS COMPLETE:  24%|██▍       | 24/100 [00:00<00:00, 79.29it/s]
# SCENARIOS COMPLETE:  32%|███▏      | 32/100 [00:00<00:00, 78.75it/s]
# SCENARIOS COMPLETE:  40%|████      | 40/100 [00:00<00:00, 78.72it/s]
# SCENARIOS COMPLETE:  48%|████▊     | 48/100 [00:00<00:00, 78.73it/s]
# SCENARIOS COMPLETE:  56%|█████▌    | 56/100 [00:00<00:00, 78.71it/s]
# SCENARIOS COMPLETE:  64%|██████▍   | 64/100 [00:00<00:00, 78.96it/s]
# SCENARIOS COMPLETE:  72%|███████▏  | 72/100 [00:00<00:00, 79.12it/s]
# SCENARIOS COMPLETE:  80%|████████  | 80/100 [00:01<00:00, 78.69it/s]
# SCENARIOS COMPLETE:  88%|████████▊ | 88/100 [00:01<00:00, 78.68it/s]
# SCENARIOS COMPLETE:  96%|█████████▌| 96/100 [00:01<00:00, 78.53it/s]
# SCENARIOS COMPLETE: 100%|██████████| 100/100 [00:01<00:00, 78.85it/s]

# %%
fig, ax = mdlhists_deg.plot_line('s.wear', 's.corrosion', 's.friction', 's.drift',
                                 'r.s.corrode_rate', 'r.s.wear_rate', 'r.s.yaw_load',
                                 title="", xlabel='lifecycle time (months)', aggregation = 'mean_bound')

# %%
fig.savefig("drive_degradations.pdf", format="pdf", bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# As shown, while wear and friction proceed monotonically, drift can go one way or another, meaning that whether the rover drifts left or right is basically up to chance. We can further look at slices of these distributions:

# %%
fig, axs = mdlhists_deg.plot_metric_dist([1, 10, 20, 25], 's.wear', 's.corrosion', 's.friction', 's.drift', bins=10, alpha=0.5)

# %%
from IPython.display import HTML
ani = mdlhists_deg.animate('plot_metric_dist_from',
                           plot_values=( 's.wear', 's.corrosion', 's.friction', 's.drift'),
                                        bins=10, alpha=0.5)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img7019036790cb4d84bcd9a1418721ae9d">
#   <div class="anim-controls">
#     <input id="_anim_slider7019036790cb4d84bcd9a1418721ae9d" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim7019036790cb4d84bcd9a1418721ae9d.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim7019036790cb4d84bcd9a1418721ae9d.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim7019036790cb4d84bcd9a1418721ae9d.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim7019036790cb4d84bcd9a1418721ae9d.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim7019036790cb4d84bcd9a1418721ae9d.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim7019036790cb4d84bcd9a1418721ae9d.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim7019036790cb4d84bcd9a1418721ae9d.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim7019036790cb4d84bcd9a1418721ae9d.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim7019036790cb4d84bcd9a1418721ae9d.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim7019036790cb4d84bcd9a1418721ae9d.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select7019036790cb4d84bcd9a1418721ae9d"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_7019036790cb4d84bcd9a1418721ae9d"
#              >
#       <label for="_anim_radio1_7019036790cb4d84bcd9a1418721ae9d">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_7019036790cb4d84bcd9a1418721ae9d"
#              checked>
#       <label for="_anim_radio2_7019036790cb4d84bcd9a1418721ae9d">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_7019036790cb4d84bcd9a1418721ae9d"
#              >
#       <label for="_anim_radio3_7019036790cb4d84bcd9a1418721ae9d">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img7019036790cb4d84bcd9a1418721ae9d";
#     var slider_id = "_anim_slider7019036790cb4d84bcd9a1418721ae9d";
#     var loop_select_id = "_anim_loop_select7019036790cb4d84bcd9a1418721ae9d";
#     var frames = new Array(101);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjkuMCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy80BEi2AAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAA+oklE

# %% [markdown]
# Given the parameter information (friction and drift) that the degradation model produced, we can now simulate the model with this information over time in the nominal scenarios.

# %%
from fmdtools.sim.sample import ParameterDomain, ParameterHistSample
from examples.rover.rover_model import RoverParam

# %% [markdown]
# We can do this using a `ParameterHistSample` to sample the histories of the various scenarios at different times.
#
# First, by defining a `ParameterDomain`:

# %%
rpd = ParameterDomain(RoverParam)
rpd.add_variables('degradation.friction', 'degradation.drift')
rpd.add_constant('drive_modes', {"mode_args": "degradation"})
rpd(1, 10).degradation
# Out:
# DegParam(friction=1.0, drift=10.0)

# %% [markdown]
# And then by defining the class:

# %%
phs = ParameterHistSample(mdlhists_deg, 's.friction', 's.drift', paramdomain=rpd)
phs._get_repname('default', 1)
phs.add_hist_groups(reps= 10, ts = [1, 2, 5, 10])
len(phs.scenarios())
# Out:
# 40

# %% [markdown]
# Simulating the nominal scenario for these parameters:

# %%
mdl=Rover(p={'drive_modes': {'mode_args': "degradation"}})
behave_endclasses, behave_mdlhists = prop.parameter_sample(fault_mdl, phs)
# Out:
# SCENARIOS COMPLETE:   0%|          | 0/40 [00:00<?, ?it/s]
# SCENARIOS COMPLETE:   2%|▎         | 1/40 [00:00<00:07,  5.13it/s]
# SCENARIOS COMPLETE:   5%|▌         | 2/40 [00:00<00:07,  5.11it/s]
# SCENARIOS COMPLETE:   8%|▊         | 3/40 [00:00<00:07,  5.10it/s]
# SCENARIOS COMPLETE:  10%|█         | 4/40 [00:00<00:07,  5.06it/s]
# SCENARIOS COMPLETE:  12%|█▎        | 5/40 [00:01<00:07,  4.63it/s]
# SCENARIOS COMPLETE:  15%|█▌        | 6/40 [00:01<00:07,  4.31it/s]
# SCENARIOS COMPLETE:  18%|█▊        | 7/40 [00:01<00:07,  4.51it/s]
# SCENARIOS COMPLETE:  20%|██        | 8/40 [00:01<00:06,  4.80it/s]
# SCENARIOS COMPLETE:  22%|██▎       | 9/40 [00:01<00:06,  4.52it/s]
# SCENARIOS COMPLETE:  25%|██▌       | 10/40 [00:02<00:06,  4.76it/s]
# SCENARIOS COMPLETE:  28%|██▊       | 11/40 [00:02<00:05,  4.94it/s]
# SCENARIOS COMPLETE:  30%|███       | 12/40 [00:02<00:05,  5.12it/s]
# SCENARIOS COMPLETE:  32%|███▎      | 13/40 [00:02<00:05,  5.21it/s]
# SCENARIOS COMPLETE:  35%|███▌      | 14/40 [00:02<00:04,  5.28it/s]
# SCENARIOS COMPLETE:  38%|███▊      | 15/40 [00:03<00:04,  5.34it/s]
# SCENARIOS COMPLETE:  40%|████      | 16/40 [00:03<00:04,  5.40it/s]
# SCENARIOS COMPLETE:  42%|████▎     | 17/40 [00:03<00:04,  5.03it/s]
# SCENARIOS COMPLETE:  45%|████▌     | 18/40 [00:03<00:04,  4.64it/s]
# SCENARIOS COMPLETE:  48%|████▊     | 19/40 [00:03<00:04,  4.51it/s]
# SCENARIOS COMPLETE:  50%|█████     | 20/40 [00:04<00:04,  4.71it/s]
# SCENARIOS COMPLETE:  52%|█████▎    | 21/40 [00:04<00:04,  4.49it/s]
# SCENARIOS COMPLETE:  55%|█████▌    | 22/40 [00:04<00:03,  4.69it/s]
# SCENARIOS COMPLETE:  57%|█████▊    | 23/40 [00:04<00:03,  4.87it/s]
# SCENARIOS COMPLETE:  60%|██████    | 24/40 [00:04<00:03,  4.98it/s]
# SCENARIOS COMPLETE:  62%|██████▎   | 25/40 [00:05<00:03,  4.69it/s]
# SCENARIOS COMPLETE:  65%|██████▌   | 26/40 [00:05<00:03,  4.48it/s]
# SCENARIOS COMPLETE:  68%|██████▊   | 27/40 [00:05<00:02,  4.66it/s]
# SCENARIOS COMPLETE:  70%|███████   | 28/40 [00:05<00:02,  4.86it/s]
# SCENARIOS COMPLETE:  72%|███████▎  | 29/40 [00:06<00:02,  4.52it/s]
# SCENARIOS COMPLETE:  75%|███████▌  | 30/40 [00:06<00:02,  4.41it/s]
# SCENARIOS COMPLETE:  78%|███████▊  | 31/40 [00:06<00:01,  4.66it/s]
# SCENARIOS COMPLETE:  80%|████████  | 32/40 [00:06<00:01,  4.84it/s]
# SCENARIOS COMPLETE:  82%|████████▎ | 33/40 [00:06<00:01,  4.61it/s]
# SCENARIOS COMPLETE:  85%|████████▌ | 34/40 [00:07<00:01,  4.39it/s]
# SCENARIOS COMPLETE:  88%|████████▊ | 35/40 [00:07<00:01,  4.65it/s]
# SCENARIOS COMPLETE:  90%|█████████ | 36/40 [00:07<00:00,  4.89it/s]
# SCENARIOS COMPLETE:  92%|█████████▎| 37/40 [00:07<00:00,  4.66it/s]
# SCENARIOS COMPLETE:  95%|█████████▌| 38/40 [00:08<00:00,  4.47it/s]
# SCENARIOS COMPLETE:  98%|█████████▊| 39/40 [00:08<00:00,  4.31it/s]
# SCENARIOS COMPLETE: 100%|██████████| 40/40 [00:08<00:00,  4.48it/s]
# SCENARIOS COMPLETE: 100%|██████████| 40/40 [00:08<00:00,  4.72it/s]

# %%
fig, ax = plot_map(fault_mdl, behave_mdlhists)

# %%
behave_endclasses.state_probabilities('prob')
# Out:
# {'incomplete mission': 24.0, 'nominal mission': 16.0}

# %%
from fmdtools.analyze.tabulate import NominalEnvelope

# %%
ne = NominalEnvelope(phs, behave_endclasses, 'classification',
                     'p.degradation.friction', 'p.degradation.drift',
                     func = lambda x: x == 'nominal mission')
ne.plot_scatter()
# Out:
# (<Figure size 600x400 with 1 Axes>,
#  <Axes: xlabel='p.degradation.friction', ylabel='p.degradation.drift'>)

# %%
ne = NominalEnvelope(phs, behave_endclasses, 'classification',
                     'inputparams.t', 'inputparams.rep',
                     func = lambda x: x == 'nominal mission')
ne.plot_scatter()
# Out:
# (<Figure size 600x400 with 1 Axes>,
#  <Axes: xlabel='inputparams.t', ylabel='inputparams.rep'>)

# %%
fig.savefig("drive_deg_envelope.pdf", format="pdf", bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# As shown, as the time (and thus degradation) increases, the rover becomes more likely to be unable to complete the mission. In this case, it results in the rover not completing the mission in time.

# %%
from fmdtools.sim.sample import SampleApproach
sa = SampleApproach(mdl)
sa.add_faultdomain('drive_faults', 'all_fxnclass_modes', 'Drive')
sa.add_faultsample('drive_faults', 'fault_phases', 'drive_faults',"start")
# sa.scenarios()

# %%
sa.scenarios()
# Out:
# [SingleFaultScenario(sequence={15.0: Injection(faults={'drive': ['elec_open']}, disturbances={})}, times=(15.0,), function='drive', fault='elec_open', rate=0.25, name='drive_elec_open_t15p0', time=15.0, phase='start'),
#  SingleFaultScenario(sequence={15.0: Injection(faults={'drive': ['stuck']}, disturbances={})}, times=(15.0,), function='drive', fault='stuck', rate=0.25, name='drive_stuck_t15p0', time=15.0, phase='start'),
#  SingleFaultScenario(sequence={15.0: Injection(faults={'drive': ['stuck_right']}, disturbances={})}, times=(15.0,), function='drive', fault='stuck_right', rate=0.25, name='drive_stuck_right_t15p0', time=15.0, phase='start'),
#  SingleFaultScenario(sequence={15.0: Injection(faults={'drive': ['stuck_left']}, disturbances={})}, times=(15.0,), function='drive', fault='stuck_left', rate=0.25, name='drive_stuck_left_t15p0', time=15.0, phase='start')]

# %%
ec_nest, hist_nest, app_nest = prop.nested_sample(mdl, phs, faultdomains={'drive_faults':  (('all_fxnclass_modes', 'Drive'), {})},
                                                  faultsamples={'drive_faults': (('fault_phases', 'drive_faults', "start"), {})},
                                                  pool=mp.Pool(5))
# Out:
# NESTED SCENARIOS COMPLETE:   0%|          | 0/40 [00:00<?, ?it/s]
# NESTED SCENARIOS COMPLETE:   2%|▎         | 1/40 [00:00<00:15,  2.49it/s]
# NESTED SCENARIOS COMPLETE:   5%|▌         | 2/40 [00:00<00:14,  2.61it/s]
# NESTED SCENARIOS COMPLETE:   8%|▊         | 3/40 [00:01<00:13,  2.67it/s]
# NESTED SCENARIOS COMPLETE:  10%|█         | 4/40 [00:01<00:13,  2.64it/s]
# NESTED SCENARIOS COMPLETE:  12%|█▎        | 5/40 [00:02<00:19,  1.79it/s]
# NESTED SCENARIOS COMPLETE:  15%|█▌        | 6/40 [00:03<00:22,  1.51it/s]
# NESTED SCENARIOS COMPLETE:  18%|█▊        | 7/40 [00:03<00:18,  1.79it/s]
# NESTED SCENARIOS COMPLETE:  20%|██        | 8/40 [00:03<00:15,  2.02it/s]
# NESTED SCENARIOS COMPLETE:  22%|██▎       | 9/40 [00:04<00:18,  1.65it/s]
# NESTED SCENARIOS COMPLETE:  25%|██▌       | 10/40 [00:05<00:15,  1.89it/s]
# NESTED SCENARIOS COMPLETE:  28%|██▊       | 11/40 [00:05<00:13,  2.11it/s]
# NESTED SCENARIOS COMPLETE:  30%|███       | 12/40 [00:05<00:12,  2.26it/s]
# NESTED SCENARIOS COMPLETE:  32%|███▎      | 13/40 [00:06<00:11,  2.38it/s]
# NESTED SCENARIOS COMPLETE:  35%|███▌      | 14/40 [00:06<00:10,  2.49it/s]
# NESTED SCENARIOS COMPLETE:  38%|███▊      | 15/40 [00:06<00:09,  2.58it/s]
# NESTED SCENARIOS COMPLETE:  40%|████      | 16/40 [00:07<00:09,  2.49it/s]
# NESTED SCENARIOS COMPLETE:  42%|████▎     | 17/40 [00:08<00:12,  1.84it/s]
# NESTED SCENARIOS COMPLETE:  45%|████▌     | 18/40 [00:09<00:14,  1.56it/s]
# NESTED SCENARIOS COMPLETE:  48%|████▊     | 19/40 [00:09<00:11,  1.77it/s]
# NESTED SCENARIOS COMPLETE:  50%|█████     | 20/40 [00:09<00:10,  1.97it/s]
# NESTED SCENARIOS COMPLETE:  52%|█████▎    | 21/40 [00:10<00:09,  2.11it/s]
# NESTED SCENARIOS COMPLETE:  55%|█████▌    | 22/40 [00:10<00:08,  2.25it/s]
# NESTED SCENARIOS COMPLETE:  57%|█████▊    | 23/40 [00:11<00:07,  2.37it/s]
# NESTED SCENARIOS COMPLETE:  60%|██████    | 24/40 [00:11<00:06,  2.45it/s]
# NESTED SCENARIOS COMPLETE:  62%|██████▎   | 25/40 [00:12<00:08,  1.86it/s]
# NESTED SCENARIOS COMPLETE:  65%|██████▌   | 26/40 [00:13<00:09,  1.55it/s]
# NESTED SCENARIOS COMPLETE:  68%|██████▊   | 27/40 [00:13<00:07,  1.80it/s]
# NESTED SCENARIOS COMPLETE:  70%|███████   | 28/40 [00:13<00:05,  2.01it/s]
# NESTED SCENARIOS COMPLETE:  72%|███████▎  | 29/40 [00:14<00:06,  1.65it/s]
# NESTED SCENARIOS COMPLETE:  75%|███████▌  | 30/40 [00:15<00:06,  1.51it/s]
# NESTED SCENARIOS COMPLETE:  78%|███████▊  | 31/40 [00:15<00:05,  1.76it/s]
# NESTED SCENARIOS COMPLETE:  80%|████████  | 32/40 [00:16<00:04,  1.99it/s]
# NESTED SCENARIOS COMPLETE:  82%|████████▎ | 33/40 [00:17<00:04,  1.68it/s]
# NESTED SCENARIOS COMPLETE:  85%|████████▌ | 34/40 [00:17<00:03,  1.50it/s]
# NESTED SCENARIOS COMPLETE:  88%|████████▊ | 35/40 [00:18<00:02,  1.75it/s]
# NESTED SCENARIOS COMPLETE:  90%|█████████ | 36/40 [00:18<00:02,  1.97it/s]
# NESTED SCENARIOS COMPLETE:  92%|█████████▎| 37/40 [00:19<00:01,  1.66it/s]
# NESTED SCENARIOS COMPLETE:  95%|█████████▌| 38/40 [00:19<00:01,  1.84it/s]
# NESTED SCENARIOS COMPLETE:  98%|█████████▊| 39/40 [00:20<00:00,  2.01it/s]
# NESTED SCENARIOS COMPLETE: 100%|██████████| 40/40 [00:20<00:00,  2.17it/s]
# NESTED SCENARIOS COMPLETE: 100%|██████████| 40/40 [00:20<00:00,  1.94it/s]

# %% [markdown]
# Finally, we can also visualize simulate and then view the effect of the degradation on average resilience...

# %%
from fmdtools.analyze.tabulate import NestedComparison
nc = NestedComparison(ec_nest, phs, ['inputparams.t'], app_nest, ['fault'], metrics=['tot_deviation', 'end_dist'], default_stat=np.mean, ci_metrics=['end_dist', 'tot_deviation'])

# %%
nc
# Out:
# {'tot_deviation': {(1, 'stuck'): 0.15679609013529022, (1, 'stuck_left'): 0.23854733096972583, (1, 'elec_open'): 0.15679609013529022, (1, 'stuck_right'): 0.21446172009278594, (2, 'stuck'): 0.18244455694081024, (2, 'stuck_left'): 0.23491833064587472, (2, 'elec_open'): 0.18244455694081024, (2, 'stuck_right'): 0.21258730106947787, (10, 'stuck'): 0.23184411136651922, (10, 'stuck_left'): 0.23184411136651922, (10, 'elec_open'): 0.23184411136651922, (10, 'stuck_right'): 0.23184411136651922, (5, 'stuck'): 0.2197336074774988, (5, 'stuck_left'): 0.2197336074774988, (5, 'elec_open'): 0.2197336074774988, (5, 'stuck_right'): 0.2197336074774988}, 'end_dist': {(1, 'stuck'): 26.410927440582952, (1, 'stuck_left'): 25.45137031117967, (1, 'elec_open'): 26.4794353090846, (1, 'stuck_right'): 25.977203908389487, (2, 'stuck'): 26.804392985595836, (2, 'stuck_left'): 26.171784282218027, (2, 'elec_open'): 26.854350891655702, (2, 'stuck_right'): 26.18823533095121, (10, 'stuck'): 28.305424255417336, (10, 'stuck_left'): 28.305424255417336, (10, 'elec_open'): 28.305424255417336, (10, 'stuck_right'): 28.305424255417336, (5, 'stuck'): 28.10972025175539, (5, 'stuck_left'): 28.10972025175539, (5, 'elec_open'): 28.10972025175539, (5, 'stuck_right'): 28.10972025175539}, 'end_dist_lb': {(1, 'stuck'): 26.016686717526703, (1, 'stuck_left'): 24.771622539463237, (1, 'elec_open'): 26.099033421450756, (1, 'stuck_right'): 25.42126796183423, (2, 'stuck'): 26.218256555803162, (2, 'stuck_left'): 25.2159126700062, (2, 'elec_open'): 26.3014131193795, (2, 'stuck_right'): 24.784478958229183, (10, 'stuck'): 28.007534406573964, (10, 'stuck_left'): 28.014607633486403, (10, 'elec_open'): 28.018040442858414, (10, 'stuck_right'): 28.020116604248102, (5, 'stuck'): 27.658127997887085, (5, 'stuck_left'): 27.676148052286543, (5, 'elec_open'): 27.652198840022344, (5, 'stuck_right'): 27.66817780873895}, 'tot_deviation_lb': {(1, 'stuck'): 0.12872277803403423, (1, 'stuck_left'): 0.22972030593986104, (1, 'elec_open'): 0.12796280314779873, (1, 'stuck_right'): 0.20835107114598214, (2, 'stuck'): 0.15105651933877254, (2, 'stuck_left'): 0.22387288971006183, (2, 'elec_open'): 0.15119541644462856, (2, 'stuck_right'): 0.20551171831124085, (10, 'stuck'): 0.22305973852393107, (10, 'stuck_left'): 0.2233520024133099, (10, 'elec_open'): 0.22308571400081825, (10, 'stuck_right'): 0.22344297878857988, (5, 'stuck'): 0.21444859136450575, (5, 'stuck_left'): 0.2145097200885683, (5, 'elec_open'): 0.21431606333813616, (5, 'stuck_right'): 0.21424628971872153}, 'end_dist_ub': {(1, 'stuck'): 27.17067732794773, (1, 'stuck_left'): 26.61581043761661, (1, 'elec_open'): 27.23141093394956, (1, 'stuck_right'): 26.898655052674165, (2, 'stuck'): 27.54812544597544, (2, 'stuck_left'): 27.244963669034227, (2, 'elec_open'): 27.575139589062257, (2, 'stuck_right'): 27.170088881377644, (10, 'stuck'): 28.474999400647203, (10, 'stuck_left'): 28.473300637588626, (10, 'elec_open'): 28.466943461948272, (10, 'stuck_right'): 28.474965664193718, (5, 'stuck'): 28.395329026454434, (5, 'stuck_left'): 28.395681102095196, (5, 'elec_open'): 28.39589985283848, (5, 'stuck_right'): 28.41815975027639}, 'tot_deviation_ub': {(1, 'stuck'): 0.19048122924649788, (1, 'stuck_left'): 0.24838021109428005, (1, 'elec_open'): 0.19053743898473896, (1, 'stuck_right'): 0.22152111889673548, (2, 'stuck'): 0.2074904890931507, (2, 'stuck_left'): 0.2445884366522371, (2, 'elec_open'): 0.2079310063545549, (2, 'stuck_right'): 0.22160269570828564, (10, 'stuck'): 0.23926125631700845, (10, 'stuck_left'): 0.23955338118787353, (10, 'elec_open'): 0.2394681871037918, (10, 'stuck_right'): 0.23966187434132072, (5, 'stuck'): 0.22705978782965489, (5, 'stuck_left'): 0.2270723976181608, (5, 'elec_open'): 0.22700108526962393, (5, 'stuck_right'): 0.2269130218945392}}

# %%
nc.sort_by_factor("fault")
nc.sort_by_factor("inputparams.t")
fig, ax = nc.as_plots('end_dist', 'tot_deviation', figsize=(8,4))

# %%
nc
# Out:
# {'tot_deviation': {(1, 'elec_open'): 0.15679609013529022, (1, 'stuck'): 0.15679609013529022, (1, 'stuck_left'): 0.23854733096972583, (1, 'stuck_right'): 0.21446172009278594, (2, 'elec_open'): 0.18244455694081024, (2, 'stuck'): 0.18244455694081024, (2, 'stuck_left'): 0.23491833064587472, (2, 'stuck_right'): 0.21258730106947787, (5, 'elec_open'): 0.2197336074774988, (5, 'stuck'): 0.2197336074774988, (5, 'stuck_left'): 0.2197336074774988, (5, 'stuck_right'): 0.2197336074774988, (10, 'elec_open'): 0.23184411136651922, (10, 'stuck'): 0.23184411136651922, (10, 'stuck_left'): 0.23184411136651922, (10, 'stuck_right'): 0.23184411136651922}, 'end_dist': {(1, 'elec_open'): 26.4794353090846, (1, 'stuck'): 26.410927440582952, (1, 'stuck_left'): 25.45137031117967, (1, 'stuck_right'): 25.977203908389487, (2, 'elec_open'): 26.854350891655702, (2, 'stuck'): 26.804392985595836, (2, 'stuck_left'): 26.171784282218027, (2, 'stuck_right'): 26.18823533095121, (5, 'elec_open'): 28.10972025175539, (5, 'stuck'): 28.10972025175539, (5, 'stuck_left'): 28.10972025175539, (5, 'stuck_right'): 28.10972025175539, (10, 'elec_open'): 28.305424255417336, (10, 'stuck'): 28.305424255417336, (10, 'stuck_left'): 28.305424255417336, (10, 'stuck_right'): 28.305424255417336}, 'end_dist_lb': {(1, 'elec_open'): 26.099033421450756, (1, 'stuck'): 26.016686717526703, (1, 'stuck_left'): 24.771622539463237, (1, 'stuck_right'): 25.42126796183423, (2, 'elec_open'): 26.3014131193795, (2, 'stuck'): 26.218256555803162, (2, 'stuck_left'): 25.2159126700062, (2, 'stuck_right'): 24.784478958229183, (5, 'elec_open'): 27.652198840022344, (5, 'stuck'): 27.658127997887085, (5, 'stuck_left'): 27.676148052286543, (5, 'stuck_right'): 27.66817780873895, (10, 'elec_open'): 28.018040442858414, (10, 'stuck'): 28.007534406573964, (10, 'stuck_left'): 28.014607633486403, (10, 'stuck_right'): 28.020116604248102}, 'tot_deviation_lb': {(1, 'elec_open'): 0.12796280314779873, (1, 'stuck'): 0.12872277803403423, (1, 'stuck_left'): 0.22972030593986104, (1, 'stuck_right'): 0.20835107114598214, (2, 'elec_open'): 0.15119541644462856, (2, 'stuck'): 0.15105651933877254, (2, 'stuck_left'): 0.22387288971006183, (2, 'stuck_right'): 0.20551171831124085, (5, 'elec_open'): 0.21431606333813616, (5, 'stuck'): 0.21444859136450575, (5, 'stuck_left'): 0.2145097200885683, (5, 'stuck_right'): 0.21424628971872153, (10, 'elec_open'): 0.22308571400081825, (10, 'stuck'): 0.22305973852393107, (10, 'stuck_left'): 0.2233520024133099, (10, 'stuck_right'): 0.22344297878857988}, 'end_dist_ub': {(1, 'elec_open'): 27.23141093394956, (1, 'stuck'): 27.17067732794773, (1, 'stuck_left'): 26.61581043761661, (1, 'stuck_right'): 26.898655052674165, (2, 'elec_open'): 27.575139589062257, (2, 'stuck'): 27.54812544597544, (2, 'stuck_left'): 27.244963669034227, (2, 'stuck_right'): 27.170088881377644, (5, 'elec_open'): 28.39589985283848, (5, 'stuck'): 28.395329026454434, (5, 'stuck_left'): 28.395681102095196, (5, 'stuck_right'): 28.41815975027639, (10, 'elec_open'): 28.466943461948272, (10, 'stuck'): 28.474999400647203, (10, 'stuck_left'): 28.473300637588626, (10, 'stuck_right'): 28.474965664193718}, 'tot_deviation_ub': {(1, 'elec_open'): 0.19053743898473896, (1, 'stuck'): 0.19048122924649788, (1, 'stuck_left'): 0.24838021109428005, (1, 'stuck_right'): 0.22152111889673548, (2, 'elec_open'): 0.2079310063545549, (2, 'stuck'): 0.2074904890931507, (2, 'stuck_left'): 0.2445884366522371, (2, 'stuck_right'): 0.22160269570828564, (5, 'elec_open'): 0.22700108526962393, (5, 'stuck'): 0.22705978782965489, (5, 'stuck_left'): 0.2270723976181608, (5, 'stuck_right'): 0.2269130218945392, (10, 'elec_open'): 0.2394681871037918, (10, 'stuck'): 0.23926125631700845, (10, 'stuck_left'): 0.23955338118787353, (10, 'stuck_right'): 0.23966187434132072}}

# %%
# fig.savefig("drive_resilience_degradation.pdf", format="pdf", bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# As shown, while there is some resilience early in the lifecycle (resulting in a small proportion of faults being recovered), this resilience goes away with degradation.

# %% [markdown]
# ## Human Degradation

# %% [markdown]
# We can also perform this assessment for the human error model, which is split up into two parts:
# - long term "degradation" of experience over months
# - short term "degradation" of stress and fatigue over a day

# %%
psf_long = PSFDegradationLong()
endresults,  hist_psf_long = prop.nominal(psf_long)

# %%
hist_psf_long.plot_line('s.experience')
# Out:
# (<Figure size 300x200 with 1 Axes>,
#  [<Axes: title={'center': 's.experience'}, xlabel='time'>])

# %%
hist_psf_long.plot_line('s.experience')
# Out:
# (<Figure size 300x200 with 1 Axes>,
#  [<Axes: title={'center': 's.experience'}, xlabel='time'>])

# %%
from examples.rover.rover_degradation import LongParams
pd_hl = ParameterDomain(LongParams)
pd_hl.add_variable("experience_param", var_lim=())
pd_hl
# Out:
# ParameterDomain with:
#  - variables: {'experience_param': ()}
#  - constants: {}
#  - parameter_initializer: LongParams

# %%
pd_hl(10)
# Out:
# LongParams(experience_param=10.0, training_frequency=8.0, experience_scale_max=10.0)

# %%
ps_hl = ParameterSample(pd_hl)
xs = np.random.default_rng(seed=101).gamma(1,1.9,101)
# round so that dist is 0-10
xs = [min(x, 9.9) for x in xs]
weight = 1/len(xs)
for x in xs:
    ps_hl.add_variable_scenario(x, weight=weight)
ps_hl
# Out:
# ParameterSample of scenarios:
#  - var_0
#  - var_1
#  - var_2
#  - var_3
#  - var_4
#  - var_5
#  - var_6
#  - var_7
#  - var_8
#  - var_9
#  - ... (101 total)

# %%
ec_psf_long, hist_psf_long= prop.parameter_sample(psf_long, ps_hl, run_stochastic=True)
# Out:
# SCENARIOS COMPLETE:   0%|          | 0/101 [00:00<?, ?it/s]
# SCENARIOS COMPLETE:  16%|█▌        | 16/101 [00:00<00:00, 151.79it/s]
# SCENARIOS COMPLETE:  32%|███▏      | 32/101 [00:00<00:00, 149.52it/s]
# SCENARIOS COMPLETE:  47%|████▋     | 47/101 [00:00<00:00, 148.97it/s]
# SCENARIOS COMPLETE:  61%|██████▏   | 62/101 [00:00<00:00, 148.96it/s]
# SCENARIOS COMPLETE:  76%|███████▌  | 77/101 [00:00<00:00, 148.99it/s]
# SCENARIOS COMPLETE:  91%|█████████ | 92/101 [00:00<00:00, 148.84it/s]
# SCENARIOS COMPLETE: 100%|██████████| 101/101 [00:00<00:00, 149.24it/s]

# %%
hist_psf_long.plot_line('s.experience')
# Out:
# (<Figure size 300x200 with 1 Axes>,
#  [<Axes: title={'center': 's.experience'}, xlabel='time'>])

# %%
fig, axs = hist_psf_long.plot_metric_dist([0, 40, 50, 60, 100], 's.experience', bins=20, alpha=0.5, figsize=(8,4))

# %%
# fig.savefig("experience_degradation.pdf", format="pdf", bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# Short-term degradation

# %%
psf_short = PSFDegradationShort()
er, hist_short = prop.nominal(psf_short)
fig, axs = hist_short.plot_line('s.fatigue', 's.stress')

# %% [markdown]
# short-term degradation (over no external params)

# %%
ps_psf_short = ParameterSample()
ps_psf_short.add_variable_replicates([], replicates=25)
ps_psf_short.scenarios()
# Out:
# [ParameterScenario(sequence={}, times=(), p={}, r={'seed': 570055244}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep0_var_0'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 1505829234}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep1_var_1'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 2563672988}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep2_var_2'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 1313586849}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep3_var_3'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 3539771706}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep4_var_4'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 2381708166}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep5_var_5'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 1066672566}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep6_var_6'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 457472510}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep7_var_7'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 890292678}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep8_var_8'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 2072978172}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep9_var_9'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 445386878}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep10_var_10'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 1605202791}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep11_var_11'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 202054381}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep12_var_12'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 3353689302}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep13_var_13'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 1293132241}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep14_var_14'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 2168503770}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep15_var_15'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 4108403991}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep16_var_16'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 1807311242}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep17_var_17'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 2992710387}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep18_var_18'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 2176527633}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep19_var_19'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 2007206821}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep20_var_20'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 1835129490}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep21_var_21'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 229686226}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep22_var_22'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 2795710681}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep23_var_23'),
#  ParameterScenario(sequence={}, times=(), p={}, r={'seed': 3094823265}, sp={}, prob=0.04, inputparams={}, rangeid='', name='rep24_var_24')]

# %%
ec_psf_short, hist_psf_short = prop.parameter_sample(psf_short, ps_psf_short, run_stochastic=True)
fig, axs = hist_psf_short.plot_line('s.fatigue', 's.stress', 'r.s.fatigue_param', aggregation="percentile")
# Out:
# SCENARIOS COMPLETE:   0%|          | 0/25 [00:00<?, ?it/s]
# SCENARIOS COMPLETE: 100%|██████████| 25/25 [00:00<00:00, 446.52it/s]

# %% [markdown]
# short-term degradation over long-term params

# %%
from examples.rover.rover_degradation import PSFShortParams
pd_short_long = ParameterDomain(PSFShortParams)
pd_short_long.add_variable("experience")
ps_short_long = ParameterHistSample(hist_psf_long, 's.experience', paramdomain=pd_short_long)
ps_short_long.add_hist_groups(reps= 10, ts = [0, 40, 50, 60, 100])

# note - need to add a way to combine replicates (seeds) over replicates (input times/groups/)

# %%
pd_short_long(10)
# Out:
# PSFShortParams(experience=10.0, stress_param=0.0, fatigue_param=1.0)

# %%
ps_short_long.scenarios()
# Out:
# [ParameterScenario(sequence={}, times=(), p={'experience': 0.0147852093576427}, r={'seed': 3399619316}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_0', 't': 0}, rangeid='', name='hist_0'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 4.355521540650882}, r={'seed': 3399619316}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_0', 't': 40}, rangeid='', name='hist_1'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 7.926159730949486}, r={'seed': 3399619316}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_0', 't': 50}, rangeid='', name='hist_2'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 9.498252713597697}, r={'seed': 3399619316}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_0', 't': 60}, rangeid='', name='hist_3'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 9.999122355752638}, r={'seed': 3399619316}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_0', 't': 100}, rangeid='', name='hist_4'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 0.003707397123126116}, r={'seed': 1003994148}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_1', 't': 0}, rangeid='', name='hist_5'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 1.6197044104299785}, r={'seed': 1003994148}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_1', 't': 40}, rangeid='', name='hist_6'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 4.890918517769909}, r={'seed': 1003994148}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_1', 't': 50}, rangeid='', name='hist_7'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 8.258304854924205}, r={'seed': 1003994148}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_1', 't': 60}, rangeid='', name='hist_8'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 9.996496965739947}, r={'seed': 1003994148}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_1', 't': 100}, rangeid='', name='hist_9'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 0.0040328347821078905}, r={'seed': 1612834589}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_2', 't': 0}, rangeid='', name='hist_10'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 1.7372307652324728}, r={'seed': 1612834589}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_2', 't': 40}, rangeid='', name='hist_11'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 5.1013174827709795}, r={'seed': 1612834589}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_2', 't': 50}, rangeid='', name='hist_12'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 8.376073873906922}, r={'seed': 1612834589}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_2', 't': 60}, rangeid='', name='hist_13'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 9.996779663860996}, r={'seed': 1612834589}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_2', 't': 100}, rangeid='', name='hist_14'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 0.004105645810848513}, r={'seed': 28268822}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_3', 't': 0}, rangeid='', name='hist_15'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 1.7630764252943243}, r={'seed': 28268822}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_3', 't': 40}, rangeid='', name='hist_16'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 5.1460417740129625}, r={'seed': 28268822}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_3', 't': 50}, rangeid='', name='hist_17'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 8.40027584188355}, r={'seed': 28268822}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_3', 't': 60}, rangeid='', name='hist_18'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 9.996836779451714}, r={'seed': 28268822}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_3', 't': 100}, rangeid='', name='hist_19'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 0.0037569908838189204}, r={'seed': 4260675538}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_4', 't': 0}, rangeid='', name='hist_20'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 1.6378293230060559}, r={'seed': 4260675538}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_4', 't': 40}, rangeid='', name='hist_21'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 4.924140166096661}, r={'seed': 4260675538}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_4', 't': 50}, rangeid='', name='hist_22'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 8.277342402550868}, r={'seed': 4260675538}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_4', 't': 60}, rangeid='', name='hist_23'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 9.996543208332358}, r={'seed': 4260675538}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_4', 't': 100}, rangeid='', name='hist_24'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 0.0035576861892378416}, r={'seed': 420788647}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_5', 't': 0}, rangeid='', name='hist_25'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 1.5645112885019485}, r={'seed': 420788647}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_5', 't': 40}, rangeid='', name='hist_26'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 4.7879419002260555}, r={'seed': 420788647}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_5', 't': 50}, rangeid='', name='hist_27'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 8.198196150411718}, r={'seed': 420788647}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_5', 't': 60}, rangeid='', name='hist_28'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 9.996349553773157}, r={'seed': 420788647}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_5', 't': 100}, rangeid='', name='hist_29'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 0.006841983111062025}, r={'seed': 3798314825}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_6', 't': 0}, rangeid='', name='hist_30'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 2.629719998704038}, r={'seed': 3798314825}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_6', 't': 40}, rangeid='', name='hist_31'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 6.386297198063246}, r={'seed': 3798314825}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_6', 't': 50}, rangeid='', name='hist_32'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 8.974697629346908}, r={'seed': 3798314825}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_6', 't': 60}, rangeid='', name='hist_33'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 9.99810213629282}, r={'seed': 3798314825}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_6', 't': 100}, rangeid='', name='hist_34'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 0.003743727872745982}, r={'seed': 317998221}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_7', 't': 0}, rangeid='', name='hist_35'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 1.632989788946346}, r={'seed': 317998221}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_7', 't': 40}, rangeid='', name='hist_36'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 4.915297962215212}, r={'seed': 317998221}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_7', 't': 50}, rangeid='', name='hist_37'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 8.272292001415185}, r={'seed': 317998221}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_7', 't': 60}, rangeid='', name='hist_38'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 9.996530961505558}, r={'seed': 317998221}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_7', 't': 100}, rangeid='', name='hist_39'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 0.014556312791561945}, r={'seed': 404157600}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_8', 't': 0}, rangeid='', name='hist_40'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 4.317146303403044}, r={'seed': 404157600}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_8', 't': 40}, rangeid='', name='hist_41'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 7.900357779757452}, r={'seed': 404157600}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_8', 't': 50}, rangeid='', name='hist_42'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 9.490753491558548}, r={'seed': 404157600}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_8', 't': 60}, rangeid='', name='hist_43'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 9.99910853568146}, r={'seed': 404157600}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_8', 't': 100}, rangeid='', name='hist_44'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 0.003917700316414757}, r={'seed': 3647026642}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_9', 't': 0}, rangeid='', name='hist_45'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 1.6960297046671722}, r={'seed': 3647026642}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_9', 't': 40}, rangeid='', name='hist_46'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 5.028890434716651}, r={'seed': 3647026642}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_9', 't': 50}, rangeid='', name='hist_47'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 8.336273464537053}, r={'seed': 3647026642}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_9', 't': 60}, rangeid='', name='hist_48'),
#  ParameterScenario(sequence={}, times=(), p={'experience': 9.996685016931059}, r={'seed': 3647026642}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'var_9', 't': 100}, rangeid='', name='hist_49')]

# %%
ec, hist_short_long = prop.parameter_sample(psf_short, ps_short_long, run_stochastic=True)
# Out:
# SCENARIOS COMPLETE:   0%|          | 0/50 [00:00<?, ?it/s]
# SCENARIOS COMPLETE:  88%|████████▊ | 44/50 [00:00<00:00, 436.96it/s]
# SCENARIOS COMPLETE: 100%|██████████| 50/50 [00:00<00:00, 428.64it/s]

# %%
fig, axs = hist_short_long.plot_line('s.fatigue', 's.stress', 'r.s.fatigue_param', aggregation="percentile")

# %%
# fig.savefig("stress_degradation.pdf", format="pdf", bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# Now sample in the model:

# %%
from examples.rover.rover_model_human import RoverHuman, RoverHumanParam
pd_comb_mdl = ParameterDomain(RoverHumanParam)
# pd_comb_mdl.add_constant('drive_modes', {"mode_args": "degradation"})
pd_comb_mdl.add_variable("psfs.fatigue")
pd_comb_mdl.add_variables("psfs.stress")
rpd.add_constant('drive_modes', {"mode_args": "degradation"})
pd_comb_mdl(1,1)
# Out:
# RoverHumanParam(ground=GroundParam(linetype='sine', amp=1.0, period=6.283185307179586, radius=20.0, x_start=10.0, y_end=10.0, x_min=0.0, x_max=30.0, x_res=0.1, path_buffer_on=0.2, path_buffer_poor=0.3, path_buffer_near=0.4, dest_buffer_on=1.0, dest_buffer_near=2.0), correction=ResCorrection(ub_f=10.0, lb_f=-1.0, ub_t=10.0, lb_t=0.0, ub_d=2.0, lb_d=-2.0, cor_d=0.0, cor_t=0.0, cor_f=0.0), degradation=DegParam(friction=0.0, drift=0.0), drive_modes={'mode_args': 'set'}, psfs=PSFParam(fatigue=1.0, stress=1.0))

# %%
ps_comb_mdl = ParameterHistSample(hist_short_long, "s.fatigue", "s.stress", paramdomain=pd_comb_mdl)
ps_comb_mdl.add_hist_groups(reps= 10, ts = [0, 1, 3, 5, 6, 8])
ps_comb_mdl.scenarios()
# Out:
# [ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 7.3939285057193675, 'stress': 0.0}}, r={'seed': 1374615985}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_0', 't': 0}, rangeid='', name='hist_0'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 7.552719802209249, 'stress': 1.0}}, r={'seed': 1374615985}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_0', 't': 1}, rangeid='', name='hist_1'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 100.0}}, r={'seed': 1374615985}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_0', 't': 3}, rangeid='', name='hist_2'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 100.0}}, r={'seed': 1374615985}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_0', 't': 5}, rangeid='', name='hist_3'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 100.0}}, r={'seed': 1374615985}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_0', 't': 6}, rangeid='', name='hist_4'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 100.0}}, r={'seed': 1374615985}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_0', 't': 8}, rangeid='', name='hist_5'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 7.3939285057193675, 'stress': 0.0}}, r={'seed': 2913953025}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_1', 't': 0}, rangeid='', name='hist_6'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 7.552719802209249, 'stress': 1.0}}, r={'seed': 2913953025}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_1', 't': 1}, rangeid='', name='hist_7'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 3.0}}, r={'seed': 2913953025}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_1', 't': 3}, rangeid='', name='hist_8'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 6.0}}, r={'seed': 2913953025}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_1', 't': 5}, rangeid='', name='hist_9'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 8.0}}, r={'seed': 2913953025}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_1', 't': 6}, rangeid='', name='hist_10'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 15.0}}, r={'seed': 2913953025}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_1', 't': 8}, rangeid='', name='hist_11'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 7.3939285057193675, 'stress': 0.0}}, r={'seed': 2277005809}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_2', 't': 0}, rangeid='', name='hist_12'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 7.552719802209249, 'stress': 1.0}}, r={'seed': 2277005809}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_2', 't': 1}, rangeid='', name='hist_13'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 3.0}}, r={'seed': 2277005809}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_2', 't': 3}, rangeid='', name='hist_14'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 5.0}}, r={'seed': 2277005809}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_2', 't': 5}, rangeid='', name='hist_15'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 6.0}}, r={'seed': 2277005809}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_2', 't': 6}, rangeid='', name='hist_16'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 10.0}}, r={'seed': 2277005809}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_2', 't': 8}, rangeid='', name='hist_17'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 7.3939285057193675, 'stress': 0.0}}, r={'seed': 2376437695}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_3', 't': 0}, rangeid='', name='hist_18'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 7.552719802209249, 'stress': 1.0}}, r={'seed': 2376437695}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_3', 't': 1}, rangeid='', name='hist_19'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 3.0}}, r={'seed': 2376437695}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_3', 't': 3}, rangeid='', name='hist_20'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 5.0}}, r={'seed': 2376437695}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_3', 't': 5}, rangeid='', name='hist_21'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 6.0}}, r={'seed': 2376437695}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_3', 't': 6}, rangeid='', name='hist_22'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 9.0}}, r={'seed': 2376437695}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_3', 't': 8}, rangeid='', name='hist_23'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 7.3939285057193675, 'stress': 0.0}}, r={'seed': 917148789}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_4', 't': 0}, rangeid='', name='hist_24'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 7.552719802209249, 'stress': 1.0}}, r={'seed': 917148789}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_4', 't': 1}, rangeid='', name='hist_25'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 3.0}}, r={'seed': 917148789}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_4', 't': 3}, rangeid='', name='hist_26'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 5.0}}, r={'seed': 917148789}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_4', 't': 5}, rangeid='', name='hist_27'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 6.0}}, r={'seed': 917148789}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_4', 't': 6}, rangeid='', name='hist_28'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 8.0}}, r={'seed': 917148789}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_4', 't': 8}, rangeid='', name='hist_29'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 1.185280182265953, 'stress': 0.0}}, r={'seed': 3872588685}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_5', 't': 0}, rangeid='', name='hist_30'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 2.355321442941582, 'stress': 1.0}}, r={'seed': 3872588685}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_5', 't': 1}, rangeid='', name='hist_31'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 5.017908302485789, 'stress': 100.0}}, r={'seed': 3872588685}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_5', 't': 3}, rangeid='', name='hist_32'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 6.789016559073363, 'stress': 100.0}}, r={'seed': 3872588685}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_5', 't': 5}, rangeid='', name='hist_33'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 9.694822371229817, 'stress': 100.0}}, r={'seed': 3872588685}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_5', 't': 6}, rangeid='', name='hist_34'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 100.0}}, r={'seed': 3872588685}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_5', 't': 8}, rangeid='', name='hist_35'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 1.185280182265953, 'stress': 0.0}}, r={'seed': 181365478}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_6', 't': 0}, rangeid='', name='hist_36'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 2.355321442941582, 'stress': 1.0}}, r={'seed': 181365478}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_6', 't': 1}, rangeid='', name='hist_37'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 5.017908302485789, 'stress': 4.0}}, r={'seed': 181365478}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_6', 't': 3}, rangeid='', name='hist_38'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 6.789016559073363, 'stress': 14.0}}, r={'seed': 181365478}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_6', 't': 5}, rangeid='', name='hist_39'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 9.694822371229817, 'stress': 25.0}}, r={'seed': 181365478}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_6', 't': 6}, rangeid='', name='hist_40'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 70.0}}, r={'seed': 181365478}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_6', 't': 8}, rangeid='', name='hist_41'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 1.185280182265953, 'stress': 0.0}}, r={'seed': 739543710}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_7', 't': 0}, rangeid='', name='hist_42'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 2.355321442941582, 'stress': 1.0}}, r={'seed': 739543710}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_7', 't': 1}, rangeid='', name='hist_43'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 5.017908302485789, 'stress': 3.0}}, r={'seed': 739543710}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_7', 't': 3}, rangeid='', name='hist_44'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 6.789016559073363, 'stress': 6.0}}, r={'seed': 739543710}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_7', 't': 5}, rangeid='', name='hist_45'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 9.694822371229817, 'stress': 8.0}}, r={'seed': 739543710}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_7', 't': 6}, rangeid='', name='hist_46'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 14.0}}, r={'seed': 739543710}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_7', 't': 8}, rangeid='', name='hist_47'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 1.185280182265953, 'stress': 0.0}}, r={'seed': 3560727715}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_8', 't': 0}, rangeid='', name='hist_48'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 2.355321442941582, 'stress': 1.0}}, r={'seed': 3560727715}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_8', 't': 1}, rangeid='', name='hist_49'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 5.017908302485789, 'stress': 3.0}}, r={'seed': 3560727715}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_8', 't': 3}, rangeid='', name='hist_50'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 6.789016559073363, 'stress': 5.0}}, r={'seed': 3560727715}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_8', 't': 5}, rangeid='', name='hist_51'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 9.694822371229817, 'stress': 6.0}}, r={'seed': 3560727715}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_8', 't': 6}, rangeid='', name='hist_52'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 9.0}}, r={'seed': 3560727715}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_8', 't': 8}, rangeid='', name='hist_53'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 1.185280182265953, 'stress': 0.0}}, r={'seed': 1643397882}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_9', 't': 0}, rangeid='', name='hist_54'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 2.355321442941582, 'stress': 1.0}}, r={'seed': 1643397882}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_9', 't': 1}, rangeid='', name='hist_55'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 5.017908302485789, 'stress': 3.0}}, r={'seed': 1643397882}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_9', 't': 3}, rangeid='', name='hist_56'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 6.789016559073363, 'stress': 5.0}}, r={'seed': 1643397882}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_9', 't': 5}, rangeid='', name='hist_57'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 9.694822371229817, 'stress': 6.0}}, r={'seed': 1643397882}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_9', 't': 6}, rangeid='', name='hist_58'),
#  ParameterScenario(sequence={}, times=(), p={'psfs': {'fatigue': 10.0, 'stress': 8.0}}, r={'seed': 1643397882}, sp={}, prob=1.0, inputparams={'comp_group': 'default', 'rep': 'hist_9', 't': 8}, rangeid='', name='hist_59')]

# %%
mdl_hum = RoverHuman()

# %%
ec, hist = prop.nominal(mdl_hum)
plot_map(mdl_hum, hist)
ec
# Out:
# endclass:
# --rate:                              1.0
# --cost:                                0
# --prob:                              1.0
# --expected_cost:                       0
# --in_bound:                         True
# --at_finish:                        True
# --line_dist:                           1
# --num_modes:                           0
# --end_dist:                          0.0
# --tot_deviation:     0.11859644458085598
# --faults:                             {}
# --classification:        nominal mission
# --end_x:              29.254775331608617
# --end_y:             -0.7827640334587979
# --endpt:                        array(2)

# %%
ec_comb, hist_comb = prop.parameter_sample(mdl_hum, ps_comb_mdl)
# Out:
# SCENARIOS COMPLETE:   0%|          | 0/60 [00:00<?, ?it/s]
# SCENARIOS COMPLETE:   2%|▏         | 1/60 [00:00<00:24,  2.38it/s]
# SCENARIOS COMPLETE:   3%|▎         | 2/60 [00:00<00:24,  2.40it/s]
# SCENARIOS COMPLETE:   5%|▌         | 3/60 [00:01<00:23,  2.43it/s]
# SCENARIOS COMPLETE:   7%|▋         | 4/60 [00:01<00:22,  2.44it/s]
# SCENARIOS COMPLETE:   8%|▊         | 5/60 [00:02<00:22,  2.45it/s]
# SCENARIOS COMPLETE:  10%|█         | 6/60 [00:02<00:22,  2.43it/s]
# SCENARIOS COMPLETE:  12%|█▏        | 7/60 [00:02<00:22,  2.40it/s]
# SCENARIOS COMPLETE:  13%|█▎        | 8/60 [00:03<00:21,  2.37it/s]
# SCENARIOS COMPLETE:  15%|█▌        | 9/60 [00:03<00:21,  2.34it/s]
# SCENARIOS COMPLETE:  17%|█▋        | 10/60 [00:04<00:21,  2.37it/s]
# SCENARIOS COMPLETE:  18%|█▊        | 11/60 [00:04<00:20,  2.35it/s]
# SCENARIOS COMPLETE:  20%|██        | 12/60 [00:05<00:20,  2.29it/s]
# SCENARIOS COMPLETE:  22%|██▏       | 13/60 [00:05<00:20,  2.29it/s]
# SCENARIOS COMPLETE:  23%|██▎       | 14/60 [00:05<00:19,  2.31it/s]
# SCENARIOS COMPLETE:  25%|██▌       | 15/60 [00:06<00:19,  2.34it/s]
# SCENARIOS COMPLETE:  27%|██▋       | 16/60 [00:06<00:18,  2.36it/s]
# SCENARIOS COMPLETE:  28%|██▊       | 17/60 [00:07<00:17,  2.39it/s]
# SCENARIOS COMPLETE:  30%|███       | 18/60 [00:07<00:17,  2.40it/s]
# SCENARIOS COMPLETE:  32%|███▏      | 19/60 [00:07<00:17,  2.41it/s]
# SCENARIOS COMPLETE:  33%|███▎      | 20/60 [00:08<00:16,  2.39it/s]
# SCENARIOS COMPLETE:  35%|███▌      | 21/60 [00:08<00:16,  2.39it/s]
# SCENARIOS COMPLETE:  37%|███▋      | 22/60 [00:09<00:16,  2.35it/s]
# SCENARIOS COMPLETE:  38%|███▊      | 23/60 [00:09<00:15,  2.38it/s]
# SCENARIOS COMPLETE:  40%|████      | 24/60 [00:10<00:15,  2.40it/s]
# SCENARIOS COMPLETE:  42%|████▏     | 25/60 [00:10<00:14,  2.39it/s]
# SCENARIOS COMPLETE:  43%|████▎     | 26/60 [00:10<00:14,  2.39it/s]
# SCENARIOS COMPLETE:  45%|████▌     | 27/60 [00:11<00:13,  2.39it/s]
# SCENARIOS COMPLETE:  47%|████▋     | 28/60 [00:11<00:13,  2.41it/s]
# SCENARIOS COMPLETE:  48%|████▊     | 29/60 [00:12<00:12,  2.41it/s]
# SCENARIOS COMPLETE:  50%|█████     | 30/60 [00:12<00:12,  2.42it/s]
# SCENARIOS COMPLETE:  52%|█████▏    | 31/60 [00:13<00:11,  2.42it/s]
# SCENARIOS COMPLETE:  53%|█████▎    | 32/60 [00:13<00:11,  2.41it/s]
# SCENARIOS COMPLETE:  55%|█████▌    | 33/60 [00:13<00:11,  2.41it/s]
# SCENARIOS COMPLETE:  57%|█████▋    | 34/60 [00:14<00:10,  2.41it/s]
# SCENARIOS COMPLETE:  58%|█████▊    | 35/60 [00:14<00:10,  2.41it/s]
# SCENARIOS COMPLETE:  60%|██████    | 36/60 [00:15<00:09,  2.42it/s]
# SCENARIOS COMPLETE:  62%|██████▏   | 37/60 [00:15<00:09,  2.41it/s]
# SCENARIOS COMPLETE:  63%|██████▎   | 38/60 [00:15<00:09,  2.39it/s]
# SCENARIOS COMPLETE:  65%|██████▌   | 39/60 [00:16<00:08,  2.39it/s]
# SCENARIOS COMPLETE:  67%|██████▋   | 40/60 [00:16<00:08,  2.38it/s]
# SCENARIOS COMPLETE:  68%|██████▊   | 41/60 [00:17<00:07,  2.40it/s]
# SCENARIOS COMPLETE:  70%|███████   | 42/60 [00:17<00:07,  2.42it/s]
# SCENARIOS COMPLETE:  72%|███████▏  | 43/60 [00:18<00:07,  2.39it/s]
# SCENARIOS COMPLETE:  73%|███████▎  | 44/60 [00:18<00:06,  2.39it/s]
# SCENARIOS COMPLETE:  75%|███████▌  | 45/60 [00:18<00:06,  2.33it/s]
# SCENARIOS COMPLETE:  77%|███████▋  | 46/60 [00:19<00:06,  2.32it/s]
# SCENARIOS COMPLETE:  78%|███████▊  | 47/60 [00:19<00:05,  2.33it/s]
# SCENARIOS COMPLETE:  80%|████████  | 48/60 [00:20<00:05,  2.35it/s]
# SCENARIOS COMPLETE:  82%|████████▏ | 49/60 [00:20<00:04,  2.34it/s]
# SCENARIOS COMPLETE:  83%|████████▎ | 50/60 [00:21<00:04,  2.31it/s]
# SCENARIOS COMPLETE:  85%|████████▌ | 51/60 [00:21<00:03,  2.32it/s]
# SCENARIOS COMPLETE:  87%|████████▋ | 52/60 [00:21<00:03,  2.32it/s]
# SCENARIOS COMPLETE:  88%|████████▊ | 53/60 [00:22<00:02,  2.36it/s]
# SCENARIOS COMPLETE:  90%|█████████ | 54/60 [00:22<00:02,  2.39it/s]
# SCENARIOS COMPLETE:  92%|█████████▏| 55/60 [00:23<00:02,  2.40it/s]
# SCENARIOS COMPLETE:  93%|█████████▎| 56/60 [00:23<00:01,  2.40it/s]
# SCENARIOS COMPLETE:  95%|█████████▌| 57/60 [00:23<00:01,  2.39it/s]
# SCENARIOS COMPLETE:  97%|█████████▋| 58/60 [00:24<00:00,  2.35it/s]
# SCENARIOS COMPLETE:  98%|█████████▊| 59/60 [00:24<00:00,  2.35it/s]
# SCENARIOS COMPLETE: 100%|██████████| 60/60 [00:25<00:00,  2.35it/s]
# SCENARIOS COMPLETE: 100%|██████████| 60/60 [00:25<00:00,  2.38it/s]

# %%
fig, ax = plot_map(mdl_hum, hist_comb)

# %%
hist_comb.plot_line('flows.psfs.s.attention', 'flows.motor_control.s.rpower', 'flows.motor_control.s.lpower')
# Out:
# (<Figure size 600x400 with 4 Axes>,
#  array([<Axes: title={'center': 'flows.psfs.s.attention'}, xlabel=' '>,
#         <Axes: title={'center': 'flows.motor_control.s.rpower'}, xlabel='time'>,
#         <Axes: title={'center': 'flows.motor_control.s.lpower'}, xlabel='time'>,
#         <Axes: >], dtype=object))

# %%
ne = NominalEnvelope(ps_comb_mdl, ec_comb, 'at_finish',
                     'p.psfs.fatigue', 'p.psfs.stress',
                     func=lambda x: x == True)
ne.plot_scatter()
# Out:
# (<Figure size 600x400 with 1 Axes>,
#  <Axes: xlabel='p.psfs.fatigue', ylabel='p.psfs.stress'>)

# %% [markdown]
# (note, this is different in the turn case because of the long straightaway)

# %%
mdl_hum = RoverHuman(p={'ground': {'linetype': 'turn'}})
ec, hist = prop.nominal(mdl_hum)
plot_map(mdl_hum, hist)
ec
# Out:
# endclass:
# --rate:                              1.0
# --cost:                                0
# --prob:                              1.0
# --expected_cost:                       0
# --in_bound:                         True
# --at_finish:                        True
# --line_dist:                           1
# --num_modes:                           0
# --end_dist:                          0.0
# --tot_deviation:    0.005246344989065292
# --faults:                             {}
# --classification:        nominal mission
# --end_x:              29.813614084369863
# --end_y:               17.26588133276667
# --endpt:                        array(2)

# %%
ec_comb, hist_comb = prop.parameter_sample(mdl_hum, ps_comb_mdl)
# Out:
# SCENARIOS COMPLETE:   0%|          | 0/60 [00:00<?, ?it/s]
# SCENARIOS COMPLETE:   2%|▏         | 1/60 [00:00<00:23,  2.51it/s]
# SCENARIOS COMPLETE:   3%|▎         | 2/60 [00:00<00:22,  2.53it/s]
# SCENARIOS COMPLETE:   5%|▌         | 3/60 [00:01<00:22,  2.51it/s]
# SCENARIOS COMPLETE:   7%|▋         | 4/60 [00:01<00:22,  2.50it/s]
# SCENARIOS COMPLETE:   8%|▊         | 5/60 [00:01<00:22,  2.50it/s]
# SCENARIOS COMPLETE:  10%|█         | 6/60 [00:02<00:21,  2.49it/s]
# SCENARIOS COMPLETE:  12%|█▏        | 7/60 [00:02<00:21,  2.49it/s]
# SCENARIOS COMPLETE:  13%|█▎        | 8/60 [00:03<00:20,  2.49it/s]
# SCENARIOS COMPLETE:  15%|█▌        | 9/60 [00:03<00:20,  2.48it/s]
# SCENARIOS COMPLETE:  17%|█▋        | 10/60 [00:04<00:20,  2.48it/s]
# SCENARIOS COMPLETE:  18%|█▊        | 11/60 [00:04<00:19,  2.46it/s]
# SCENARIOS COMPLETE:  20%|██        | 12/60 [00:04<00:19,  2.44it/s]
# SCENARIOS COMPLETE:  22%|██▏       | 13/60 [00:05<00:19,  2.44it/s]
# SCENARIOS COMPLETE:  23%|██▎       | 14/60 [00:05<00:18,  2.42it/s]
# SCENARIOS COMPLETE:  25%|██▌       | 15/60 [00:06<00:18,  2.42it/s]
# SCENARIOS COMPLETE:  27%|██▋       | 16/60 [00:06<00:18,  2.41it/s]
# SCENARIOS COMPLETE:  28%|██▊       | 17/60 [00:06<00:17,  2.40it/s]
# SCENARIOS COMPLETE:  30%|███       | 18/60 [00:07<00:17,  2.37it/s]
# SCENARIOS COMPLETE:  32%|███▏      | 19/60 [00:07<00:17,  2.36it/s]
# SCENARIOS COMPLETE:  33%|███▎      | 20/60 [00:08<00:16,  2.36it/s]
# SCENARIOS COMPLETE:  35%|███▌      | 21/60 [00:08<00:16,  2.39it/s]
# SCENARIOS COMPLETE:  37%|███▋      | 22/60 [00:09<00:15,  2.38it/s]
# SCENARIOS COMPLETE:  38%|███▊      | 23/60 [00:09<00:15,  2.40it/s]
# SCENARIOS COMPLETE:  40%|████      | 24/60 [00:09<00:14,  2.42it/s]
# SCENARIOS COMPLETE:  42%|████▏     | 25/60 [00:10<00:14,  2.43it/s]
# SCENARIOS COMPLETE:  43%|████▎     | 26/60 [00:10<00:13,  2.46it/s]
# SCENARIOS COMPLETE:  45%|████▌     | 27/60 [00:11<00:13,  2.43it/s]
# SCENARIOS COMPLETE:  47%|████▋     | 28/60 [00:11<00:13,  2.44it/s]
# SCENARIOS COMPLETE:  48%|████▊     | 29/60 [00:11<00:12,  2.45it/s]
# SCENARIOS COMPLETE:  50%|█████     | 30/60 [00:12<00:12,  2.44it/s]
# SCENARIOS COMPLETE:  52%|█████▏    | 31/60 [00:12<00:11,  2.42it/s]
# SCENARIOS COMPLETE:  53%|█████▎    | 32/60 [00:13<00:11,  2.38it/s]
# SCENARIOS COMPLETE:  55%|█████▌    | 33/60 [00:13<00:11,  2.39it/s]
# SCENARIOS COMPLETE:  57%|█████▋    | 34/60 [00:13<00:10,  2.41it/s]
# SCENARIOS COMPLETE:  58%|█████▊    | 35/60 [00:14<00:10,  2.40it/s]
# SCENARIOS COMPLETE:  60%|██████    | 36/60 [00:14<00:10,  2.39it/s]
# SCENARIOS COMPLETE:  62%|██████▏   | 37/60 [00:15<00:09,  2.37it/s]
# SCENARIOS COMPLETE:  63%|██████▎   | 38/60 [00:15<00:09,  2.37it/s]
# SCENARIOS COMPLETE:  65%|██████▌   | 39/60 [00:16<00:08,  2.39it/s]
# SCENARIOS COMPLETE:  67%|██████▋   | 40/60 [00:16<00:08,  2.41it/s]
# SCENARIOS COMPLETE:  68%|██████▊   | 41/60 [00:16<00:07,  2.42it/s]
# SCENARIOS COMPLETE:  70%|███████   | 42/60 [00:17<00:07,  2.44it/s]
# SCENARIOS COMPLETE:  72%|███████▏  | 43/60 [00:17<00:07,  2.42it/s]
# SCENARIOS COMPLETE:  73%|███████▎  | 44/60 [00:18<00:06,  2.41it/s]
# SCENARIOS COMPLETE:  75%|███████▌  | 45/60 [00:18<00:06,  2.43it/s]
# SCENARIOS COMPLETE:  77%|███████▋  | 46/60 [00:18<00:05,  2.43it/s]
# SCENARIOS COMPLETE:  78%|███████▊  | 47/60 [00:19<00:05,  2.43it/s]
# SCENARIOS COMPLETE:  80%|████████  | 48/60 [00:19<00:04,  2.43it/s]
# SCENARIOS COMPLETE:  82%|████████▏ | 49/60 [00:20<00:04,  2.42it/s]
# SCENARIOS COMPLETE:  83%|████████▎ | 50/60 [00:20<00:04,  2.40it/s]
# SCENARIOS COMPLETE:  85%|████████▌ | 51/60 [00:21<00:03,  2.42it/s]
# SCENARIOS COMPLETE:  87%|████████▋ | 52/60 [00:21<00:03,  2.43it/s]
# SCENARIOS COMPLETE:  88%|████████▊ | 53/60 [00:21<00:02,  2.41it/s]
# SCENARIOS COMPLETE:  90%|█████████ | 54/60 [00:22<00:02,  2.40it/s]
# SCENARIOS COMPLETE:  92%|█████████▏| 55/60 [00:22<00:02,  2.39it/s]
# SCENARIOS COMPLETE:  93%|█████████▎| 56/60 [00:23<00:01,  2.34it/s]
# SCENARIOS COMPLETE:  95%|█████████▌| 57/60 [00:23<00:01,  2.33it/s]
# SCENARIOS COMPLETE:  97%|█████████▋| 58/60 [00:24<00:00,  2.36it/s]
# SCENARIOS COMPLETE:  98%|█████████▊| 59/60 [00:24<00:00,  2.38it/s]
# SCENARIOS COMPLETE: 100%|██████████| 60/60 [00:24<00:00,  2.39it/s]
# SCENARIOS COMPLETE: 100%|██████████| 60/60 [00:24<00:00,  2.42it/s]

# %%
fig, ax = plot_map(mdl_hum, hist_comb)

# %%
hist_comb.plot_line('flows.psfs.s.attention', 'flows.motor_control.s.rpower', 'flows.motor_control.s.lpower')
# Out:
# (<Figure size 600x400 with 4 Axes>,
#  array([<Axes: title={'center': 'flows.psfs.s.attention'}, xlabel=' '>,
#         <Axes: title={'center': 'flows.motor_control.s.rpower'}, xlabel='time'>,
#         <Axes: title={'center': 'flows.motor_control.s.lpower'}, xlabel='time'>,
#         <Axes: >], dtype=object))

# %%
ne = NominalEnvelope(ps_comb_mdl, ec_comb, 'at_finish',
                     'p.psfs.fatigue', 'p.psfs.stress',
                     func=lambda x: x == True)
ne.plot_scatter()
# Out:
# (<Figure size 600x400 with 1 Axes>,
#  <Axes: xlabel='p.psfs.fatigue', ylabel='p.psfs.stress'>)

# %% [markdown]
# We can thus see how degradation time effects this:

# %%
ne = NominalEnvelope(ps_comb_mdl, ec_comb, 'at_finish',
                     'inputparams.t', 'inputparams.rep',
                     func=lambda x: x == True)
ne.plot_scatter()
# Out:
# (<Figure size 600x400 with 1 Axes>,
#  <Axes: xlabel='inputparams.t', ylabel='inputparams.rep'>)

# %% [markdown]
# To re-implement:
# - Need to be able to jointly plot/tabulate by single-day time + multi-day time
# - Combining approaches?

# %% [markdown]
# As for the human resilience:

# %%
ec_nest, hist_nest, app_nest = prop.nested_sample(mdl, phs, faultdomains={'drive_faults':  (('all_fxnclass_modes', 'Drive'), {})},
                                                  faultsamples={'drive_faults': (('fault_phases', 'drive_faults', "start"), {})},
                                                  pool=mp.Pool(5))
# Out:
# NESTED SCENARIOS COMPLETE:   0%|          | 0/40 [00:00<?, ?it/s]
# NESTED SCENARIOS COMPLETE:   2%|▎         | 1/40 [00:00<00:15,  2.54it/s]
# NESTED SCENARIOS COMPLETE:   5%|▌         | 2/40 [00:00<00:14,  2.62it/s]
# NESTED SCENARIOS COMPLETE:   8%|▊         | 3/40 [00:01<00:13,  2.68it/s]
# NESTED SCENARIOS COMPLETE:  10%|█         | 4/40 [00:01<00:13,  2.71it/s]
# NESTED SCENARIOS COMPLETE:  12%|█▎        | 5/40 [00:02<00:18,  1.86it/s]
# NESTED SCENARIOS COMPLETE:  15%|█▌        | 6/40 [00:03<00:21,  1.57it/s]
# NESTED SCENARIOS COMPLETE:  18%|█▊        | 7/40 [00:03<00:17,  1.84it/s]
# NESTED SCENARIOS COMPLETE:  20%|██        | 8/40 [00:03<00:15,  2.07it/s]
# NESTED SCENARIOS COMPLETE:  22%|██▎       | 9/40 [00:04<00:18,  1.68it/s]
# NESTED SCENARIOS COMPLETE:  25%|██▌       | 10/40 [00:05<00:15,  1.93it/s]
# NESTED SCENARIOS COMPLETE:  28%|██▊       | 11/40 [00:05<00:13,  2.14it/s]
# NESTED SCENARIOS COMPLETE:  30%|███       | 12/40 [00:05<00:12,  2.32it/s]
# NESTED SCENARIOS COMPLETE:  32%|███▎      | 13/40 [00:06<00:10,  2.47it/s]
# NESTED SCENARIOS COMPLETE:  35%|███▌      | 14/40 [00:06<00:10,  2.58it/s]
# NESTED SCENARIOS COMPLETE:  38%|███▊      | 15/40 [00:06<00:09,  2.65it/s]
# NESTED SCENARIOS COMPLETE:  40%|████      | 16/40 [00:07<00:08,  2.72it/s]
# NESTED SCENARIOS COMPLETE:  42%|████▎     | 17/40 [00:07<00:11,  2.00it/s]
# NESTED SCENARIOS COMPLETE:  45%|████▌     | 18/40 [00:08<00:13,  1.66it/s]
# NESTED SCENARIOS COMPLETE:  48%|████▊     | 19/40 [00:09<00:11,  1.86it/s]
# NESTED SCENARIOS COMPLETE:  50%|█████     | 20/40 [00:09<00:09,  2.05it/s]
# NESTED SCENARIOS COMPLETE:  52%|█████▎    | 21/40 [00:09<00:08,  2.18it/s]
# NESTED SCENARIOS COMPLETE:  55%|█████▌    | 22/40 [00:10<00:08,  2.15it/s]
# NESTED SCENARIOS COMPLETE:  57%|█████▊    | 23/40 [00:10<00:07,  2.28it/s]
# NESTED SCENARIOS COMPLETE:  60%|██████    | 24/40 [00:11<00:06,  2.36it/s]
# NESTED SCENARIOS COMPLETE:  62%|██████▎   | 25/40 [00:12<00:08,  1.84it/s]
# NESTED SCENARIOS COMPLETE:  65%|██████▌   | 26/40 [00:12<00:08,  1.59it/s]
# NESTED SCENARIOS COMPLETE:  68%|██████▊   | 27/40 [00:13<00:07,  1.83it/s]
# NESTED SCENARIOS COMPLETE:  70%|███████   | 28/40 [00:13<00:05,  2.05it/s]
# NESTED SCENARIOS COMPLETE:  72%|███████▎  | 29/40 [00:14<00:06,  1.70it/s]
# NESTED SCENARIOS COMPLETE:  75%|███████▌  | 30/40 [00:15<00:06,  1.54it/s]
# NESTED SCENARIOS COMPLETE:  78%|███████▊  | 31/40 [00:15<00:05,  1.78it/s]
# NESTED SCENARIOS COMPLETE:  80%|████████  | 32/40 [00:15<00:03,  2.01it/s]
# NESTED SCENARIOS COMPLETE:  82%|████████▎ | 33/40 [00:16<00:04,  1.69it/s]
# NESTED SCENARIOS COMPLETE:  85%|████████▌ | 34/40 [00:17<00:03,  1.51it/s]
# NESTED SCENARIOS COMPLETE:  88%|████████▊ | 35/40 [00:17<00:02,  1.75it/s]
# NESTED SCENARIOS COMPLETE:  90%|█████████ | 36/40 [00:18<00:02,  1.99it/s]
# NESTED SCENARIOS COMPLETE:  92%|█████████▎| 37/40 [00:19<00:01,  1.67it/s]
# NESTED SCENARIOS COMPLETE:  95%|█████████▌| 38/40 [00:19<00:01,  1.87it/s]
# NESTED SCENARIOS COMPLETE:  98%|█████████▊| 39/40 [00:19<00:00,  2.04it/s]
# NESTED SCENARIOS COMPLETE: 100%|██████████| 40/40 [00:20<00:00,  2.22it/s]
# NESTED SCENARIOS COMPLETE: 100%|██████████| 40/40 [00:20<00:00,  1.98it/s]

# %%
nc = NestedComparison(ec_nest, phs, ['inputparams.t'], app_nest, ['fault'], metrics=['tot_deviation', 'end_dist'], default_stat=np.mean, ci_metrics=['end_dist', 'tot_deviation'])

# %%
nc.sort_by_factor("fault")
nc.sort_by_factor("inputparams.t")
fig, ax = nc.as_plots('end_dist', 'tot_deviation', figsize=(8,4))

# %%
# fig.savefig("human_resilience_degradation.pdf", format="pdf", bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ## Combined Degradation
#
# Idea: make same resilience plots as before but with degradation of resilience to drive faults at 0, 4, and 8 hours of fatigue.
#
# Need method of doing this:
# - take params for one and replace with the other (kind of hacky and requires independence)
# - create composite of both? (how do you determine the merge between output params?)
# - use a combined method with both histories as input and sample over t_life and t_day (use this one)

# %% [markdown]
# Resilience assessment
