# %%
from fmdtools_examples.uas_water_rescue.model_main import Drone
from fmdtools_examples.uas_water_rescue.model_main import plot_env_with_traj
from fmdtools_examples.uas_water_rescue.model_main import plot_env_with_traj_z
import fmdtools.sim.propagate as propagate

mdl = Drone(sp={'end_time': 5})
results_fault, hist_fault = propagate.one_fault(mdl, "affect_dof.ca.comps.lr", "mechbreak", time=1.4)
plot_env_with_traj(hist_fault, mdl)
# Out:
# /Users/iris/Documents/GitHub/fmdtools/src/fmdtools/sim/propagate.py:691: UserWarning: Faults found during the nominal run {'store_ee.lowcharge': Fault(prob=7e-05, cost=0.0, phases=(('taxi', 0.6), ('move', 0.2), ('land', 0.2)), disturbances=(), units=sim), 's1p1.lowcharge': Fault(prob=4e-05, cost=100.0, phases=(('taxi', 0.5), ('move', 0.2), ('land', 0.3)), disturbances=(), units=hr)}
#   warnings.warn("Faults found during the nominal run " + str(endfaults))
# (<Figure size 500x500 with 1 Axes>,
#  <Axes: title={'center': 'UAS Water Rescue'}, xlabel='X (100m)', ylabel='Y (100m)'>)
