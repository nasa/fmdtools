# %% [markdown]
# # Action Sequence Graph Tutorial
#
# This tutorial covers use of the Action Sequence Graph in the FxnBlock class, which is useful for representing a Function's progress through a sequence of actions (e.g., modes of operation, etc)..

# %%
from fmdtools.define.state import State
from fmdtools.define.mode import Mode
from fmdtools.define.block import FxnBlock, Action, ASG
from fmdtools.define.model import Model
from fmdtools.define.flow import Flow
import fmdtools.analyze as an
import fmdtools.sim.propagate as prop

# %% [markdown]
# Action sequence graphs are used within a function block to represent the actions that the function performs and their sequence. Actions in an ASG are respresented by `Action` blocks, which are similar to function and component blocks in that they have:
# - flow connections
# - modes, and
# - behaviors
#
# Flow connections are routed to the action in the function block definition and represent the *shared variables* between the actions.
#
# Modes are similar to function modes and are instantiated (as they are in components) at both the Function and Action level. Using the `name=` option enables one to tag these modes as action modes at the function level while using the same local name

# %% [markdown]
# Below we define the states to performed by the ASG:
# - Outcome, which tracks the number of actions and perceptions performed by the ASG
# - HazardState, which specifies whether a hazard is present, percieved, or mitigated

# %%
class OutcomeStates(State):
    num_perceptions: int=0
    num_actions:     int=0
class Outcome(Flow):
    _init_s = OutcomeStates
    
class HazardState(State):
    present:    bool=False
    percieved:  bool=False
    mitigated:  bool=False
class Hazard(Flow):
    _init_s = HazardState

# %% [markdown]
# Below we define three actions for use in a given model:
# - Perceive, a user's perception abilities/behaviors. In this function the user percieves a hazard (unless their perception fails)
# - Act, the user's action which they perform to mitigate the hazard.
# - Done, the user's state when they are done performing the action.

# %%
class ActionMode(Mode):
    faultparams=('failed','unable')
    exclusive=True
class Perceive(Action):
    __slots__=('hazard', 'outcome')
    _init_m = ActionMode
    _init_hazard = Hazard
    _init_outcome = Outcome
    def behavior(self,time):
        if not self.m.in_mode('failed', 'unable'): 
            self.hazard.s.percieved = self.hazard.s.present
            self.outcome.s.num_perceptions+=self.hazard.s.percieved
        else:
            self.hazard.s.percieved = False
            self.m.remove_fault('failed', 'nom')
    def percieved(self):
        return self.hazard.s.percieved
class Act(Action):
    __slots__=('hazard', 'outcome')
    _init_m = ActionMode
    _init_hazard = Hazard
    _init_outcome = Outcome
    def behavior(self,time):
        if not self.m.in_mode('failed', 'unable'): 
            self.outcome.s.num_actions+=1
            self.hazard.s.mitigated=True
        elif self.m.in_mode('failed'): 
            self.hazard.s.mitigated=False
            self.m.remove_fault('failed', 'nom')
        else: self.hazard.s.mitigated=False
    def acted(self):
        return not self.m.in_mode('failed')
class Done(Action):
    __slots__=('hazard')
    _init_hazard = Hazard
    def behavior(self,time):
        if not self.hazard.s.present: self.hazard.s.mitigated=False
    def ready(self):
        return not self.hazard.s.present

# %% [markdown]
# To proceed through the sequence of actions, *conditions* must be met between each action. In these actions, we have defined the following conditions:
# - Percieve.percieved: perception is done if the hazard is percieved
# - Act.acted: the action is complete if the action was performed
# - Done.complete: the hazard mitigation is over (and mitigated state is reset to False)
#
# To create the overall ASG structure, the following adds the flows, actions, and conditions to the ASG class

# %%
class Human(ASG):
    initial_action="perceive"
    _init_hazard = Hazard    # flows from external fxn/model should be defined as a part of the class definition                
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.add_flow("outcome",    fclass=Outcome) #flows can be added in the ASG for custom flow architectures.
        
        
        self.add_act("perceive",    Perceive,   "outcome", "hazard")
        self.add_act("act",         Act,        "outcome", "hazard")
        self.add_act("done",        Done,       "outcome", "hazard")
        
        self.add_cond("perceive",   "act",      "percieved",    self.actions['perceive'].percieved)
        self.add_cond("act",        "done",     "acted",        self.actions['act'].acted)
        self.add_cond("done",       "perceive", "ready",        self.actions['done'].ready)
        self.build()

# %% [markdown]
# Note the use of the following methods:
# - add_flow adds a flow so it can pass variables between actions. Here *Outcome* is an internal flow, while *Hazard* is an external flow.

# %%
help(ASG.add_flow)
# Out:
# Help on function add_flow in module fmdtools.define.block:
#
# add_flow(self, flowname, fclass=<class 'fmdtools.define.flow.Flow'>, p={}, s={}, flowtype='')
#     Adds a flow with given attributes to ASG. Used to enable a flexible
#     internal flow architecture in the ASG.
#
#     Parameters
#     ----------
#     flowname : str
#         Unique flow name to give the flow in the model
#     fclass : Class, optional
#         Class to instantiate (e.g. CommsFlow, MultiFlow). Default is Flow.
#         Class must take flowname, flowdict, flowtype as input to __init__()
#         May alternatively provide already-instanced object.
#     p : dict, optional
#         Parameter dictionary to instantiate the flow with
#     s : dict, optional
#         State dictionary to overwrite Flow default state values with
#     flowtype : str, optional
#         Denotes type for class (e.g. 'energy,' 'material,', 'signal')

# %% [markdown]
# - add_act adds the action to the function and hands it the given flows and parameters. Here the actions are "Percieve", "Act", and "Done"

# %%
help(ASG.add_act)
# Out:
# Help on function add_act in module fmdtools.define.block:
#
# add_act(self, name, actclass, *flownames, duration=0.0, **params)
#     Associate an Action with the Function Block for use in the Action Sequence Graph
#
#     Parameters
#     ----------
#     name : str
#         Internal Name for the Action
#     action : Action
#         Action class to instantiate
#     *flows : flow
#         Flows (optional) which connect the actions
#     **params : any
#         parameters to instantiate the Action with.

# %% [markdown]
# - add_cond specifies the conditions for going from one action to another.

# %%
help(ASG.add_cond)
# Out:
# Help on function add_cond in module fmdtools.define.block:
#
# add_cond(self, start_action, end_action, name='auto', condition='pass')
#     Associates a Condition with the Function Block for use in the Action Sequence Graph
#
#     Parameters
#     ----------
#     start_action : str
#         Action where the condition is checked
#     end_action : str
#         Action that the condition leads to.
#     name : str
#         Name for the condition. Defaults to numbered conditions if none are provided.
#     condition : method
#         Method in the class to use as a condition. Defaults to self.condition_pass if none are provided

# %% [markdown]
# - ASG.build finally constructs the structure of the ASG (see: self.action_graph and self.flow_graph) and determines the settings for the simulation. In DetectHazard, default options are used, with the first action specified as "Percieve" and also with it specified that the actions propagate in the dynamic step (rather than static step)

# %%
help(ASG.build)
# Out:
# Help on function build in module fmdtools.define.block:
#
# build(self)

# %% [markdown]
# - ASG.show can then be used to visualize the graph

# %%
help(ASG.show)
# Out:
# Help on function show in module fmdtools.define.block:
#
# show(self, gtype='combined', with_cond_labels=True, pos=[])
#     Shows a visual representation of the internal Action Sequence Graph of the Function Block
#
#     Parameters
#     ----------
#     gtype : 'combined'/'flows'/'actions'
#         Gives a graphical representation of the ASG. Default is 'combined'
#         - 'actions'     (for function input):    plots the sequence of actions in the function's Action Sequence Graph
#         - 'flows'       (for function input):    plots the action/flow connections in the function's Action Sequence Graph
#         - 'combined'    (for function input):    plots both the sequence of actions in the functions ASG and action/flow connections
#     with_cond_labels: Bool
#         Whether or not to label the conditions
#     pos : dict
#         Dictionary of node positions for actions/flows

# %%
h = Human()
h
# Out:
# c:\users\dhulse\documents\github\fmdtools\fmdtools\define\block.py:60: UserWarning: these flows sent from model ['outcome'] not added to class <class '__main__.Done'>
#   warnings.warn("these flows sent from model "+str([*flows.keys()])+" not added to class "+str(obj.__class__))
# Human(actions={'perceive': perceive Perceive
# - State()
# - ActionMode(mode=nominal, faults=set())
# , 'act': act Act
# - State()
# - ActionMode(mode=nominal, faults=set())
# , 'done': done Done
# - State()
# - Mode(mode=nominal, faults=set())
# }, action_graph=<networkx.classes.digraph.DiGraph object at 0x0000024DB28A42E0>, flow_graph=<networkx.classes.graph.Graph object at 0x0000024DB28A4280>, conditions={'percieved': <bound method Perceive.percieved of perceive Perceive
# - State()
# - ActionMode(mode=nominal, faults=set())
# >, 'acted': <bound method Act.acted of act Act
# - State()
# - ActionMode(mode=nominal, faults=set())
# >, 'ready': <bound method Done.ready of done Done
# - State()
# - Mode(mode=nominal, faults=set())
# >}, faultmodes={'perceive_failed': 'perceive', 'perceive_unable': 'perceive', 'act_failed': 'act', 'act_unable': 'act'}, flows={'hazard': hazard Hazard flow: HazardState(present=False, percieved=False, mitigated=False), 'outcome': outcome Outcome flow: OutcomeStates(num_perceptions=0, num_actions=0)}, active_actions={'perceive'}, pos={'perceive': array([-1.   , -0.375]), 'outcome': array([ 0.875, -0.375]), 'hazard': array([-0.0625,  0.25  ]), 'act': array([ 0.25  , -0.0625]), 'done': array([-0.0625,  0.5625])})

# %%
fig = h.show()

# %% [markdown]
# As shown, the "Percieve" action is active (green), while the inactive actions are shown in blue. This action is active because it was defined as initial_action in the ASG definition.
#
# Below we first instantiate the function to how how it (and the ASG) simulates on its own

# %%
class DetectHazard(FxnBlock):
    _init_a =           Human
    _init_hazard=       Hazard

# %% [markdown]
# If we update the action, we can see the ASG progress between states:

# %%
ex_fxn = DetectHazard('detect_hazard')
ex_fxn.t.dt=1.0

ex_fxn.a.flows['hazard']
# Out:
# hazard Hazard flow: HazardState(present=False, percieved=False, mitigated=False)

# %%
ex_fxn.a.flows['hazard'].s.present=True
ex_fxn('dynamic', time= 1)

# %%
fig = ex_fxn.a.show()

# %%
ex_fxn.a.flows['hazard']
# Out:
# hazard Hazard flow: HazardState(present=True, percieved=True, mitigated=True)

# %%
ex_fxn.a.flows['outcome']
# Out:
# outcome Outcome flow: OutcomeStates(num_perceptions=1, num_actions=1)

# %% [markdown]
# As shown, each of the actions are progressed throuh in a single timestep until the ASG is in the "Done" action

# %%
ex_fxn.a.flows['hazard'].s.present=False
ex_fxn('dynamic', time= 2)

# %%
fig = ex_fxn.a.show()

# %%
ex_fxn.a.flows['outcome']
# Out:
# outcome Outcome flow: OutcomeStates(num_perceptions=1, num_actions=1)

# %%
ex_fxn.a.flows['hazard']
# Out:
# hazard Hazard flow: HazardState(present=False, percieved=False, mitigated=True)

# %% [markdown]
# As shown, now that the hazard is no longer present, the "Ready" Condition is triggered and the ASG goes back to the percieve state.

# %% [markdown]
# Below, this function is placed in the context of a model so we can see how it behaves in the context of a simulation

# %%
class ProduceHazard(FxnBlock):
    __slots__=('hazard',)
    _init_hazard = Hazard
    def dynamic_behavior(self,time):
        if not time%4: self.hazard.s.present=True
        else:          self.hazard.s.present=False
class PassStates(State):
    hazards_mitigated:  int=0
    hazards_propagated: int=0
class PassHazard(FxnBlock):
    __slots__=('hazard',)
    _init_s = PassStates
    _init_hazard = Hazard
    def dynamic_behavior(self,time):
        if self.hazard.s.present and self.hazard.s.mitigated:       self.s.hazards_mitigated+=1
        elif self.hazard.s.present and not self.hazard.s.mitigated: self.s.hazards_propagated+=1

from fmdtools.define.parameter import Parameter
class HazardModel(Model):
    __slots__=()
    default_sp = dict(times=(0,60), dt=1.0)
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.add_flow("hazard", Hazard)
        
        self.add_fxn("produce_hazard", ProduceHazard, 'hazard')
        self.add_fxn("detect_hazard", DetectHazard, 'hazard')
        self.add_fxn("pass_hazard",  PassHazard, 'hazard')
        self.build()

# %%
mdl = HazardModel()
endstate,  mdlhist = prop.nominal(mdl)

# %% [markdown]
# Below we look at the states of the functions/flows to see how this has simulated.

# %%
mdlhist
# Out:
# fxns:
# --produce_hazard:
# ----m:
# ------mode:                    array(61)
# --detect_hazard:
# ----a:
# ------perceive:
# --------m:
# ----------mode:                array(61)
# ------act:
# --------m:
# ----------mode:                array(61)
# ------done:
# --------m:
# ----------mode:                array(61)
# ------active_actions:          array(61)
# ----m:
# ------faults:
# --------perceive_failed:       array(61)
# --------perceive_unable:       array(61)
# --------act_failed:            array(61)
# --------act_unable:            array(61)
# ------mode:                    array(61)
# --pass_hazard:
# ----s:
# ------hazards_mitigated:       array(61)
# ------hazards_propagated:      array(61)
# ----m:
# ------mode:                    array(61)
# flows:
# --hazard:
# ----s:
# ------present:                 array(61)
# ------percieved:               array(61)
# ------mitigated:               array(61)
# time:                          array(61)

# %%
restab = mdlhist.as_table()

# %%
restab
# Out:
#    fxns.produce_hazard.m.mode fxns.detect_hazard.a.perceive.m.mode  \
# 0                     nominal                                False
# 1                     nominal                                False
# 2                     nominal                                False
# 3                     nominal                                False
# 4                     nominal                                False
# ..                        ...                                  ...
# 56                    nominal                                False
# 57                    nominal                                False
# 58                    nominal                                False
# 59                    nominal                                False
# 60                    nominal                                False
#
#    fxns.detect_hazard.a.act.m.mode fxns.detect_hazard.a.done.m.mode  \
# 0                            False                            False
# 1                            False                            False
# 2                            False                            False
# 3                            False                            False
# 4                            False                            False
# ..                             ...                              ...
# 56                           False                            False
# 57                           False                            False
# 58                           False                            False
# 59                           False                            False
# 60                           False                            False
#
#    fxns.detect_hazard.a.active_actions  \
# 0                           {perceive}
# 1                           {perceive}
# 2                           {perceive}
# 3                           {perceive}
# 4                               {done}
# ..                                 ...
# 56                              {done}
# 57                          {perceive}
# 58                          {perceive}
# 59                          {perceive}
# 60                              {done}
#
#     fxns.detect_hazard.m.faults.perceive_failed  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ..                                          ...
# 56                                        False
# 57                                        False
# 58                                        False
# 59                                        False
# 60                                        False
#
#     fxns.detect_hazard.m.faults.perceive_unable  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ..                                          ...
# 56                                        False
# 57                                        False
# 58                                        False
# 59                                        False
# 60                                        False
#
#     fxns.detect_hazard.m.faults.act_failed  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ..                                     ...
# 56                                   False
# 57                                   False
# 58                                   False
# 59                                   False
# 60                                   False
#
#     fxns.detect_hazard.m.faults.act_unable fxns.detect_hazard.m.mode  \
# 0                                    False                   nominal
# 1                                    False                   nominal
# 2                                    False                   nominal
# 3                                    False                   nominal
# 4                                    False                   nominal
# ..                                     ...                       ...
# 56                                   False                   nominal
# 57                                   False                   nominal
# 58                                   False                   nominal
# 59                                   False                   nominal
# 60                                   False                   nominal
#
#     fxns.pass_hazard.s.hazards_mitigated  \
# 0                                      0
# 1                                      0
# 2                                      0
# 3                                      0
# 4                                      1
# ..                                   ...
# 56                                    14
# 57                                    14
# 58                                    14
# 59                                    14
# 60                                    15
#
#     fxns.pass_hazard.s.hazards_propagated fxns.pass_hazard.m.mode  \
# 0                                       0                 nominal
# 1                                       0                 nominal
# 2                                       0                 nominal
# 3                                       0                 nominal
# 4                                       0                 nominal
# ..                                    ...                     ...
# 56                                      0                 nominal
# 57                                      0                 nominal
# 58                                      0                 nominal
# 59                                      0                 nominal
# 60                                      0                 nominal
#
#     flows.hazard.s.present  flows.hazard.s.percieved  \
# 0                    False                     False
# 1                    False                     False
# 2                    False                     False
# 3                    False                     False
# 4                     True                      True
# ..                     ...                       ...
# 56                    True                      True
# 57                   False                     False
# 58                   False                     False
# 59                   False                     False
# 60                    True                      True
#
#     flows.hazard.s.mitigated  time
# 0                      False   0.0
# 1                      False   1.0
# 2                      False   2.0
# 3                      False   3.0
# 4                       True   4.0
# ..                       ...   ...
# 56                      True  56.0
# 57                      True  57.0
# 58                      True  58.0
# 59                      True  59.0
# 60                      True  60.0
#
# [61 rows x 17 columns]

# %% [markdown]
# As shown, the ASG alternates between Perceive (when the hazard is not present) and Done (when the hazard is present)

# %% [markdown]
# As a result, all of the present hazards (above) are also perceived and mitigated.

# %% [markdown]
# And as a result no hazards are propagated.

# %% [markdown]
# Or, in plot form:

# %%
fig, axs = an.plot.mdlhists(mdlhist, fxnflowvals={'fxns':{'detect_hazard':'outcome', 'pass_hazard':'all'}}, figsize=(10,5))
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\1/ipykernel_17804/2676100578.py in <module>
# ----> 1 fig, axs = an.plot.mdlhists(mdlhist, fxnflowvals={'fxns':{'detect_hazard':'outcome', 'pass_hazard':'all'}}, figsize=(10,5))
#
# c:\users\dhulse\documents\github\fmdtools\fmdtools\analyze\plot.py in mdlhists(mdlhists, fxnflowvals, cols, aggregation, comp_groups, legend_loc, xlabel, ylabels, max_ind, boundtype, fillalpha, boundcolor, boundlinestyle, ci, titles, title, indiv_kwargs, time_slice, time_slice_label, figsize, v_padding, h_padding, title_padding, phases, modephases, label_phases, legend_title, **kwargs)
#     134         mdlhists[scen] = mdlhists[scen].cut(max_ind)
#     135     times = mdlhists[[*mdlhists.keys()][0]]['time']
# --> 136     flat_mdlhists = {scen:mdlhist.flatten(to_include=fxnflowvals) for scen, mdlhist in mdlhists.items()}
#     137     #Sort into comparison groups
#     138     if not comp_groups:
#
# c:\users\dhulse\documents\github\fmdtools\fmdtools\analyze\plot.py in <dictcomp>(.0)
#     134         mdlhists[scen] = mdlhists[scen].cut(max_ind)
#     135     times = mdlhists[[*mdlhists.keys()][0]]['time']
# --> 136     flat_mdlhists = {scen:mdlhist.flatten(to_include=fxnflowvals) for scen, mdlhist in mdlhists.items()}
#     137     #Sort into comparison groups
#     138     if not comp_groups:
#
# c:\users\dhulse\documents\github\fmdtools\fmdtools\sim\result.py in flatten(self, newhist, prevname, to_include)
#     308                 new_to_include = get_sub_include(att, to_include)
#     309                 if new_to_include:
# --> 310                     val.flatten(newhist, newname, new_to_include)
#     311             elif to_include in ('all', 'default') or att in to_include:
#     312                 if len(newname)==1: newhist[newname[0]] = val
#
# c:\users\dhulse\documents\github\fmdtools\fmdtools\sim\result.py in flatten(self, newhist, prevname, to_include)
#     308                 new_to_include = get_sub_include(att, to_include)
#     309                 if new_to_include:
# --> 310                     val.flatten(newhist, newname, new_to_include)
#     311             elif to_include in ('all', 'default') or att in to_include:
#     312                 if len(newname)==1: newhist[newname[0]] = val
#
# c:\users\dhulse\documents\github\fmdtools\fmdtools\sim\result.py in flatten(self, newhist, prevname, to_include)
#     302             newhist = self.__class__()
#     303         #TODO: Add some error handling for when the attributes in "to_include" aren't actually in hist
# --> 304         check_include_errors(self, to_include)
#     305         for att, val in self.items():
#     306             newname = prevname+tuple([att])
#
# c:\users\dhulse\documents\github\fmdtools\fmdtools\sim\result.py in check_include_errors(result, to_include)
#     174             check_include_error(result,k)
#     175     else:
# --> 176         check_include_error(result,to_include)
#     177 def check_include_error(result,to_include):
#     178     if to_include not in ('all', 'default') and to_include not in result:
#
# c:\users\dhulse\documents\github\fmdtools\fmdtools\sim\result.py in check_include_error(result, to_include)
#     177 def check_include_error(result,to_include):
#     178     if to_include not in ('all', 'default') and to_include not in result:
# --> 179         raise Exception("to_include key "+to_include+" not in result keys: "+str(result.keys()))
#     180
#     181 def bootstrap_confidence_interval(data, method=np.mean, return_anyway=False, **kwargs):
#
# Exception: to_include key outcome not in result keys: dict_keys(['a', 'm'])

# %% [markdown]
# As shown, perceptions and actions track the hazards mitigated.

# %%
fig, axs = an.plot.mdlhists(mdlhist, fxnflowvals={'flows':{'hazard':'all'},'fxns':{'detect_hazard':{'m'}}, figsize=(10,5))

# %% [markdown]
# And the mode tracks the presence of the hazard.

# %% [markdown]
# ASGs can also be viewed using the `analyze.graph` module. Below we will simulate a fault and see how it tracks in the model.

# %%
resgraph_fault, mdlhist_fault = prop.one_fault(mdl, 'detect_hazard','perceive_failed', time=4, desired_result='bipartite')
# Out:
# c:\users\dhulse\documents\github\fmdtools\fmdtools\define\block.py:60: UserWarning: these flows sent from model ['outcome'] not added to class <class '__main__.Done'>
#   warnings.warn("these flows sent from model "+str([*flows.keys()])+" not added to class "+str(obj.__class__))

# %%
mdlhist_fault.faulty.fxns.detect_hazard.a.act
# Out:
# m:
# --mode:                        array(61)

# %% [markdown]
# As shown, this fault results in the hazard not being perceived (and thus the hazard propagating)

# %%
fig, axs = an.plot.mdlhists(mdlhist_fault, fxnflowvals={'flows':{'hazard':'all'},
                                                        'fxns':{'detect_hazard':{'a':'act'}}}, figsize=(10,5), time_slice=[4])

# %%
fig, axs = an.plot.mdlhists(mdlhist_fault, fxnflowvals={'fxns':{'detect_hazard':'outcome', 
                                                                'pass_hazard':'all'}}, figsize=(10,5), time_slice=[4])
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\1/ipykernel_17804/673485231.py in <module>
# ----> 1 fig, axs = an.plot.mdlhists(mdlhist_fault, fxnflowvals={'fxns':{'detect_hazard':'outcome',
#       2                                                                 'pass_hazard':'all'}}, figsize=(10,5), time_slice=[4])
#
# c:\users\dhulse\documents\github\fmdtools\fmdtools\analyze\plot.py in mdlhists(mdlhists, fxnflowvals, cols, aggregation, comp_groups, legend_loc, xlabel, ylabels, max_ind, boundtype, fillalpha, boundcolor, boundlinestyle, ci, titles, title, indiv_kwargs, time_slice, time_slice_label, figsize, v_padding, h_padding, title_padding, phases, modephases, label_phases, legend_title, **kwargs)
#     134         mdlhists[scen] = mdlhists[scen].cut(max_ind)
#     135     times = mdlhists[[*mdlhists.keys()][0]]['time']
# --> 136     flat_mdlhists = {scen:mdlhist.flatten(to_include=fxnflowvals) for scen, mdlhist in mdlhists.items()}
#     137     #Sort into comparison groups
#     138     if not comp_groups:
#
# c:\users\dhulse\documents\github\fmdtools\fmdtools\analyze\plot.py in <dictcomp>(.0)
#     134         mdlhists[scen] = mdlhists[scen].cut(max_ind)
#     135     times = mdlhists[[*mdlhists.keys()][0]]['time']
# --> 136     flat_mdlhists = {scen:mdlhist.flatten(to_include=fxnflowvals) for scen, mdlhist in mdlhists.items()}
#     137     #Sort into comparison groups
#     138     if not comp_groups:
#
# c:\users\dhulse\documents\github\fmdtools\fmdtools\sim\result.py in flatten(self, newhist, prevname, to_include)
#     308                 new_to_include = get_sub_include(att, to_include)
#     309                 if new_to_include:
# --> 310                     val.flatten(newhist, newname, new_to_include)
#     311             elif to_include in ('all', 'default') or att in to_include:
#     312                 if len(newname)==1: newhist[newname[0]] = val
#
# c:\users\dhulse\documents\github\fmdtools\fmdtools\sim\result.py in flatten(self, newhist, prevname, to_include)
#     308                 new_to_include = get_sub_include(att, to_include)
#     309                 if new_to_include:
# --> 310                     val.flatten(newhist, newname, new_to_include)
#     311             elif to_include in ('all', 'default') or att in to_include:
#     312                 if len(newname)==1: newhist[newname[0]] = val
#
# c:\users\dhulse\documents\github\fmdtools\fmdtools\sim\result.py in flatten(self, newhist, prevname, to_include)
#     302             newhist = self.__class__()
#     303         #TODO: Add some error handling for when the attributes in "to_include" aren't actually in hist
# --> 304         check_include_errors(self, to_include)
#     305         for att, val in self.items():
#     306             newname = prevname+tuple([att])
#
# c:\users\dhulse\documents\github\fmdtools\fmdtools\sim\result.py in check_include_errors(result, to_include)
#     174             check_include_error(result,k)
#     175     else:
# --> 176         check_include_error(result,to_include)
#     177 def check_include_error(result,to_include):
#     178     if to_include not in ('all', 'default') and to_include not in result:
#
# c:\users\dhulse\documents\github\fmdtools\fmdtools\sim\result.py in check_include_error(result, to_include)
#     177 def check_include_error(result,to_include):
#     178     if to_include not in ('all', 'default') and to_include not in result:
# --> 179         raise Exception("to_include key "+to_include+" not in result keys: "+str(result.keys()))
#     180
#     181 def bootstrap_confidence_interval(data, method=np.mean, return_anyway=False, **kwargs):
#
# Exception: to_include key outcome not in result keys: dict_keys(['a', 'm'])

# %% [markdown]
# As shown, this only shows up in the PassHazard function (since the fault is removed in one timestep).

# %%
fig = an.graph.show(resgraph_fault)

# %% [markdown]
# To see this in more detail, we will process the results history and then use `graph.results_from` at the time of the fault.

# %%
reshist = mdlhist_fault.get_degraded_hist(*mdl.fxns, *mdl.flows)
reshist.as_table()
# Out:
#     produce_hazard  detect_hazard  pass_hazard  hazard  total  time
# 0                1              1            1       1      0   0.0
# 1                1              1            1       1      0   1.0
# 2                1              1            1       1      0   2.0
# 3                1              1            1       1      0   3.0
# 4                1              0            0       0      3   4.0
# ..             ...            ...          ...     ...    ...   ...
# 56               1              1            0       1      1  56.0
# 57               1              1            0       1      1  57.0
# 58               1              1            0       1      1  58.0
# 59               1              1            0       1      1  59.0
# 60               1              1            0       1      1  60.0
#
# [61 rows x 6 columns]

# %% [markdown]
# Below shows the state of the model at the given time.

# %%
fig = an.graph.result_from(mdl.bipartite, reshist, 4)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\1/ipykernel_17804/3282239920.py in <module>
# ----> 1 fig = an.graph.result_from(mdl.bipartite, reshist, 4)
#
# c:\users\dhulse\documents\github\fmdtools\fmdtools\analyze\graph.py in result_from(mdl, reshist, time, renderer, gtype, **kwargs)
#     618     elif getattr(mdl,'type', '')=='function':
#     619         g,_, pos, kwargs['seqgraph'], kwargs['arrows'] = get_asg_pos(mdl.a,kwargs.pop('pos',[]), gtype, kwargs.get('arrows',False))
# --> 620     else: raise Exception("Invalid object type: "+str(type(mdl))+" use a model or function instead")
#     621     if renderer=='matplotlib':
#     622         fig  = plt.figure(figsize=kwargs.pop('figsize', (6,4)))
#
# Exception: Invalid object type: <class 'networkx.classes.graph.Graph'> use a model or function instead

# %%
reshist = mdlhist_fault.get_faulty_hist(*mdl.fxns, *mdl.flows)
reshist.as_table()
# Out:
# C:\Users\dhulse\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#     produce_hazard  detect_hazard  pass_hazard  hazard  total  time
# 0            False          False        False   False  False   0.0
# 1            False          False        False   False  False   1.0
# 2            False          False        False   False  False   2.0
# 3            False          False        False   False  False   3.0
# 4            False          False        False   False  False   4.0
# ..             ...            ...          ...     ...    ...   ...
# 56           False          False        False   False  False  56.0
# 57           False          False        False   False  False  57.0
# 58           False          False        False   False  False  58.0
# 59           False          False        False   False  False  59.0
# 60           False          False        False   False  False  60.0
#
# [61 rows x 6 columns]

# %%
reshist['detect_hazard'][4]
# Out:
# False

# %% [markdown]
# We can also use `show` to view the state of the ASG. See below:

# %%
fig = an.graph.result_from(mdl.fxns['detect_hazard'], reshist, 4, gtype='combined')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\1/ipykernel_17804/127455380.py in <module>
# ----> 1 fig = an.graph.result_from(mdl.fxns['detect_hazard'], reshist, 4, gtype='combined')
#
# c:\users\dhulse\documents\github\fmdtools\fmdtools\analyze\graph.py in result_from(mdl, reshist, time, renderer, gtype, **kwargs)
#     618     elif getattr(mdl,'type', '')=='function':
#     619         g,_, pos, kwargs['seqgraph'], kwargs['arrows'] = get_asg_pos(mdl.a,kwargs.pop('pos',[]), gtype, kwargs.get('arrows',False))
# --> 620     else: raise Exception("Invalid object type: "+str(type(mdl))+" use a model or function instead")
#     621     if renderer=='matplotlib':
#     622         fig  = plt.figure(figsize=kwargs.pop('figsize', (6,4)))
#
# Exception: Invalid object type: <class '__main__.DetectHazard'> use a model or function instead

# %% [markdown]
# Note the lack of a fault at this time-step, despite it being instantiated here. This is because the fault was removed at the end of the same time-step it was added in.
#
# The 'unable' fault, on the other hand, stays throughout the simulation and thus shows up:

# %%
endstate_unable, mdlhist_unable = prop.one_fault(mdl, 'detect_hazard','act_unable', time=4)
#reshist_unable, diff_unable, summary_unable = an.process.hist(mdlhist_unable)
fig, axs = an.plot.mdlhists(mdlhist_unable, fxnflowvals={'flows':{'hazard':'all'},
                                                        'fxns':{'detect_hazard':{'a':'act'}}}, 
                            figsize=(10,5), time_slice=[4])

# %%
fig = an.graph.result_from(mdl, reshist_unable, 4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\1/ipykernel_17804/4005224457.py in <module>
# ----> 1 fig = an.graph.result_from(mdl, reshist_unable, 4)
#
# NameError: name 'reshist_unable' is not defined

# %%
fig = an.graph.result_from(mdl.fxns['detect_hazard'], reshist_unable, 4, gtype='combined')

# %%
fig = an.graph.result_from(mdl.fxns['detect_hazard'], reshist_unable, 6, gtype='combined')
