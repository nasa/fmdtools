# %%
import sys
sys.path.append('../../')

import fmdtools.faultsim.propagate as propagate
import fmdtools.resultdisp as rd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import numpy as np
import seaborn as sns; sns.set(style="ticks", color_codes=True)

from drone_mdl import *
import time

# %%
from drone_opt import *

# %% [markdown]
# Example model and parameters:

# %%
params={'start': [0.0,0.0, 10, 10], 'target': [0, 150, 160, 160], 'safe': [0, 50, 10, 10], # areas
        'flightplan':{ 1:[0,0,50], 2:[100, 200, 50], 3:[100, 100, 85], 4:[-25, 150, 20],5:[75, 300, 20],6:[0, 300, 20], 7:[0,0,50], 8:[0,0,0] },
        'landtime': 12,
        'loc':'rural',
        'bat':'series-split',                           #'monolithic', 'series-split', 'paralel-split', 'split-both'
        'linearch':'quad',                              #quad, hex, oct
        'respolicy':{'bat':'emland','line':'emland'}}   #continue, to_home, to_nearest, emland
mdl = Drone(params=params)

# %% [markdown]
# ### Model Overview

# %%
#%matplotlib qt - unnecessary--already set in model
# pos = rd.graph.set_pos(mdl, gtype='bipartite')
# %matplotlib inline

# %%
fig, ax = rd.graph.show(mdl, gtype='bipartite', scale=2.0, retfig=True, title='Multirotor Model Structure')

# %%
fig.savefig('modelstructure.pdf', format="pdf", bbox_inches = 'tight', pad_inches = 0.0)

# %% [markdown]
# ### Design model
#
# The drone model has 4 possible battery architectures: monolithic, series-split, parallel-split, and split-both. Each of these architectures enable some reconfiguration of the battery in case of faults but also add design cost, and (more importantly), weight.
#
# The drone model also has 3 possible line architectures (quadrotor, hexarotor, and octorotor) which increase design resilience but also lead to both increased design cost, weight, and drag.
#
# The cost of a model can be tabulated using `calc_des` in `drone_opt`.

# %%
calc_des(mdl)
# Out:
# 50000

# %% [markdown]
# To get the objective in terms of the design vector $x_{des}$, use `x_to_descost`.

# %%
x_des = [1,0]

# %%
x_to_dcost(x_des)
# Out:
# 50000

# %% [markdown]
# ### Operational model
#
# The drone model has 1 operational variable - the flight height. This variable determines how high the drone flies and thus how detailed of an image it can caputure. Based on this height, a flightplan is determined.

# %% [markdown]
# The operational model models the function of the battery, motors, and trajectory of the craft over time, as shown:

# %%
endresults_nom, resgraph, mdlhist =propagate.nominal(mdl)
rd.plot.mdlhistvals(mdlhist,fxnflowvals={'StoreEE':'soc', 'EE_1':'rate', 'DOFs': 'elev', 'Planpath':['mode', 'pt'], 'Dir1':'power'})

# put a constraint on battery health

# %% [markdown]
# The flightplan generated for this model is shown below. As shown, the drone flies through the arbitrary points set in the flightplan. Optimizing this sequence of points is a difficult problem, so instead we fly through a set pattern to cover the entire viewable area

# %%
plot_nomtraj(mdlhist, params)

# %%
x=[0,0,55,1,1] # height is the third parameter -- 55
mdl = x_to_mdl(x)
endresults_nom, resgraph, mdlhist =propagate.nominal(mdl)

# %%
plot_nomtraj(mdlhist, mdl.params)

# %% [markdown]
# We can then see how this plan covers the space of points to view. As shown, the target area is shown in red and the points viewed are red while the unviewed points are grey.
#
# The drone flies from an initial landing location, flies over the target location, and then flies back. If there is a problem, there is also a designated land point that the drone can also fly to.

# %%
plot_xy(mdlhist, endresults_nom, title='Nominal Flightpath at 55m height', legend=True)

# %% [markdown]
# This flight plan changes depending on operational height, as shown:

# %%
mdl_low = x_to_mdl([1,1,50,1,1])
endresults_low, resgraph, mdlhist_low =propagate.nominal(mdl_low)

# %%
mdl_med = x_to_mdl([1,1,80,1,1])
endresults_med, resgraph, mdlhist_med =propagate.nominal(mdl_med)

# %%
mdl_hi = x_to_mdl([1,1,180,1,1])
endresults_hi, resgraph, mdlhist_hi =propagate.nominal(mdl_hi)

# %%
fig = plot_xys({'50 m':mdlhist_low ,'80 m': mdlhist_med , '180 m': mdlhist_hi}, {'80 m': endresults_med , '50 m':endresults_low , '180 m': endresults_hi}, legend=True, title="Flight Paths at Varying Heights", retfig=True)

# %%
fig.savefig('flightplans.pdf', format="pdf", bbox_inches = 'tight', pad_inches = 0.0)

# %% [markdown]
# The cost of a model is tabulated using `calc_oper` in `drone_opt`, along with the value of constraints:
# - battery max discharge (20%)
# - existence of faults
# - max height (122 m per FAA regulation)

# %%
calc_oper(mdl)
# Out:
# (-115960.60753703168, -36, False, 0)

# %% [markdown]
# This operational cost and constraint values can be optimized in terms of design and operational variables $x_{des}$ and $x_{oper}$ using `x_to_ocost`.

# %%
x_oper = [90]

# %%
x_to_ocost(x_des, x_oper)
# Out:
# (-45073.94672582088, -42, False, 0)

# %% [markdown]
# ### Resilience model
#
# The resilience model has two variables--the battery resilience policy, and the line resilience policy, which each determine how the flight plan changes based on faults detected in the battery and line, respectively.
#
# The resilience cost of a model can be calculated using `calc_res`.

# %%
rescost = calc_res(mdl)

# %%
rescost
# Out:
# 6985910.340596572

# %% [markdown]
# This can be calculated in terms of the design, operational, and variables $x_{des}$, $x_{oper}$, and $x_{res}$ using `x_to_rcost`

# %%
x_res = [0,0]

# %%
rescost = x_to_rcost(x_des, x_oper, x_res)

# %%
rescost
# Out:
# 23431239.033438712

# %% [markdown]
# Table of fault scenanios in urban flight scenario:

# %%
mdl = x_to_mdl([0,0, 30, 0,0], loc='urban')
a,b,c,d = calc_oper(mdl)

# %%
app = SampleApproach(mdl, faults='single-component', phases={'forward'})
endclasses, mdlhists = propagate.approach(mdl, app, staged=True)

# %%
endclasses['ManageHealth falsemasking, t=7.0']
# Out:
# {'rate': 1.1666666666666665e-07,
#  'cost': 1654.8587156669892,
#  'expected cost': 19.306685016114873,
#  'repcost': 1000,
#  'landcost': 0,
#  'safecost': 800,
#  'viewed value': 145.1412843330109,
#  'viewed': {(-80, 70): 0.0010935444016918405,
#   (-80, 80): 0.0010935444016918405,
#   (-80, 90): 0.0010935444016918405,
#   (-80, 100): 0.0011112533346389944,
#   (-80, 110): 0.0011112533346389944,
#   (-80, 120): 0.0011112533346389944,
#   (-80, 130): 0.0011110826548677425,
#   (-80, 140): 0.0011110826548677425,
#   (-80, 150): 0.0011110826548677425,
#   (-80, 160): 0.0011111113263210202,
#   (-80, 170): 0.0011111113263210202,
#   (-80, 180): 0.0011111113263210202,
#   (-80, 190): 0.0011111110532543223,
#   (-80, 200): 0.0011111110532543223,
#   (-80, 210): 0.0011111110532543223,
#   (-80, 220): 0.0011111110969449854,
#   (-80, 230): 0.001111111099129522,
#   (-70, 70): 0.0010935444016918405,
#   (-70, 80): 0.0010935444016918405,
#   (-70, 90): 0.0010935444016918405,
#   (-70, 100): 0.0011112533346389944,
#   (-70, 110): 0.0011112533346389944,
#   (-70, 120): 0.0011112533346389944,
#   (-70, 130): 0.0011110826548677425,
#   (-70, 140): 0.0011110826548677425,
#   (-70, 150): 0.0011110826548677425,
#   (-70, 160): 0.0011111113263210202,
#   (-70, 170): 0.0011111113263210202,
#   (-70, 180): 0.0011111113263210202,
#   (-70, 190): 0.001111111099129522,
#   (-70, 200): 0.001111111099129522,
#   (-70, 210): 0.001111111099129522,
#   (-70, 220): 0.001111111099129522,
#   (-70, 230): 0.001111111099129522,
#   (-60, 70): 0.0010935444016918405,
#   (-60, 80): 0.0010935444016918405,
#   (-60, 90): 0.0010935444016918405,
#   (-60, 100): 0.0011112533346389944,
#   (-60, 110): 0.0011112533346389944,
#   (-60, 120): 0.0011112533346389944,
#   (-60, 130): 0.0011110826548677425,
#   (-60, 140): 0.0011110826548677425,
#   (-60, 150): 0.0011110826548677425,
#   (-60, 160): 0.001111111099129522,
#   (-60, 170): 0.001111111099129522,
#   (-60, 180): 0.001111111099129522,
#   (-60, 190): 0.001111111099129522,
#   (-60, 200): 0.001111111099129522,
#   (-60, 210): 0.001111111099129522,
#   (-60, 220): 0.001111111099129522,
#   (-60, 230): 0.001111111099129522,
#   (-50, 70): 0.0010935444016918405,
#   (-50, 80): 0.0010935444016918405,
#   (-50, 90): 0.0010935444016918405,
#   (-50, 100): 0.0011112533346389944,
#   (-50, 110): 0.0011112533346389944,
#   (-50, 120): 0.001111111099129522,
#   (-50, 130): 0.001111111099129522,
#   (-50, 140): 0.001111111099129522,
#   (-50, 150): 0.001111111099129522,
#   (-50, 160): 0.001111111099129522,
#   (-50, 170): 0.001111111099129522,
#   (-50, 180): 0.001111111099129522,
#   (-50, 190): 0.001111111099129522,
#   (-50, 200): 0.001111111099129522,
#   (-50, 210): 0.001111111099129522,
#   (-50, 220): 0.001111111099129522,
#   (-50, 230): 0.001111111099129522,
#   (-40, 70): 0.0010935444016918405,
#   (-40, 80): 0.001111111099129522,
#   (-40, 90): 0.001111111099129522,
#   (-40, 100): 0.001111111099129522,
#   (-40, 110): 0.001111111099129522,
#   (-40, 120): 0.001111111099129522,
#   (-40, 130): 0.001111111099129522,
#   (-40, 140): 0.001111111099129522,
#   (-40, 150): 0.001111111099129522,
#   (-40, 160): 0.001111111099129522,
#   (-40, 170): 0.001111111099129522,
#   (-40, 180): 0.001111111099129522,
#   (-40, 190): 0.001111111099129522,
#   (-40, 200): 0.001111111099129522,
#   (-40, 210): 0.001111111099129522,
#   (-40, 220): 0.0011111110969449854,
#   (-40, 230): 0.0011111110969449854,
#   (-30, 70): 0.001111111099129522,
#   (-30, 80): 0.001111111099129522,
#   (-30, 90): 0.001111111099129522,
#   (-30, 100): 0.001111111099129522,
#   (-30, 110): 0.001111111099129522,
#   (-30, 120): 0.001111111099129522,
#   (-30, 130): 0.001111111099129522,
#   (-30, 140): 0.001111111099129522,
#   (-30, 150): 0.001111111099129522,
#   (-30, 160): 0.001111111099129522,
#   (-30, 170): 0.001111111099129522,
#   (-30, 180): 0.0011111099609885516,
#   (-30, 190): 0.0011111110532543223,
#   (-30, 200): 0.0011111110532543223,
#   (-30, 210): 0.0011111110532543223,
#   (-30, 220): 0.0011111110969449854,
#   (-30, 230): 0.0011111110969449854,
#   (-20, 70): 0.001111111099129522,
#   (-20, 80): 0.001111111099129522,
#   (-20, 90): 0.001111111099129522,
#   (-20, 100): 0.001111111099129522,
#   (-20, 110): 0.001111111099129522,
#   (-20, 120): 0.001111111099129522,
#   (-20, 130): 0.001111111099129522,
#   (-20, 140): 0.0011110826548677425,
#   (-20, 150): 0.0011110826548677425,
#   (-20, 160): 0.0011111099609885516,
#   (-20, 170): 0.0011111099609885516,
#   (-20, 180): 0.0011111099609885516,
#   (-20, 190): 0.0011111110532543223,
#   (-20, 200): 0.0011111110532543223,
#   (-20, 210): 0.0011111110532543223,
#   (-20, 220): 0.0011111110969449854,
#   (-20, 230): 0.0011111110969449854,
#   (-10, 70): 0.001111111099129522,
#   (-10, 80): 0.001111111099129522,
#   (-10, 90): 0.001111111099129522,
#   (-10, 100): 0.001111111099129522,
#   (-10, 110): 0.0011104003288578647,
#   (-10, 120): 0.0011104003288578647,
#   (-10, 130): 0.0011110826548677425,
#   (-10, 140): 0.0011110826548677425,
#   (-10, 150): 0.0011110826548677425,
#   (-10, 160): 0.0011111099609885516,
#   (-10, 170): 0.0011111099609885516,
#   (-10, 180): 0.0011111099609885516,
#   (-10, 190): 0.0011111110532543223,
#   (-10, 200): 0.0011111110532543223,
#   (-10, 210): 0.0011111110532543223,
#   (-10, 220): 0.0011111110969449854,
#   (-10, 230): 0.0011111110969449854,
#   (0, 70): 0.0010935444016918405,
#   (0, 80): 0.0010935444016918405,
#   (0, 90): 0.0010935444016918405,
#   (0, 100): 0.0011104003288578647,
#   (0, 110): 0.0011104003288578647,
#   (0, 120): 0.0011104003288578647,
#   (0, 130): 0.0011110826548677425,
#   (0, 140): 0.0011110826548677425,
#   (0, 150): 0.0011110826548677425,
#   (0, 160): 0.0011111099609885516,
#   (0, 170): 0.0011111099609885516,
#   (0, 180): 0.0011111099609885516,
#   (0, 190): 0.0011111110532543223,
#   (0, 200): 0.0011111110532543223,
#   (0, 210): 0.0011111110532543223,
#   (0, 220): 0.0011111110969449854,
#   (0, 230): 0.0011111110969449854,
#   (10, 70): 0.0010935444016918405,
#   (10, 80): 0.0010935444016918405,
#   (10, 90): 0.0010935444016918405,
#   (10, 100): 0.0011104003288578647,
#   (10, 110): 0.0011104003288578647,
#   (10, 120): 0.0011104003288578647,
#   (10, 130): 0.0011110826548677425,
#   (10, 140): 0.0011110826548677425,
#   (10, 150): 0.0011110826548677425,
#   (10, 160): 0.0011111099609885516,
#   (10, 170): 0.0011111099609885516,
#   (10, 180): 0.0011111099609885516,
#   (10, 190): 0.0011111110532543223,
#   (10, 200): 0.0011111110532543223,
#   (10, 210): 0.0011111110532543223,
#   (10, 220): 0.0011111110969449854,
#   (10, 230): 0.0011111110969449854,
#   (20, 70): 0.0010935444016918405,
#   (20, 80): 0.0010935444016918405,
#   (20, 90): 0.0010935444016918405,
#   (20, 100): 0.0011104003288578647,
#   (20, 110): 0.0011104003288578647,
#   (20, 120): 0.0011104003288578647,
#   (20, 130): 0.0011110826548677425,
#   (20, 140): 0.0011110826548677425,
#   (20, 150): 0.0011110826548677425,
#   (20, 160): 0.0011111099609885516,
#   (20, 170): 0.0011111099609885516,
#   (20, 180): 0.0011111099609885516,
#   (20, 190): 0.0011111110532543223,
#   (20, 200): 0.0011111110532543223,
#   (20, 210): 0.0011111110532543223,
#   (20, 220): 0.0011111110969449854,
#   (20, 230): 0.0011111110969449854,
#   (30, 70): 0.0010935444016918405,
#   (30, 80): 0.0010935444016918405,
#   (30, 90): 0.0010935444016918405,
#   (30, 100): 0.0011104003288578647,
#   (30, 110): 0.0011104003288578647,
#   (30, 120): 0.0011104003288578647,
#   (30, 130): 0.0011110826548677425,
#   (30, 140): 0.0011110826548677425,
#   (30, 150): 0.0011110826548677425,
#   (30, 160): 0.0011111099609885516,
#   (30, 170): 0.0011111099609885516,
#   (30, 180): 0.0011111099609885516,
#   (30, 190): 0.0011111110532543223,
#   (30, 200): 0.0011111110532543223,
#   (30, 210): 0.0011111110532543223,
#   (30, 220): 0.0011111110969449854,
#   (30, 230): 0.0011111110969449854,
#   (40, 70): 0.0010935444016918405,
#   (40, 80): 0.0010935444016918405,
#   (40, 90): 0.0010935444016918405,
#   (40, 100): 0.0011104003288578647,
#   (40, 110): 0.0011104003288578647,
#   (40, 120): 0.0011104003288578647,
#   (40, 130): 0.0011110826548677425,
#   (40, 140): 0.0011110826548677425,
#   (40, 150): 0.0011110826548677425,
#   (40, 160): 0.0011111099609885516,
#   (40, 170): 0.0011111099609885516,
#   (40, 180): 0.0011111099609885516,
#   (40, 190): 0.0011111110532543223,
#   (40, 200): 0.0011111110532543223,
#   (40, 210): 0.0011111110532543223,
#   (40, 220): 0.0011111110969449854,
#   (40, 230): 0.0011111110969449854,
#   (50, 70): 0.0011146752058159171,
#   (50, 80): 0.0011146752058159171,
#   (50, 90): 0.0011146752058159171,
#   (50, 100): 0.0011104003288578647,
#   (50, 110): 0.0011104003288578647,
#   (50, 120): 0.0011104003288578647,
#   (50, 130): 0.0011111167876760406,
#   (50, 140): 0.0011111167876760406,
#   (50, 150): 0.0011111167876760406,
#   (50, 160): 0.0011111099609885516,
#   (50, 170): 0.0011111099609885516,
#   (50, 180): 0.0011111099609885516,
#   (50, 190): 0.0011111111078676557,
#   (50, 200): 0.0011111111078676557,
#   (50, 210): 0.0011111111078676557,
#   (50, 220): 0.0011111110969449854,
#   (50, 230): 0.0011111110969449854,
#   (60, 70): 0.0011146752058159171,
#   (60, 80): 0.0011146752058159171,
#   (60, 90): 0.0011146752058159171,
#   (60, 100): 0.0011104003288578647,
#   (60, 110): 0.0011104003288578647,
#   (60, 120): 0.0011104003288578647,
#   (60, 130): 0.0011111167876760406,
#   (60, 140): 0.0011111167876760406,
#   (60, 150): 0.0011111167876760406,
#   (60, 160): 0.0011111099609885516,
#   (60, 170): 0.0011111099609885516,
#   (60, 180): 0.0011111099609885516,
#   (60, 190): 0.0011111111078676557,
#   (60, 200): 0.0011111111078676557,
#   (60, 210): 0.0011111111078676557,
#   (60, 220): 0.0011111110969449854,
#   (60, 230): 0.0011111110969449854,
#   (70, 70): 0.0011146752058159171,
#   (70, 80): 0.0011146752058159171,
#   (70, 90): 0.0011146752058159171,
#   (70, 100): 0.0011104003288578647,
#   (70, 110): 0.0011104003288578647,
#   (70, 120): 0.0011104003288578647,
#   (70, 130): 0.0011111167876760406,
#   (70, 140): 0.0011111167876760406,
#   (70, 150): 0.0011111167876760406,
#   (70, 160): 0.0011111099609885516,
#   (70, 170): 0.0011111099609885516,
#   (70, 180): 0.0011111099609885516,
#   (70, 190): 0.0011111111078676557,
#   (70, 200): 0.0011111111078676557,
#   (70, 210): 0.0011111111078676557,
#   (70, 220): 0.0011111110969449854,
#   (70, 230): 0.0011111110969449854,
#   (80, 70): 0.0011146752058159171,
#   (80, 80): 0.0011146752058159171,
#   (80, 90): 0.0011146752058159171,
#   (80, 100): 0.0011104003288578647,
#   (80, 110): 0.0011104003288578647,
#   (80, 120): 0.0011104003288578647,
#   (80, 130): 0.0011111167876760406,
#   (80, 140): 0.0011111167876760406,
#   (80, 150): 0.0011111167876760406,
#   (80, 160): 0.0011111099609885516,
#   (80, 170): 0.0011111099609885516,
#   (80, 180): 0.0011111099609885516,
#   (80, 190): 0.0011111111078676557,
#   (80, 200): 0.0011111111078676557,
#   (80, 210): 0.0011111111078676557,
#   (80, 220): 0.0011111110969449854,
#   (80, 230): 0.0011111110969449854},
#  'landloc': 'nominal',
#  'body strikes': 0,
#  'head strikes': 0,
#  'property restrictions': 0,
#  'severities': {'hazardous': 0.0, 'minor': 1.1666666666666665e-07}}

# %%
simplefmea = rd.tabulate.simplefmea(endclasses)
simplefmea
# Out:
#                                          rate     cost expected cost repcost  \
# ManageHealth falsemasking, t=7.0  1.16667e-07  1654.86       19.3067    1000
# ManageHealth lostfunction, t=7.0  2.33333e-08  1654.86       3.86134    1000
# StoreEE nocharge, t=7.0               2.8e-05  14914.6       41760.9     100
# StoreEE lowcharge, t=7.0              9.8e-05  15461.4        151522     200
# StoreEE S1P1short, t=7.0          1.55556e-05  14914.6       23200.5     100
# StoreEE S1P1degr, t=7.0           1.55556e-05  14914.6       23200.5     100
# StoreEE S1P1break, t=7.0          1.55556e-05  14914.6       23200.5     100
# StoreEE S1P1nocharge, t=7.0           8.4e-05  14914.6        125283     100
# DistEE short, t=7.0               2.33333e-06  15114.6       3526.75     300
# DistEE degr, t=7.0                3.88889e-06  15014.6       5839.02     200
# DistEE break, t=7.0               1.55556e-06  15014.6       2335.61     200
# AffectDOF RFshort, t=7.0          3.11111e-06  15614.6       4857.88     800
# AffectDOF RFopenc, t=7.0          3.11111e-06  15214.6       4733.44     400
# AffectDOF RFctlbreak, t=7.0       6.22222e-06  15114.6       9404.65     300
# AffectDOF RFmechbreak, t=7.0      3.11111e-06  15514.6       4826.77     700
# CtlDOF noctl, t=7.0                   2.8e-06  15814.6       4428.09    1000
# CtlDOF degctl, t=7.0                 1.12e-05  16014.6       17936.4    1200
# Planpath noloc, t=7.0                 2.8e-06  17714.6       4960.09    1200
# Planpath degloc, t=7.0               1.12e-05  17714.6       19840.4    1200
# HoldPayload break, t=7.0          1.55556e-07  16314.6       253.783    1500
# HoldPayload deform, t=7.0         6.22222e-07  16314.6       1015.13    1500
#
#                                  landcost safecost viewed value  \
# ManageHealth falsemasking, t=7.0        0      800      145.141
# ManageHealth lostfunction, t=7.0        0      800      145.141
# StoreEE nocharge, t=7.0             10000     4900      85.3764
# StoreEE lowcharge, t=7.0            10000     5400      138.612
# StoreEE S1P1short, t=7.0            10000     4900      85.3764
# StoreEE S1P1degr, t=7.0             10000     4900      85.3764
# StoreEE S1P1break, t=7.0            10000     4900      85.3764
# StoreEE S1P1nocharge, t=7.0         10000     4900      85.3764
# DistEE short, t=7.0                 10000     4900      85.3764
# DistEE degr, t=7.0                  10000     4900      85.3764
# DistEE break, t=7.0                 10000     4900      85.3764
# AffectDOF RFshort, t=7.0            10000     4900      85.3764
# AffectDOF RFopenc, t=7.0            10000     4900      85.3764
# AffectDOF RFctlbreak, t=7.0         10000     4900      85.3764
# AffectDOF RFmechbreak, t=7.0        10000     4900      85.3764
# CtlDOF noctl, t=7.0                 10000     4900      85.3764
# CtlDOF degctl, t=7.0                10000     4900      85.3764
# Planpath noloc, t=7.0               10000     6600      85.3764
# Planpath degloc, t=7.0              10000     6600      85.3764
# HoldPayload break, t=7.0            10000     4900      85.3764
# HoldPayload deform, t=7.0           10000     4900      85.3764
#
#                                                                              viewed  \
# ManageHealth falsemasking, t=7.0  {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# ManageHealth lostfunction, t=7.0  {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# StoreEE nocharge, t=7.0           {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# StoreEE lowcharge, t=7.0          {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# StoreEE S1P1short, t=7.0          {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# StoreEE S1P1degr, t=7.0           {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# StoreEE S1P1break, t=7.0          {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# StoreEE S1P1nocharge, t=7.0       {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# DistEE short, t=7.0               {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# DistEE degr, t=7.0                {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# DistEE break, t=7.0               {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# AffectDOF RFshort, t=7.0          {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# AffectDOF RFopenc, t=7.0          {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# AffectDOF RFctlbreak, t=7.0       {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# AffectDOF RFmechbreak, t=7.0      {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# CtlDOF noctl, t=7.0               {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# CtlDOF degctl, t=7.0              {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# Planpath noloc, t=7.0             {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# Planpath degloc, t=7.0            {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# HoldPayload break, t=7.0          {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# HoldPayload deform, t=7.0         {(-80, 70): 0.0010935444016918405, (-80, 80): ...
#
#                                          landloc body strikes head strikes  \
# ManageHealth falsemasking, t=7.0         nominal            0            0
# ManageHealth lostfunction, t=7.0         nominal            0            0
# StoreEE nocharge, t=7.0              over target       0.0003       0.0002
# StoreEE lowcharge, t=7.0          outside target       0.0003       0.0002
# StoreEE S1P1short, t=7.0             over target       0.0003       0.0002
# StoreEE S1P1degr, t=7.0              over target       0.0003       0.0002
# StoreEE S1P1break, t=7.0             over target       0.0003       0.0002
# StoreEE S1P1nocharge, t=7.0          over target       0.0003       0.0002
# DistEE short, t=7.0                  over target       0.0003       0.0002
# DistEE degr, t=7.0                   over target       0.0003       0.0002
# DistEE break, t=7.0                  over target       0.0003       0.0002
# AffectDOF RFshort, t=7.0             over target       0.0003       0.0002
# AffectDOF RFopenc, t=7.0             over target       0.0003       0.0002
# AffectDOF RFctlbreak, t=7.0          over target       0.0003       0.0002
# AffectDOF RFmechbreak, t=7.0         over target       0.0003       0.0002
# CtlDOF noctl, t=7.0                  over target       0.0003       0.0002
# CtlDOF degctl, t=7.0                 over target       0.0003       0.0002
# Planpath noloc, t=7.0                over target       0.0003       0.0002
# Planpath degloc, t=7.0               over target       0.0003       0.0002
# HoldPayload break, t=7.0             over target       0.0003       0.0002
# HoldPayload deform, t=7.0            over target       0.0003       0.0002
#
#                                  property restrictions  \
# ManageHealth falsemasking, t=7.0                     0
# ManageHealth lostfunction, t=7.0                     0
# StoreEE nocharge, t=7.0                              1
# StoreEE lowcharge, t=7.0                             1
# StoreEE S1P1short, t=7.0                             1
# StoreEE S1P1degr, t=7.0                              1
# StoreEE S1P1break, t=7.0                             1
# StoreEE S1P1nocharge, t=7.0                          1
# DistEE short, t=7.0                                  1
# DistEE degr, t=7.0                                   1
# DistEE break, t=7.0                                  1
# AffectDOF RFshort, t=7.0                             1
# AffectDOF RFopenc, t=7.0                             1
# AffectDOF RFctlbreak, t=7.0                          1
# AffectDOF RFmechbreak, t=7.0                         1
# CtlDOF noctl, t=7.0                                  1
# CtlDOF degctl, t=7.0                                 1
# Planpath noloc, t=7.0                                1
# Planpath degloc, t=7.0                               1
# HoldPayload break, t=7.0                             1
# HoldPayload deform, t=7.0                            1
#
#                                                                          severities  \
# ManageHealth falsemasking, t=7.0  {'hazardous': 0.0, 'minor': 1.1666666666666665...
# ManageHealth lostfunction, t=7.0  {'hazardous': 0.0, 'minor': 2.3333333333333334...
# StoreEE nocharge, t=7.0           {'hazardous': 2.7986004665499388e-08, 'minor':...
# StoreEE lowcharge, t=7.0          {'hazardous': 9.795101632924785e-08, 'minor': ...
# StoreEE S1P1short, t=7.0          {'hazardous': 1.5547780369721885e-08, 'minor':...
# StoreEE S1P1degr, t=7.0           {'hazardous': 1.5547780369721885e-08, 'minor':...
# StoreEE S1P1break, t=7.0          {'hazardous': 1.5547780369721882e-08, 'minor':...
# StoreEE S1P1nocharge, t=7.0       {'hazardous': 8.395801399649815e-08, 'minor': ...
# DistEE short, t=7.0               {'hazardous': 2.3321670554582825e-09, 'minor':...
# DistEE degr, t=7.0                {'hazardous': 3.886945092430471e-09, 'minor': ...
# DistEE break, t=7.0               {'hazardous': 1.5547780369721887e-09, 'minor':...
# AffectDOF RFshort, t=7.0          {'hazardous': 3.1095560739443775e-09, 'minor':...
# AffectDOF RFopenc, t=7.0          {'hazardous': 3.1095560739443775e-09, 'minor':...
# AffectDOF RFctlbreak, t=7.0       {'hazardous': 6.219112147888755e-09, 'minor': ...
# AffectDOF RFmechbreak, t=7.0      {'hazardous': 3.1095560739443775e-09, 'minor':...
# CtlDOF noctl, t=7.0               {'hazardous': 2.7986004665499393e-09, 'minor':...
# CtlDOF degctl, t=7.0              {'hazardous': 1.1194401866199757e-08, 'minor':...
# Planpath noloc, t=7.0             {'hazardous': 2.7986004665499393e-09, 'minor':...
# Planpath degloc, t=7.0            {'hazardous': 1.1194401866199757e-08, 'minor':...
# HoldPayload break, t=7.0          {'hazardous': 1.554778036972188e-10, 'minor': ...
# HoldPayload deform, t=7.0         {'hazardous': 6.219112147888752e-10, 'minor': ...
#
#                                  unsafe flight time
# ManageHealth falsemasking, t=7.0                  8
# ManageHealth lostfunction, t=7.0                  8
# StoreEE nocharge, t=7.0                           1
# StoreEE lowcharge, t=7.0                          6
# StoreEE S1P1short, t=7.0                          1
# StoreEE S1P1degr, t=7.0                           1
# StoreEE S1P1break, t=7.0                          1
# StoreEE S1P1nocharge, t=7.0                       1
# DistEE short, t=7.0                               1
# DistEE degr, t=7.0                                1
# DistEE break, t=7.0                               1
# AffectDOF RFshort, t=7.0                          1
# AffectDOF RFopenc, t=7.0                          1
# AffectDOF RFctlbreak, t=7.0                       1
# AffectDOF RFmechbreak, t=7.0                      1
# CtlDOF noctl, t=7.0                               1
# CtlDOF degctl, t=7.0                              1
# Planpath noloc, t=7.0                            18
# Planpath degloc, t=7.0                           18
# HoldPayload break, t=7.0                          1
# HoldPayload deform, t=7.0                         1

# %%
scentable = simplefmea[[ 'rate', 'unsafe flight time', 'landloc','cost']]
scentable
# Out:
#                                          rate unsafe flight time  \
# ManageHealth falsemasking, t=7.0  1.16667e-07                  8
# ManageHealth lostfunction, t=7.0  2.33333e-08                  8
# StoreEE nocharge, t=7.0               2.8e-05                  1
# StoreEE lowcharge, t=7.0              9.8e-05                  6
# StoreEE S1P1short, t=7.0          1.55556e-05                  1
# StoreEE S1P1degr, t=7.0           1.55556e-05                  1
# StoreEE S1P1break, t=7.0          1.55556e-05                  1
# StoreEE S1P1nocharge, t=7.0           8.4e-05                  1
# DistEE short, t=7.0               2.33333e-06                  1
# DistEE degr, t=7.0                3.88889e-06                  1
# DistEE break, t=7.0               1.55556e-06                  1
# AffectDOF RFshort, t=7.0          3.11111e-06                  1
# AffectDOF RFopenc, t=7.0          3.11111e-06                  1
# AffectDOF RFctlbreak, t=7.0       6.22222e-06                  1
# AffectDOF RFmechbreak, t=7.0      3.11111e-06                  1
# CtlDOF noctl, t=7.0                   2.8e-06                  1
# CtlDOF degctl, t=7.0                 1.12e-05                  1
# Planpath noloc, t=7.0                 2.8e-06                 18
# Planpath degloc, t=7.0               1.12e-05                 18
# HoldPayload break, t=7.0          1.55556e-07                  1
# HoldPayload deform, t=7.0         6.22222e-07                  1
#
#                                          landloc     cost
# ManageHealth falsemasking, t=7.0         nominal  1654.86
# ManageHealth lostfunction, t=7.0         nominal  1654.86
# StoreEE nocharge, t=7.0              over target  14914.6
# StoreEE lowcharge, t=7.0          outside target  15461.4
# StoreEE S1P1short, t=7.0             over target  14914.6
# StoreEE S1P1degr, t=7.0              over target  14914.6
# StoreEE S1P1break, t=7.0             over target  14914.6
# StoreEE S1P1nocharge, t=7.0          over target  14914.6
# DistEE short, t=7.0                  over target  15114.6
# DistEE degr, t=7.0                   over target  15014.6
# DistEE break, t=7.0                  over target  15014.6
# AffectDOF RFshort, t=7.0             over target  15614.6
# AffectDOF RFopenc, t=7.0             over target  15214.6
# AffectDOF RFctlbreak, t=7.0          over target  15114.6
# AffectDOF RFmechbreak, t=7.0         over target  15514.6
# CtlDOF noctl, t=7.0                  over target  15814.6
# CtlDOF degctl, t=7.0                 over target  16014.6
# Planpath noloc, t=7.0                over target  17714.6
# Planpath degloc, t=7.0               over target  17714.6
# HoldPayload break, t=7.0             over target  16314.6
# HoldPayload deform, t=7.0            over target  16314.6

# %%
print(scentable.to_latex())
# Out:
# \begin{tabular}{lllll}
# \toprule
# {} &         rate & unsafe flight time &         landloc &     cost \\
# \midrule
# ManageHealth falsemasking, t=7.0 &  1.16667e-07 &                  8 &         nominal &  1654.86 \\
# ManageHealth lostfunction, t=7.0 &  2.33333e-08 &                  8 &         nominal &  1654.86 \\
# StoreEE nocharge, t=7.0          &      2.8e-05 &                  1 &     over target &  14914.6 \\
# StoreEE lowcharge, t=7.0         &      9.8e-05 &                  6 &  outside target &  15461.4 \\
# StoreEE S1P1short, t=7.0         &  1.55556e-05 &                  1 &     over target &  14914.6 \\
# StoreEE S1P1degr, t=7.0          &  1.55556e-05 &                  1 &     over target &  14914.6 \\
# StoreEE S1P1break, t=7.0         &  1.55556e-05 &                  1 &     over target &  14914.6 \\
# StoreEE S1P1nocharge, t=7.0      &      8.4e-05 &                  1 &     over target &  14914.6 \\
# DistEE short, t=7.0              &  2.33333e-06 &                  1 &     over target &  15114.6 \\
# DistEE degr, t=7.0               &  3.88889e-06 &                  1 &     over target &  15014.6 \\
# DistEE break, t=7.0              &  1.55556e-06 &                  1 &     over target &  15014.6 \\
# AffectDOF RFshort, t=7.0         &  3.11111e-06 &                  1 &     over target &  15514.6 \\
# AffectDOF RFopenc, t=7.0         &  3.11111e-06 &                  1 &     over target &  15214.6 \\
# AffectDOF RFctlbreak, t=7.0      &  6.22222e-06 &                  1 &     over target &  15114.6 \\
# AffectDOF RFmechbreak, t=7.0     &  3.11111e-06 &                  1 &     over target &  15514.6 \\
# CtlDOF noctl, t=7.0              &      2.8e-06 &                  1 &     over target &  15814.6 \\
# CtlDOF degctl, t=7.0             &     1.12e-05 &                  1 &     over target &  16014.6 \\
# Planpath noloc, t=7.0            &      2.8e-06 &                 18 &     over target &  17714.6 \\
# Planpath degloc, t=7.0           &     1.12e-05 &                 18 &     over target &  17714.6 \\
# HoldPayload break, t=7.0         &  1.55556e-07 &                  1 &     over target &  16314.6 \\
# HoldPayload deform, t=7.0        &  6.22222e-07 &                  1 &     over target &  16314.6 \\
# \bottomrule
# \end{tabular}

# %%
sum(scentable["rate"][0:2]) + sum(scentable["rate"][8:11]) + sum(scentable["rate"][15:])
# Out:
# 3.6695555555555566e-05

# %%
(sum(scentable["cost"][0:2]) + sum(scentable["cost"][8:11]) + sum(scentable["cost"][15:]))/11
# Out:
# 13485.57540876353

# %%
scentable["rate"][15:]
# Out:
# CtlDOF noctl, t=7.0              2.8e-06
# CtlDOF degctl, t=7.0            1.12e-05
# Planpath noloc, t=7.0            2.8e-06
# Planpath degloc, t=7.0          1.12e-05
# HoldPayload break, t=7.0     1.55556e-07
# HoldPayload deform, t=7.0    6.22222e-07
# Name: rate, dtype: object

# %% [markdown]
# The model can also be queried in terms of the entire design vector using `x_to_mdl` and `x_to_cost`:

# %%
x=[0,2,100,1,1]

# %%
mdl = x_to_mdl(x)

# %%
cost, constraints = x_to_cost(x)

# %%
cost
# Out:
# 5431789.247231738

# %%
constraints
# Out:
# (-12, False, 0)

# %% [markdown]
# ### Exploring design trade-offs

# %% [markdown]
# Octocopter performance

# %%
x=[0,2,100,1,1]
mdl = x_to_mdl(x)
endresults,resgraph,mdlhist = propagate.nominal(mdl)

# %%
rd.plot.mdlhistvals(mdlhist, fxnflowvals={'StoreEE':['soc'], 'DOFs':['x', 'y', 'elev']})

# %% [markdown]
# Quadcopter performance

# %%
x=[0,0,100,1,1]
mdl = x_to_mdl(x)
endresults,resgraph,mdlhist = propagate.nominal(mdl)

# %%
rd.plot.mdlhistvals(mdlhist, fxnflowvals={'StoreEE':['soc'], 'DOFs':['x', 'y', 'elev']})

# %% [markdown]
# As shown, over the same flight with the same parameters, the quadcopter has a higher state of charge. Thus, as shown below, it can fly lower, resulting in a longer mission while ending at the same state of charge.

# %%
x=[0,0,30,1,1]
mdl = x_to_mdl(x)
endresults,resgraph,mdlhist = propagate.nominal(mdl)
rd.plot.mdlhistvals(mdlhist, fxnflowvals={'StoreEE':['soc'], 'DOFs':['x', 'y', 'elev']})

# %% [markdown]
# ### Trade-off plotting

# %%
explore_tradoffs(loc='urban', filename='tradeoffs_urban.csv')
# Out:
#      Bat  Rotor  Height  ResPolBat  ResPolRot  desC        operC     resC c1  \
# 0      0      0      10          0          0     0  2.08288e+08  67650.2  1
# 1      0      0      20          0          0     0 -4.59432e+06  66718.6  1
# 2      0      0      30          0          0     0 -1.45141e+07  65786.3  0
# 3      0      0      40          0          0     0 -1.44861e+07  33339.4  0
# 4      0      0      50          0          0     0 -1.44731e+07    33085  0
# 5      0      0      60          0          0     0 -1.44661e+07  29915.5  0
# 6      0      0      70          0          0     0 -1.44618e+07  29705.9  0
# 7      0      0      80          0          0     0  -1.4459e+07  23289.5  0
# 8      0      0      90          0          0     0 -1.44571e+07  23200.1  0
# 9      0      0     100          0          0     0 -1.44558e+07  23110.7  0
# 10     0      0     110          0          0     0 -1.44548e+07  23015.9  0
# 11     0      0     120          0          0     0  -1.4454e+07  22931.7  0
# 12     0      1      10          0          0  1000  2.10044e+08    69542  1
# 13     0      1      20          0          0  1000  2.03406e+08    68668  1
# 14     0      1      30          0          0  1000 -4.01413e+06  67726.5  1
# 15     0      1      40          0          0  1000 -1.44861e+07  48494.1  0
# 16     0      1      50          0          0  1000 -1.44731e+07  48100.4  0
# 17     0      1      60          0          0  1000 -1.44661e+07  43502.5  0
# 18     0      1      70          0          0  1000 -1.44618e+07  43282.8  0
# 547    3      0      80          3          3   600  -1.4459e+07  95739.5  0
# 548    3      0      90          3          3   600 -1.44571e+07  95441.8  0
# 549    3      0     100          3          3   600 -1.44558e+07  95144.2  0
# 550    3      0     110          3          3   600 -1.44548e+07    94829  0
# 551    3      0     120          3          3   600  -1.4454e+07  94548.8  0
# 552    3      1      10          3          3  1600  2.70428e+08   194880  1
# 553    3      1      20          3          3  1600  2.64623e+08   193126  1
# 554    3      1      30          3          3  1600  6.64859e+07   191330  1
# 555    3      1      40          3          3  1600 -1.44861e+07   137346  0
# 556    3      1      50          3          3  1600 -1.44731e+07   136487  0
# 557    3      1      60          3          3  1600 -1.44661e+07   123411  0
# 558    3      1      70          3          3  1600 -1.44618e+07   122705  0
# 559    3      1      80          3          3  1600  -1.4459e+07  96263.3  0
# 560    3      1      90          3          3  1600 -1.44571e+07  95962.4  0
# 561    3      1     100          3          3  1600 -1.44558e+07  95661.4  0
# 562    3      1     110          3          3  1600 -1.44548e+07  95347.3  0
# 563    3      1     120          3          3  1600  -1.4454e+07    95064  0
# 564    3      2      10          3          3  2600  2.72092e+08   196490  1
# 565    3      2      20          3          3  2600  2.67754e+08   194718  1
# 566    3      2      30          3          3  2600  2.63639e+08   192906  1
# 567    3      2      40          3          3  2600  6.60139e+07   191059  1
# 568    3      2      50          3          3  2600  6.60269e+07   189236  1
# 569    3      2      60          3          3  2600  2.55339e+07   122267  1
# 570    3      2      70          3          3  2600  2.55382e+07   121553  1
# 571    3      2      80          3          3  2600  -1.4459e+07  97058.5  0
# 572    3      2      90          3          3  2600 -1.44571e+07  96754.3  0
# 573    3      2     100          3          3  2600 -1.44558e+07    96450  0
# 574    3      2     110          3          3  2600 -1.44548e+07  96127.8  0
# 575    3      2     120          3          3  2600  -1.4454e+07  95841.4  0
#
#     c2 c3 c_cum
# 0    1  0     1
# 1    1  0     1
# 2    0  0     0
# 3    0  0     0
# 4    0  0     0
# 5    0  0     0
# 6    0  0     0
# 7    0  0     0
# 8    0  0     0
# 9    0  0     0
# 10   0  1     1
# 11   0  1     1
# 12   1  0     1
# 13   1  0     1
# 14   1  0     1
# 15   0  0     0
# 16   0  0     0
# 17   0  0     0
# 18   0  0     0
# 19   0  0     0
# 20   0  0     0
# 21   0  0     0
# 22   0  1     1
# 23   0  1     1
# 24   1  0     1
# 25   1  0     1
# 26   1  0     1
# 27   1  0     1
# 28   1  0     1
# 29   1  0     1
# 30   1  0     1
# 31   0  0     0
# 32   0  0     0
# 33   0  0     0
# 34   0  1     1
# 35   0  1     1
# 36   1  0     1
# 37   1  0     1
# 38   0  0     0
# 39   0  0     0
# 40   0  0     0
# 41   0  0     0
# 42   0  0     0
# 43   0  0     0
# 44   0  0     0
# 45   0  0     0
# 46   0  1     1
# 47   0  1     1
# 48   1  0     1
# 49   1  0     1
# 50   1  0     1
# 51   0  0     0
# 52   0  0     0
# 53   0  0     0
# 54   0  0     0
# 55   0  0     0
# 56   0  0     0
# 57   0  0     0
# 58   0  1     1
# 59   0  1     1
# 60   1  0     1
# 61   1  0     1
# 523  0  0     0
# 524  0  0     0
# 525  0  0     0
# 526  0  1     1
# 527  0  1     1
# 528  1  0     1
# 529  1  0     1
# 530  1  0     1
# 531  1  0     1
# 532  1  0     1
# 533  1  0     1
# 534  1  0     1
# 535  0  0     0
# 536  0  0     0
# 537  0  0     0
# 538  0  1     1
# 539  0  1     1
# 540  1  0     1
# 541  1  0     1
# 542  0  0     0
# 543  0  0     0
# 544  0  0     0
# 545  0  0     0
# 546  0  0     0
# 547  0  0     0
# 548  0  0     0
# 549  0  0     0
# 550  0  1     1
# 551  0  1     1
# 552  1  0     1
# 553  1  0     1
# 554  1  0     1
# 555  0  0     0
# 556  0  0     0
# 557  0  0     0
# 558  0  0     0
# 559  0  0     0
# 560  0  0     0
# 561  0  0     0
# 562  0  1     1
# 563  0  1     1
# 564  1  0     1
# 565  1  0     1
# 566  1  0     1
# 567  1  0     1
# 568  1  0     1
# 569  1  0     1
# 570  1  0     1
# 571  0  0     0
# 572  0  0     0
# 573  0  0     0
# 574  0  1     1
# 575  0  1     1

# %%
# Read the dataset of cost model values and constraint validation for a large grid of design variables
grid_results= pd.read_csv('tradeoffs_urban.csv')
#print(grid_results.head())
#print(grid_results.shape)

# Portion of feasible data among the whole dataset
feasible_DS =(grid_results['c_cum'].isin([0]).sum())/len(grid_results)
#print("The portion of feasible design space from the grid results")
#print(feasible_DS)

#Subsetting only feasible data
grid_results_FS = grid_results[(grid_results['c_cum']==0)]
g = sns.pairplot(grid_results_FS, hue="ResPolBat", vars=["Bat", "Rotor","Height","desC","operC","resC"], corner=True, diag_kind="kde",kind="reg")
g.fig.suptitle("Exploration of Design Variables", y=1.08)
# Out:
# Text(0.5, 1.08, 'Exploration of Design Variables')

# %%
g.fig.savefig('tradeoffs.pdf', format="pdf", bbox_inches = 'tight', pad_inches = 0.0)

# %% [markdown]
# ### Optimization/plotting

# %% [markdown]
# ### all-in-one search and pareto plotting

# %% [markdown]
# brute-force search of the space:

# %%
results, opthist_rural, evals, ftime = brute_search(loc='rural')

resultstab = pd.DataFrame(results)
resultstab.columns = resultstab.columns.to_flat_index()
resultstab.to_csv('fullspace_rural.csv')

# %%
opthist_rural
# Out:
# [[208356162.25674683, (0, 0, 10, 0, 0)],
#  [11703625.676818116, (0, 0, 10, 1, 0)],
#  [-4527571.1886717295, (0, 0, 20, 0, 0)],
#  [-4551902.051531776, (0, 0, 20, 1, 0)],
#  [-14448311.015062585, (0, 0, 30, 0, 0)],
#  [-14450750.126173697, (0, 0, 30, 0, 2)],
#  [-14470291.195490409, (0, 0, 30, 1, 0)],
#  [-14472730.30660152, (0, 0, 30, 1, 2)],
#  [-14474925.50660152, (0, 0, 30, 2, 2)],
#  [-14482154.33649224, (1, 0, 30, 1, 0)],
#  [-14484593.447603352, (1, 0, 30, 1, 2)],
#  [-14486945.447603352, (2, 0, 30, 1, 0)],
#  [-14489384.558714462, (2, 0, 30, 1, 2)]]

# %%
results, opthist_urban, evals, ftime = brute_search(loc='urban')

resultstab = pd.DataFrame(results)
resultstab.columns = resultstab.columns.to_flat_index()
resultstab.to_csv('fullspace_urban.csv')

# %%
opthist_urban

# %%
results, opthist_conj, evals, ftime = brute_search(loc='congested')

resultstab = pd.DataFrame(results)
resultstab.columns = resultstab.columns.to_flat_index()
resultstab.to_csv('fullspace_congested.csv')

# %%
opthist_conj
# Out:
# [[747640088791.3457, (0, 0, 10, 0, 0)],
#  [248657341.12404034, (0, 0, 10, 1, 0)],
#  [226109364.96021724, (0, 0, 20, 0, 0)],
#  [132893282.29735714, (0, 0, 20, 1, 0)],
#  [123091132.63339847, (0, 0, 30, 1, 0)],
#  [113797621.52228734, (0, 0, 30, 1, 2)],
#  [113680245.52228734, (0, 0, 30, 2, 2)],
#  [98028403.9145577, (0, 0, 40, 0, 0)],
#  [91390181.69233549, (0, 0, 40, 0, 1)],
#  [83805543.329671, (0, 0, 40, 1, 0)],
#  [77167321.10744879, (0, 0, 40, 1, 1)],
#  [77083481.10744879, (0, 0, 40, 2, 1)],
#  [73996295.2125157, (0, 0, 60, 1, 0)],
#  [68021895.2125157, (0, 0, 60, 1, 1)],
#  [67946439.2125157, (0, 0, 60, 2, 1)],
#  [64291985.21906077, (0, 0, 80, 0, 0)],
#  [59645229.663505204, (0, 0, 80, 0, 1)],
#  [54345779.73064158, (0, 0, 80, 1, 0)],
#  [49699024.17508603, (0, 0, 80, 1, 1)],
#  [49640336.17508603, (0, 0, 80, 2, 1)],
#  [48367152.05356437, (0, 0, 110, 0, 1)],
#  [48271144.35919015, (0, 0, 110, 1, 1)],
#  [34283602.15906332, (1, 0, 30, 1, 0)],
#  [24990091.047952205, (1, 0, 30, 1, 2)],
#  [22417120.886743832, (1, 0, 40, 1, 0)],
#  [15778898.664521609, (1, 0, 40, 1, 1)],
#  [12772308.055813292, (1, 0, 60, 1, 1)],
#  [10899709.065384816, (1, 0, 80, 0, 1)],
#  [6727177.237477407, (1, 0, 80, 1, 1)],
#  [5348735.11913619, (1, 0, 110, 0, 1)],
#  [5299127.647171466, (1, 0, 110, 1, 1)],
#  [5295892.091615906, (2, 0, 110, 1, 1)]]

# %% [markdown]
# load search results:

# %%
resultstab_rural = pd.read_csv('fullspace_rural.csv')
resultstab_rural = resultstab_rural.drop(labels='Unnamed: 0', axis=1)
resultstab_rural
# Out:
#    (0, 0, 30, 0, 0)  (0, 0, 30, 0, 1)  (0, 0, 30, 0, 2)  (0, 0, 30, 0, 3)  \
# 0      0.000000e+00      0.000000e+00      0.000000e+00      0.000000e+00
# 1     -1.451413e+07     -1.451413e+07     -1.451413e+07     -1.451413e+07
# 2      6.581742e+04      6.581742e+04      6.337831e+04      6.581742e+04
# 3      7.938000e+03      7.938000e+03      7.938000e+03      7.938000e+03
# 4      3.087778e+04      3.087778e+04      2.963333e+04      3.087778e+04
# 5      3.016162e+04      3.016162e+04      2.896695e+04      3.016162e+04
# 6     -3.159975e+03     -3.159975e+03     -3.159975e+03     -3.159975e+03
#
#    (0, 0, 30, 1, 0)  (0, 0, 30, 1, 1)  (0, 0, 30, 1, 2)  (0, 0, 30, 1, 3)  \
# 0      0.000000e+00      0.000000e+00      0.000000e+00      0.000000e+00
# 1     -1.451413e+07     -1.451413e+07     -1.451413e+07     -1.451413e+07
# 2      4.383724e+04      4.383724e+04      4.139813e+04      4.383724e+04
# 3      7.938000e+03      7.938000e+03      7.938000e+03      7.938000e+03
# 4      1.952222e+04      1.952222e+04      1.827778e+04      1.952222e+04
# 5      1.901528e+04      1.901528e+04      1.782062e+04      1.901528e+04
# 6     -2.638267e+03     -2.638267e+03     -2.638267e+03     -2.638267e+03
#
#    (0, 0, 30, 2, 0)  (0, 0, 30, 2, 1)  ...  (3, 2, 100, 1, 2)  \
# 0      0.000000e+00      0.000000e+00  ...       2.600000e+03
# 1     -1.451413e+07     -1.451413e+07  ...      -1.445578e+07
# 2      4.164204e+04      4.164204e+04  ...       3.235298e+04
# 3      7.938000e+03      7.938000e+03  ...       2.857867e+04
# 4      1.840222e+04      1.840222e+04  ...       3.538889e+03
# 5      1.794008e+04      1.794008e+04  ...       3.604557e+03
# 6     -2.638267e+03     -2.638267e+03  ...      -3.369129e+03
#
#    (3, 2, 100, 1, 3)  (3, 2, 100, 2, 0)  (3, 2, 100, 2, 1)  (3, 2, 100, 2, 2)  \
# 0       2.600000e+03       2.600000e+03       2.600000e+03       2.600000e+03
# 1      -1.445578e+07      -1.445578e+07      -1.445578e+07      -1.445578e+07
# 2       3.479832e+04       3.481786e+04       3.235298e+04       3.235298e+04
# 3       2.857867e+04       2.857867e+04       2.857867e+04       2.857867e+04
# 4       4.783333e+03       4.783333e+03       3.538889e+03       3.538889e+03
# 5       4.805446e+03       4.850557e+03       3.604557e+03       3.604557e+03
# 6      -3.369129e+03      -3.394699e+03      -3.369129e+03      -3.369129e+03
#
#    (3, 2, 100, 2, 3)  (3, 2, 100, 3, 0)  (3, 2, 100, 3, 1)  (3, 2, 100, 3, 2)  \
# 0       2.600000e+03       2.600000e+03       2.600000e+03       2.600000e+03
# 1      -1.445578e+07      -1.445578e+07      -1.445578e+07      -1.445578e+07
# 2       3.479832e+04       9.659402e+04       9.412915e+04       9.412915e+04
# 3       2.857867e+04       2.857867e+04       2.857867e+04       2.857867e+04
# 4       4.783333e+03       3.581667e+04       3.457222e+04       3.457222e+04
# 5       4.805446e+03       3.559339e+04       3.434739e+04       3.434739e+04
# 6      -3.369129e+03      -3.394699e+03      -3.369129e+03      -3.369129e+03
#
#    (3, 2, 100, 3, 3)
# 0       2.600000e+03
# 1      -1.445578e+07
# 2       9.657448e+04
# 3       2.857867e+04
# 4       3.581667e+04
# 5       3.554828e+04
# 6      -3.369129e+03
#
# [7 rows x 1152 columns]

# %% [markdown]
# Construct pareto front of design, operational, and resilience costs:

# %%
pareto3 = get_3dpareto(resultstab_rural, 0,1,2)

# %%
fig, ax = plot_pareto3(pareto3)

# %%
ax.set_xlabel('$C_D$ (\$)')
ax.set_ylabel('$C_R$ (\$)')
ax.set_zlabel('$C_O$ (\$)')
ax.xaxis.labelpad=10
ax.yaxis.labelpad=10
ax.zaxis.labelpad=10
ax.dist = 12
#ax.set_title('Pareto Front in Rural Scenario')
ax.legend_.remove()
fig

# %%
fig.savefig('pareto_dorcosts_rural.pdf', format="pdf", bbox_inches = 'tight', pad_inches = 0.0)

# %%
resultstab_urban = pd.read_csv('fullspace_urban.csv')
resultstab_urban = resultstab_urban.drop(labels='Unnamed: 0', axis=1)
resultstab_urban
# Out:
#    (0, 0, 30, 0, 0)  (0, 0, 30, 0, 1)  (0, 0, 30, 0, 2)  (0, 0, 30, 0, 3)  \
# 0      0.000000e+00      0.000000e+00      0.000000e+00      0.000000e+00
# 1     -1.451413e+07     -1.451413e+07     -1.451413e+07     -1.451413e+07
# 2      4.721481e+05      4.721481e+05      4.537303e+05      4.721481e+05
# 3      7.938000e+03      7.938000e+03      7.938000e+03      7.938000e+03
# 4      3.087778e+05      3.087778e+05      2.963333e+05      3.087778e+05
# 5      1.585923e+05      1.585923e+05      1.526190e+05      1.585923e+05
# 6     -3.159975e+03     -3.159975e+03     -3.159975e+03     -3.159975e+03
#
#    (0, 0, 30, 1, 0)  (0, 0, 30, 1, 1)  (0, 0, 30, 1, 2)  (0, 0, 30, 1, 3)  \
# 0      0.000000e+00      0.000000e+00      0.000000e+00      0.000000e+00
# 1     -1.451413e+07     -1.451413e+07     -1.451413e+07     -1.451413e+07
# 2      2.997076e+05      2.997076e+05      2.812898e+05      2.997076e+05
# 3      7.938000e+03      7.938000e+03      7.938000e+03      7.938000e+03
# 4      1.952222e+05      1.952222e+05      1.827778e+05      1.952222e+05
# 5      9.918564e+04      9.918564e+04      9.321231e+04      9.918564e+04
# 6     -2.638267e+03     -2.638267e+03     -2.638267e+03     -2.638267e+03
#
#    (0, 0, 30, 2, 0)  (0, 0, 30, 2, 1)  ...  (3, 2, 100, 1, 2)  \
# 0      0.000000e+00      0.000000e+00  ...       2.600000e+03
# 1     -1.451413e+07     -1.451413e+07  ...      -1.445578e+07
# 2      2.831316e+05      2.831316e+05  ...       8.172956e+04
# 3      7.938000e+03      7.938000e+03  ...       2.857867e+04
# 4      1.840222e+05      1.840222e+05  ...       3.538889e+04
# 5      9.380964e+04      9.380964e+04  ...       2.113113e+04
# 6     -2.638267e+03     -2.638267e+03  ...      -3.369129e+03
#
#    (3, 2, 100, 1, 3)  (3, 2, 100, 2, 0)  (3, 2, 100, 2, 1)  (3, 2, 100, 2, 2)  \
# 0       2.600000e+03       2.600000e+03       2.600000e+03       2.600000e+03
# 1      -1.445578e+07      -1.445578e+07      -1.445578e+07      -1.445578e+07
# 2       1.002718e+05       1.011484e+05       8.172956e+04       8.172956e+04
# 3       2.857867e+04       2.857867e+04       2.857867e+04       2.857867e+04
# 4       4.783333e+04       4.783333e+04       3.538889e+04       3.538889e+04
# 5       2.722891e+04       2.813113e+04       2.113113e+04       2.113113e+04
# 6      -3.369129e+03      -3.394699e+03      -3.369129e+03      -3.369129e+03
#
#    (3, 2, 100, 2, 3)  (3, 2, 100, 3, 0)  (3, 2, 100, 3, 1)  (3, 2, 100, 3, 2)  \
# 0       2.600000e+03       2.600000e+03       2.600000e+03       2.600000e+03
# 1      -1.445578e+07      -1.445578e+07      -1.445578e+07      -1.445578e+07
# 2       1.002718e+05       5.794584e+05       5.600396e+05       5.600396e+05
# 3       2.857867e+04       2.857867e+04       2.857867e+04       2.857867e+04
# 4       4.783333e+04       3.581667e+05       3.457222e+05       3.457222e+05
# 5       2.722891e+04       1.961078e+05       1.891078e+05       1.891078e+05
# 6      -3.369129e+03      -3.394699e+03      -3.369129e+03      -3.369129e+03
#
#    (3, 2, 100, 3, 3)
# 0       2.600000e+03
# 1      -1.445578e+07
# 2       5.785818e+05
# 3       2.857867e+04
# 4       3.581667e+05
# 5       1.952056e+05
# 6      -3.369129e+03
#
# [7 rows x 1152 columns]

# %%
pareto3_urban = get_3dpareto(resultstab_urban, 0,1,2)

# %%
fig, ax = plot_pareto3(pareto3_urban)
ax.set_xlabel('$C_D$ (\$)')
ax.set_ylabel('$C_R$ (\$)')
ax.set_zlabel('$C_O$ (\$)')
ax.xaxis.labelpad=10
ax.yaxis.labelpad=10
ax.zaxis.labelpad=10
ax.dist = 12
#ax.set_title('Pareto Front in Urban Scenario')
ax.legend_.remove()
#fig.subplots_adjust(top=1, bottom=-0.2, left=-0.2, right=0.9)
fig

# %%
fig.savefig('pareto_dorcosts_urban.pdf', format="pdf", bbox_inches = 'tight', pad_inches = 0.0)

# %%
resultstab_congested = pd.read_csv('fullspace_congested.csv')
resultstab_congested = resultstab_congested .drop(labels='Unnamed: 0', axis=1)
resultstab_congested
# Out:
#    (0, 0, 30, 0, 0)  (0, 0, 30, 0, 1)  (0, 0, 30, 0, 2)  (0, 0, 30, 0, 3)  \
# 0      0.000000e+00      0.000000e+00      0.000000e+00      0.000000e+00
# 1     -1.451413e+07     -1.451413e+07     -1.451413e+07     -1.451413e+07
# 2      1.585445e+08      1.585445e+08      1.492509e+08      1.585445e+08
# 3      7.938000e+03      7.938000e+03      7.938000e+03      7.938000e+03
# 4      3.087778e+06      3.087778e+06      2.963333e+06      3.087778e+06
# 5      1.554519e+08      1.554519e+08      1.462828e+08      1.554519e+08
# 6     -3.159975e+03     -3.159975e+03     -3.159975e+03     -3.159975e+03
#
#    (0, 0, 30, 1, 0)  (0, 0, 30, 1, 1)  (0, 0, 30, 1, 2)  (0, 0, 30, 1, 3)  \
# 0      0.000000e+00      0.000000e+00      0.000000e+00      0.000000e+00
# 1     -1.451413e+07     -1.451413e+07     -1.451413e+07     -1.451413e+07
# 2      1.376053e+08      1.376053e+08      1.283117e+08      1.376053e+08
# 3      7.938000e+03      7.938000e+03      7.938000e+03      7.938000e+03
# 4      1.952222e+06      1.952222e+06      1.827778e+06      1.952222e+06
# 5      1.356477e+08      1.356477e+08      1.264787e+08      1.356477e+08
# 6     -2.638267e+03     -2.638267e+03     -2.638267e+03     -2.638267e+03
#
#    (0, 0, 30, 2, 0)  (0, 0, 30, 2, 1)  ...  (3, 2, 100, 1, 2)  \
# 0      0.000000e+00      0.000000e+00  ...       2.600000e+03
# 1     -1.451413e+07     -1.451413e+07  ...      -1.445578e+07
# 2      1.374879e+08      1.374879e+08  ...       2.093995e+07
# 3      7.938000e+03      7.938000e+03  ...       2.857867e+04
# 4      1.840222e+06      1.840222e+06  ...       3.538889e+05
# 5      1.356424e+08      1.356424e+08  ...       2.056085e+07
# 6     -2.638267e+03     -2.638267e+03  ...      -3.369129e+03
#
#    (3, 2, 100, 1, 3)  (3, 2, 100, 2, 0)  (3, 2, 100, 2, 1)  (3, 2, 100, 2, 2)  \
# 0       2.600000e+03       2.600000e+03       2.600000e+03       2.600000e+03
# 1      -1.445578e+07      -1.445578e+07      -1.445578e+07      -1.445578e+07
# 2       3.023471e+07       3.436710e+07       2.506334e+07       2.506334e+07
# 3       2.857867e+04       2.857867e+04       2.857867e+04       2.857867e+04
# 4       4.783333e+05       4.783333e+05       3.538889e+05       3.538889e+05
# 5       2.973116e+07       3.386358e+07       2.468424e+07       2.468424e+07
# 6      -3.369129e+03      -3.394699e+03      -3.369129e+03      -3.369129e+03
#
#    (3, 2, 100, 2, 3)  (3, 2, 100, 3, 0)  (3, 2, 100, 3, 1)  (3, 2, 100, 3, 2)  \
# 0       2.600000e+03       2.600000e+03       2.600000e+03       2.600000e+03
# 1      -1.445578e+07      -1.445578e+07      -1.445578e+07      -1.445578e+07
# 2       3.435810e+07       2.677459e+08       2.584422e+08       2.584422e+08
# 3       2.857867e+04       2.857867e+04       2.857867e+04       2.857867e+04
# 4       4.783333e+05       3.581667e+06       3.457222e+06       3.457222e+06
# 5       3.385456e+07       2.641391e+08       2.549597e+08       2.549597e+08
# 6      -3.369129e+03      -3.394699e+03      -3.369129e+03      -3.369129e+03
#
#    (3, 2, 100, 3, 3)
# 0       2.600000e+03
# 1      -1.445578e+07
# 2       2.677369e+08
# 3       2.857867e+04
# 4       3.581667e+06
# 5       2.641301e+08
# 6      -3.369129e+03
#
# [7 rows x 1152 columns]

# %%
pareto3_congested = get_3dpareto(resultstab_congested, 0,1,2)

# %%
fig, ax = plot_pareto3(pareto3_congested)
ax.set_xlabel('$C_D$ (\$)')
ax.set_ylabel('$C_R$ (\$)')
ax.set_zlabel('$C_O$ (\$)')
ax.xaxis.labelpad=10
ax.yaxis.labelpad=10
ax.zaxis.labelpad=10
ax.dist = 12
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, ['Equal-weight design'], loc='upper center')
#ax.set_title('Pareto Front in Congested Scenario')
fig

# %%
fig.savefig('pareto_dorcosts_congested.pdf', format="pdf", bbox_inches = 'tight', pad_inches = 0.0)

# %% [markdown]
# Construct pareto front of Repair, Landing, and Flight Costs

# %%
resilcosts = resultstab_urban[3:5]
flightcosts = resultstab_urban[5:7].sum()
resilcosts = resilcosts.append(flightcosts, ignore_index=True)

pareto3_resilience = get_3dpareto(resilcosts, 0,1,2)

# %%
fig, ax = plot_pareto3(pareto3_resilience)
ax.set_xlabel('Repair Cost')
ax.set_ylabel('Landing Cost')
ax.set_zlabel('Flight Cost')
ax.set_title('Resilience Pareto Front in Urban Scenario')
# Out:
# Text(0.5, 0.92, 'Resilience Pareto Front in Urban Scenario')

# %%
fig.savefig('pareto_resilcosts.pdf', format="pdf", bbox_inches = 'tight', pad_inches = 0.0)

# %% [markdown]
# ### Comparison of Optimization Architectures

# %%
comparison_tab = pd.DataFrame(columns=['Approach', 'X_opt', 'Total Cost', 'D/O Cost', 'Res. Cost', 'D/O Evals', 'Res. Evals', 'Comp. Time'])
comparison_tab
# Out:
# Empty DataFrame
# Columns: [Approach, X_opt, Total Cost, D/O Cost, Res. Cost, D/O Evals, Res. Evals, Comp. Time]
# Index: []

# %% [markdown]
# All-in-one Approach:

# %%
results, opt_hist, num_evals, runtime = brute_search(loc = 'urban')

# %%
x_to_cost([2,0,40,1,1], loc='urban')
#so, need to fix the bilevel frameworks--the AAO is getting to the true min while they are not
# Out:
# (-14401412.002145058, (-28, False, 0))

# %%
aao_values = {'Approach':'All-in-one'}
aao_values['X_opt'] = opt_hist[-1][1]
aao_values['Total Cost'] = opt_hist[-1][0]
aao_values['D/O Cost'] = x_to_dcost(opt_hist[-1][1][0:2]) + x_to_ocost(opt_hist[-1][1][0:2], opt_hist[-1][1][2:3])[0]
aao_values['Res. Cost'] = x_to_rcost(opt_hist[-1][1][0:2], opt_hist[-1][1][2:3], opt_hist[-1][1][3:5], loc='urban')
aao_values['D/O Evals'] = num_evals
aao_values['Res. Evals'] = num_evals
aao_values['Comp. Time'] = runtime

comparison_tab = comparison_tab.append(aao_values, ignore_index=True)
comparison_tab
# Out:
#      Approach             X_opt    Total Cost      D/O Cost     Res. Cost  \
# 0  All-in-one  (2, 0, 40, 1, 1) -1.440141e+07 -1.448577e+07  84360.660993
#
#   D/O Evals Res. Evals   Comp. Time
# 0      2304       2304  2375.260467

# %% [markdown]
# Bi-stage Approach:

# %%
xdes_opt, xoper_opt, xres_opt, desC_opt, operC_opt, resC_opt, num_upper, num_lower, runtime = bistage_optimization(loc='urban')
# Out:
# #####################Two-Stage approach###############################
# Stage 1 optimal solution:
# [ 0.  0. 30.]
# -23.4201
# 0
# (-14514128.43330109, -14, False, 0)
# #####################################################################
# Stage 2 optimal solution:
# [2. 2.]
# 264682.7111
# 264682.7111440134

# %%
bistage_values = {'Approach': 'Bi-stage'}
bistage_values['X_opt'] = xdes_opt+xoper_opt+xres_opt
bistage_values['Total Cost'] = desC_opt+operC_opt[0]+resC_opt
bistage_values['D/O Cost'] = desC_opt+operC_opt[0]
bistage_values['Res. Cost'] = resC_opt
bistage_values['D/O Evals'] = num_upper
bistage_values['Res. Evals'] = num_lower
bistage_values['Comp. Time'] = runtime

comparison_tab = comparison_tab.append(bistage_values, ignore_index=True)
comparison_tab
# Out:
#      Approach               X_opt    Total Cost      D/O Cost      Res. Cost  \
# 0  All-in-one    (2, 0, 40, 1, 1) -1.440141e+07 -1.448577e+07   84360.660993
# 1    Bi-stage  [0, 0, 30.0, 2, 2] -1.424945e+07 -1.451413e+07  264682.711144
#
#   D/O Evals Res. Evals   Comp. Time
# 0      2304       2304  2375.260467
# 1       144         16    27.478157

# %% [markdown]
# Bi-level Approach:

# %%
xdes_opt, xoper_opt, xres_opt, desC_opt, operC_opt, resC_opt, num_upper, num_lower, runtime = bilevel_optimization(loc='urban', decomp = False)
# Out:
# #####################Bi-level approach###############################
# Upper level optimal solution:
# [ 2.  0. 40.]
# -14401412.0021
# 300
# (-14486072.663137984, -28, False, 0)
# #####################################################################
# Lower level optimal solution:
# [1, 1]
# 84360.66099292606

# %%
bilevel_values = {'Approach': 'Bi-level'}
bilevel_values['X_opt'] = xdes_opt+xoper_opt+xres_opt
bilevel_values['Total Cost'] = desC_opt+operC_opt[0]+resC_opt
bilevel_values['D/O Cost'] = desC_opt+operC_opt[0]
bilevel_values['Res. Cost'] = resC_opt
bilevel_values['D/O Evals'] = num_upper
bilevel_values['Res. Evals'] = num_lower
bilevel_values['Comp. Time'] = runtime

comparison_tab = comparison_tab.append(bilevel_values, ignore_index=True)
comparison_tab
# Out:
#      Approach               X_opt    Total Cost      D/O Cost      Res. Cost  \
# 0  All-in-one    (2, 0, 40, 1, 1) -1.440141e+07 -1.448577e+07   84360.660993
# 1    Bi-stage  [0, 0, 30.0, 2, 2] -1.424945e+07 -1.451413e+07  264682.711144
# 2    Bi-level  [2, 0, 40.0, 1, 1] -1.440141e+07 -1.448577e+07   84360.660993
#
#   D/O Evals Res. Evals   Comp. Time
# 0      2304       2304  2375.260467
# 1       144         16    27.478157
# 2       144       1152  1062.116055

# %% [markdown]
# Bi-level Approach with lower-level decomposition:

# %%
xdes_opt, xoper_opt, xres_opt, desC_opt, operC_opt, resC_opt, num_upper, num_lower, runtime = bilevel_optimization(loc='urban', decomp = True)
# Out:
# #####################Bi-level approach###############################
# Upper level optimal solution:
# [ 2.  0. 40.]
# -14401412.0021
# 300
# (-14486072.663137984, -28, False, 0)
# #####################################################################
# Lower level optimal solution:
# [1, 1]
# 84360.66099292606

# %%
bileveldecomp_values = {'Approach': 'Bi-level (Decomp)'}
bileveldecomp_values['X_opt'] = xdes_opt+xoper_opt+xres_opt
bileveldecomp_values['Total Cost'] = desC_opt+operC_opt[0]+resC_opt
bileveldecomp_values['D/O Cost'] = desC_opt+operC_opt[0]
bileveldecomp_values['Res. Cost'] = resC_opt
bileveldecomp_values['D/O Evals'] = num_upper
bileveldecomp_values['Res. Evals'] = num_lower
bileveldecomp_values['Comp. Time'] = runtime

comparison_tab = comparison_tab.append(bileveldecomp_values, ignore_index=True)
comparison_tab
# Out:
#             Approach               X_opt    Total Cost      D/O Cost  \
# 0         All-in-one    (2, 0, 40, 1, 1) -1.440141e+07 -1.448577e+07
# 1           Bi-stage  [0, 0, 30.0, 2, 2] -1.424945e+07 -1.451413e+07
# 2           Bi-level  [2, 0, 40.0, 1, 1] -1.440141e+07 -1.448577e+07
# 3  Bi-level (Decomp)  [2, 0, 40.0, 1, 1] -1.440141e+07 -1.448577e+07
#
#        Res. Cost D/O Evals Res. Evals   Comp. Time
# 0   84360.660993      2304       2304  2375.260467
# 1  264682.711144       144         16    27.478157
# 2   84360.660993       144       1152  1062.116055
# 3   84360.660993       144        576   245.630060

# %%
comparison_tab.to_csv('comparison_table.csv')

# %%
print(comparison_tab.to_latex())
# Out:
# \begin{tabular}{lllrrrllr}
# \toprule
# {} &           Approach &               X\_opt &    Total Cost &      D/O Cost &      Res. Cost & D/O Evals & Res. Evals &   Comp. Time \\
# \midrule
# 0 &         All-in-one &    (2, 0, 40, 1, 1) & -1.440141e+07 & -1.448577e+07 &   84360.660993 &      2304 &       2304 &  2375.260467 \\
# 1 &           Bi-stage &  [0, 0, 30.0, 2, 2] & -1.424945e+07 & -1.451413e+07 &  264682.711144 &       144 &         16 &    27.478157 \\
# 2 &           Bi-level &  [2, 0, 40.0, 1, 1] & -1.440141e+07 & -1.448577e+07 &   84360.660993 &       144 &       1152 &  1062.116055 \\
# 3 &  Bi-level (Decomp) &  [2, 0, 40.0, 1, 1] & -1.440141e+07 & -1.448577e+07 &   84360.660993 &       144 &        576 &   245.630060 \\
# \bottomrule
# \end{tabular}

# %%
xres_opt
# Out:
# [0, 1]
