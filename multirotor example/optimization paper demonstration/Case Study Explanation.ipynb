# %%
import sys, os
sys.path.insert(1,os.path.join("..",".."))

import fmdtools.faultsim.propagate as propagate
import fmdtools.resultdisp as rd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import numpy as np
import seaborn as sns; sns.set(style="ticks", color_codes=True)

from drone_mdl import *
import time

# %%
from drone_opt import *

# %% [markdown]
# Example model and parameters:

# %%
params={'start': [0.0,0.0, 10, 10], 'target': [0, 150, 160, 160], 'safe': [0, 50, 10, 10], # areas
        'flightplan':{ 1:[0,0,50], 2:[100, 200, 50], 3:[100, 100, 85], 4:[-25, 150, 20],5:[75, 300, 20],6:[0, 300, 20], 7:[0,0,50], 8:[0,0,0] },
        'landtime': 12,
        'loc':'rural',
        'bat':'series-split',                           #'monolithic', 'series-split', 'paralel-split', 'split-both'
        'linearch':'quad',                              #quad, hex, oct
        'respolicy':{'bat':'emland','line':'emland'}}   #continue, to_home, to_nearest, emland
mdl = Drone(params=params)

# %% [markdown]
# ### Model Overview

# %%
#%matplotlib qt - unnecessary--already set in model
# pos = rd.graph.set_pos(mdl, gtype='bipartite')
# %matplotlib inline

# %%
fig, ax = rd.graph.show(mdl, gtype='bipartite', scale=2.0)

# %%
fig.savefig('modelstructure.pdf', format="pdf", bbox_inches = 'tight', pad_inches = 0.0)

# %% [markdown]
# ### Design model
#
# The drone model has 4 possible battery architectures: monolithic, series-split, parallel-split, and split-both. Each of these architectures enable some reconfiguration of the battery in case of faults but also add design cost, and (more importantly), weight.
#
# The drone model also has 3 possible line architectures (quadrotor, hexarotor, and octorotor) which increase design resilience but also lead to both increased design cost, weight, and drag.
#
# The cost of a model can be tabulated using `calc_des` in `drone_opt`.

# %%
calc_des(mdl)
# Out:
# 300

# %% [markdown]
# To get the objective in terms of the design vector $x_{des}$, use `x_to_descost`.

# %%
x_des = [1,0]

# %%
x_to_dcost(x_des)
# Out:
# 300

# %% [markdown]
# ### Operational model
#
# The drone model has 1 operational variable - the flight height. This variable determines how high the drone flies and thus how detailed of an image it can caputure. Based on this height, a flightplan is determined.

# %% [markdown]
# The operational model models the function of the battery, motors, and trajectory of the craft over time, as shown:

# %%
endresults_nom, resgraph, mdlhist =propagate.nominal(mdl)
rd.plot.mdlhistvals(mdlhist,fxnflowvals={'StoreEE':'soc', 'EE_1':'rate', 'DOFs': 'elev', 'Planpath':['mode', 'pt'], 'Dir1':'power'})

# put a constraint on battery health

# %% [markdown]
# The flightplan generated for this model is shown below. As shown, the drone flies through the arbitrary points set in the flightplan. Optimizing this sequence of points is a difficult problem, so instead we fly through a set pattern to cover the entire viewable area

# %%
plot_nomtraj(mdlhist, params)

# %%
x=[0,0,55,1,1] # height is the third parameter -- 55
mdl = x_to_mdl(x)
endresults_nom, resgraph, mdlhist =propagate.nominal(mdl)

# %%
plot_nomtraj(mdlhist, mdl.params)

# %% [markdown]
# We can then see how this plan covers the space of points to view. As shown, the target area is shown in red and the points viewed are red while the unviewed points are grey.
#
# The drone flies from an initial landing location, flies over the target location, and then flies back. If there is a problem, there is also a designated land point that the drone can also fly to.

# %%
plot_xy(mdlhist, endresults_nom, title='Nominal Flightpath at 55m height', legend=True)

# %% [markdown]
# This flight plan changes depending on operational height, as shown:

# %%
mdl_low = x_to_mdl([1,1,50,1,1])
endresults_low, resgraph, mdlhist_low =propagate.nominal(mdl_low)

# %%
mdl_med = x_to_mdl([1,1,80,1,1])
endresults_med, resgraph, mdlhist_med =propagate.nominal(mdl_med)

# %%
mdl_hi = x_to_mdl([1,1,180,1,1])
endresults_hi, resgraph, mdlhist_hi =propagate.nominal(mdl_hi)

# %%
fig = plot_xys({'50 m':mdlhist_low ,'80 m': mdlhist_med , '180 m': mdlhist_hi}, {'80 m': endresults_med , '50 m':endresults_low , '180 m': endresults_hi}, legend=True, title="Flight Paths at Varying Heights", retfig=True)
# Out:
# C:\Users\dhulse\Documents\GitHub\fmdtools\multirotor example\optimization paper demonstration\drone_opt.py:255: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(np.ceil((num_plots+1)/cols),cols,n, label='legend')

# %%
fig.savefig('flightplans.pdf', format="pdf", bbox_inches = 'tight', pad_inches = 0.0)

# %% [markdown]
# The cost of a model is tabulated using `calc_oper` in `drone_opt`, along with the value of constraints:
# - battery max discharge (20%)
# - existence of faults
# - max height (122 m per FAA regulation)

# %%
calc_oper(mdl)
# Out:
# (-9969116.59948255, -36.102377155008725, False, 0)

# %% [markdown]
# This operational cost and constraint values can be optimized in terms of design and operational variables $x_{des}$ and $x_{oper}$ using `x_to_ocost`.

# %%
x_oper = [90]

# %%
x_to_ocost(x_des, x_oper)
# Out:
# (-10957136.282944445, -42.41266043897626, False, 0)

# %% [markdown]
# ### Resilience model
#
# The resilience model has two variables--the battery resilience policy, and the line resilience policy, which each determine how the flight plan changes based on faults detected in the battery and line, respectively.
#
# The resilience cost of a model can be calculated using `calc_res`.

# %%
rescost = calc_res(mdl)
# Out:
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.76it/s]

# %%
rescost
# Out:
# -9958232.517042963

# %% [markdown]
# This can be calculated in terms of the design, operational, and variables $x_{des}$, $x_{oper}$, and $x_{res}$ using `x_to_rcost`

# %%
x_res = [0,0]

# %%
rescost = x_to_rcost(x_des, x_oper, x_res)
# Out:
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.34it/s]

# %%
rescost
# Out:
# -10946594.510396076

# %% [markdown]
# Table of fault scenanios in urban flight scenario:

# %%
mdl = x_to_mdl([0,0, 30, 0,0], loc='urban')
a,b,c,d = calc_oper(mdl)

# %%
app = SampleApproach(mdl, faults='single-component', phases={'forward'})
endclasses, mdlhists = propagate.approach(mdl, app, staged=True)
# Out:
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.62it/s]

# %%
endclasses['ManageHealth falsemasking, t=7.0']
# Out:
# {'rate': 9.333333333333334e-08,
#  'cost': 2354.8587137588097,
#  'expected cost': 21.978681328415558,
#  'repcost': 1000,
#  'landcost': 0,
#  'safecost': 1500,
#  'viewed value': 145.1412862411902,
#  'viewed': {(-80, 70): 0.0010935444016918405,
#   (-80, 80): 0.0010935444016918405,
#   (-80, 90): 0.0010935444016918405,
#   (-80, 100): 0.0011112533346389944,
#   (-80, 110): 0.0011112533346389944,
#   (-80, 120): 0.0011112533346389944,
#   (-80, 130): 0.0011111167876760406,
#   (-80, 140): 0.0011111167876760406,
#   (-80, 150): 0.0011111167876760406,
#   (-40, 200): 0.0011111110986926122,
#   (-40, 210): 0.0011111110986926122,
#   (-40, 220): 0.001111111099129522,
#   (-40, 230): 0.001111111099129522,
#   (-30, 70): 0.0011111110986926122,
#   (-30, 80): 0.0011111110986926122,
#   (-30, 90): 0.0011111110986926122,
#   (-30, 100): 0.0011111110986926122,
#   (-30, 110): 0.0011111110986926122,
#   (-30, 120): 0.0011111110986926122,
#   (-30, 130): 0.0011111110986926122,
#   (-30, 140): 0.0011111110986926122,
#   (-30, 150): 0.0011111110986926122,
#   (-30, 160): 0.0011111110986926122,
#   (-30, 170): 0.0011111110986926122,
#   (-30, 180): 0.0011111113263210202,
#   (-30, 190): 0.0011111111078676557,
#   (-30, 200): 0.0011111111078676557,
#   (-30, 210): 0.0011111111078676557,
#   (-30, 220): 0.001111111099129522,
#   (-30, 230): 0.001111111099129522,
#   (-20, 70): 0.0011111110986926122,
#   (-20, 80): 0.0011111110986926122,
#   (-20, 90): 0.0011111110986926122,
#   (-20, 100): 0.0011111110986926122,
#   (-20, 110): 0.0011111110986926122,
#   (-20, 120): 0.0011111110986926122,
#   (-20, 130): 0.0011111110986926122,
#   (-20, 140): 0.0011111167876760406,
#   (-20, 150): 0.0011111167876760406,
#   (-20, 160): 0.0011111113263210202,
#   (-20, 170): 0.0011111113263210202,
#   (-20, 180): 0.0011111113263210202,
#   (-20, 190): 0.0011111111078676557,
#   (-20, 200): 0.0011111111078676557,
#   (-20, 210): 0.0011111111078676557,
#   (-20, 220): 0.001111111099129522,
#   (-20, 230): 0.001111111099129522,
#   (-10, 70): 0.0011111110986926122,
#   (-10, 80): 0.0011111110986926122,
#   (-10, 90): 0.0011111110986926122,
#   (-10, 100): 0.0011111110986926122,
#   (-10, 110): 0.0011104003288578647,
#   (-10, 120): 0.0011104003288578647,
#   (-10, 130): 0.0011111167876760406,
#   (-10, 140): 0.0011111167876760406,
#   (-10, 150): 0.0011111167876760406,
#   (-10, 160): 0.0011111113263210202,
#   (-10, 170): 0.0011111113263210202,
#   (-10, 180): 0.0011111113263210202,
#   (-10, 190): 0.0011111111078676557,
#   (-10, 200): 0.0011111111078676557,
#   (-10, 210): 0.0011111111078676557,
#   (-10, 220): 0.001111111099129522,
#   (-10, 230): 0.001111111099129522,
#   (0, 70): 0.0010935444016918405,
#   (0, 80): 0.0010935444016918405,
#   (0, 90): 0.0010935444016918405,
#   (0, 100): 0.0011104003288578647,
#   (0, 110): 0.0011104003288578647,
#   (0, 120): 0.0011104003288578647,
#   (0, 130): 0.0011111167876760406,
#   (0, 140): 0.0011111167876760406,
#   (0, 150): 0.0011111167876760406,
#   (0, 160): 0.0011111113263210202,
#   (0, 170): 0.0011111113263210202,
#   (0, 180): 0.0011111113263210202,
#   (0, 190): 0.0011111111078676557,
#   (0, 200): 0.0011111111078676557,
#   (0, 210): 0.0011111111078676557,
#   (0, 220): 0.001111111099129522,
#   (0, 230): 0.001111111099129522,
#   (10, 70): 0.0010935444016918405,
#   (10, 80): 0.0010935444016918405,
#   (10, 90): 0.0010935444016918405,
#   (10, 100): 0.0011104003288578647,
#   (10, 110): 0.0011104003288578647,
#   (10, 120): 0.0011104003288578647,
#   (10, 130): 0.0011111167876760406,
#   (10, 140): 0.0011111167876760406,
#   (10, 150): 0.0011111167876760406,
#   (10, 160): 0.0011111113263210202,
#   (10, 170): 0.0011111113263210202,
#   (10, 180): 0.0011111113263210202,
#   (10, 190): 0.0011111111078676557,
#   (10, 200): 0.0011111111078676557,
#   (10, 210): 0.0011111111078676557,
#   (10, 220): 0.001111111099129522,
#   (10, 230): 0.001111111099129522,
#   (20, 70): 0.0010935444016918405,
#   (20, 80): 0.0010935444016918405,
#   (20, 90): 0.0010935444016918405,
#   (20, 100): 0.0011104003288578647,
#   (20, 110): 0.0011104003288578647,
#   (20, 120): 0.0011104003288578647,
#   (20, 130): 0.0011111167876760406,
#   (20, 140): 0.0011111167876760406,
#   (20, 150): 0.0011111167876760406,
#   (20, 160): 0.0011111113263210202,
#   (20, 170): 0.0011111113263210202,
#   (20, 180): 0.0011111113263210202,
#   (20, 190): 0.0011111111078676557,
#   (20, 200): 0.0011111111078676557,
#   (20, 210): 0.0011111111078676557,
#   (20, 220): 0.001111111099129522,
#   (20, 230): 0.001111111099129522,
#   (30, 70): 0.0010935444016918405,
#   (30, 80): 0.0010935444016918405,
#   (30, 90): 0.0010935444016918405,
#   (30, 100): 0.0011104003288578647,
#   (30, 110): 0.0011104003288578647,
#   (30, 120): 0.0011104003288578647,
#   (30, 130): 0.0011111167876760406,
#   (30, 140): 0.0011111167876760406,
#   (30, 150): 0.0011111167876760406,
#   (30, 160): 0.0011111113263210202,
#   (30, 170): 0.0011111113263210202,
#   (30, 180): 0.0011111113263210202,
#   (30, 190): 0.0011111111078676557,
#   (30, 200): 0.0011111111078676557,
#   (30, 210): 0.0011111111078676557,
#   (30, 220): 0.001111111099129522,
#   (30, 230): 0.001111111099129522,
#   (40, 70): 0.0010935444016918405,
#   (40, 80): 0.0010935444016918405,
#   (40, 90): 0.0010935444016918405,
#   (40, 100): 0.0011104003288578647,
#   (40, 110): 0.0011104003288578647,
#   (40, 120): 0.0011104003288578647,
#   (40, 130): 0.0011111167876760406,
#   (40, 140): 0.0011111167876760406,
#   (40, 150): 0.0011111167876760406,
#   (40, 160): 0.0011111113263210202,
#   (40, 170): 0.0011111113263210202,
#   (40, 180): 0.0011111113263210202,
#   (40, 190): 0.0011111111078676557,
#   (40, 200): 0.0011111111078676557,
#   (40, 210): 0.0011111111078676557,
#   (40, 220): 0.001111111099129522,
#   (40, 230): 0.001111111099129522,
#   (50, 70): 0.0011146752058159171,
#   (50, 80): 0.0011146752058159171,
#   (50, 90): 0.0011146752058159171,
#   (50, 100): 0.0011104003288578647,
#   (50, 110): 0.0011104003288578647,
#   (50, 120): 0.0011104003288578647,
#   (50, 130): 0.0011111099609885516,
#   (50, 140): 0.0011111099609885516,
#   (50, 150): 0.0011111099609885516,
#   (50, 160): 0.0011111113263210202,
#   (50, 170): 0.0011111113263210202,
#   (50, 180): 0.0011111113263210202,
#   (50, 190): 0.0011111110969449854,
#   (50, 200): 0.0011111110969449854,
#   (50, 210): 0.0011111110969449854,
#   (50, 220): 0.001111111099129522,
#   (50, 230): 0.001111111099129522,
#   (60, 70): 0.0011146752058159171,
#   (60, 80): 0.0011146752058159171,
#   (60, 90): 0.0011146752058159171,
#   (60, 100): 0.0011104003288578647,
#   (60, 110): 0.0011104003288578647,
#   (60, 120): 0.0011104003288578647,
#   (60, 130): 0.0011111099609885516,
#   (60, 140): 0.0011111099609885516,
#   (60, 150): 0.0011111099609885516,
#   (60, 160): 0.0011111113263210202,
#   (60, 170): 0.0011111113263210202,
#   (60, 180): 0.0011111113263210202,
#   (60, 190): 0.0011111110969449854,
#   (60, 200): 0.0011111110969449854,
#   (60, 210): 0.0011111110969449854,
#   (60, 220): 0.001111111099129522,
#   (60, 230): 0.001111111099129522,
#   (70, 70): 0.0011146752058159171,
#   (70, 80): 0.0011146752058159171,
#   (70, 90): 0.0011146752058159171,
#   (70, 100): 0.0011104003288578647,
#   (70, 110): 0.0011104003288578647,
#   (70, 120): 0.0011104003288578647,
#   (70, 130): 0.0011111099609885516,
#   (70, 140): 0.0011111099609885516,
#   (70, 150): 0.0011111099609885516,
#   (70, 160): 0.0011111113263210202,
#   (70, 170): 0.0011111113263210202,
#   (70, 180): 0.0011111113263210202,
#   (70, 190): 0.0011111110969449854,
#   (70, 200): 0.0011111110969449854,
#   (70, 210): 0.0011111110969449854,
#   (70, 220): 0.001111111099129522,
#   (70, 230): 0.001111111099129522,
#   (80, 70): 0.0011146752058159171,
#   (80, 80): 0.0011146752058159171,
#   (80, 90): 0.0011146752058159171,
#   (80, 100): 0.0011104003288578647,
#   (80, 110): 0.0011104003288578647,
#   (80, 120): 0.0011104003288578647,
#   (80, 130): 0.0011111099609885516,
#   (80, 140): 0.0011111099609885516,
#   (80, 150): 0.0011111099609885516,
#   (80, 160): 0.0011111113263210202,
#   (80, 170): 0.0011111113263210202,
#   (80, 180): 0.0011111113263210202,
#   (80, 190): 0.0011111110969449854,
#   (80, 200): 0.0011111110969449854,
#   (80, 210): 0.0011111110969449854,
#   (80, 220): 0.001111111099129522,
#   (80, 230): 0.001111111099129522},
#  'landloc': 'nominal',
#  'body strikes': 0,
#  'head strikes': 0,
#  'property restrictions': 0,
#  'severities': {'hazardous': 0.0, 'minor': 9.333333333333334e-08},
#  'unsafe flight time': 15}

# %%
simplefmea = rd.tabulate.simplefmea(endclasses)
simplefmea
# Out:
#                                       rate         cost     expected cost  \
# ManageHealth falsemasking, t=7.0       0.0  2354.858714         21.978681
# ManageHealth falseemland, t=7.0        0.0  2354.858714         10.989341
# ManageHealth lostfunction, t=7.0       0.0  2354.858714          8.242005
# StoreEE nocharge, t=7.0           0.000009  15434.21024       14405.26289
# StoreEE lowcharge, t=7.0          0.000033  15634.21024      51071.753449
# StoreEE S1P1short, t=7.0          0.000016  15434.21024      24008.771484
# StoreEE S1P1degr, t=7.0           0.000016  15434.21024      24008.771484
# StoreEE S1P1break, t=7.0          0.000016  15434.21024      24008.771484
# StoreEE S1P1nocharge, t=7.0       0.000028  15434.21024      43215.788671
# DistEE short, t=7.0               0.000002  15634.21024       3647.982389
# DistEE degr, t=7.0                0.000004  15534.21024        6041.08176
# DistEE break, t=7.0               0.000002  15534.21024       2416.432704
# AffectDOF RFshort, t=7.0          0.000003  16234.21024       5050.643186
# AffectDOF RFopenc, t=7.0          0.000003  15834.21024       4926.198741
# AffectDOF RFctlbreak, t=7.0       0.000006  15734.21024        9790.17526
# AffectDOF RFmechbreak, t=7.0      0.000003  16134.21024       5019.532075
# AffectDOF RFmechfriction, t=7.0   0.000002  1854.858716        432.800367
# AffectDOF RFstuck, t=7.0          0.000001  15834.21024       1477.859622
# CtlDOF noctl, t=7.0               0.000001  16434.21024       2300.789434
# CtlDOF degctl, t=7.0              0.000006  16634.21024       9315.157734
# Planpath noloc, t=7.0             0.000001  18334.21024       2566.789434
# Planpath degloc, t=7.0            0.000006  18334.21024      10267.157734
# HoldPayload break, t=7.0               0.0  16934.21024        263.421048
# HoldPayload deform, t=7.0         0.000001  16934.21024       1053.684193
# nominal                                1.0  1254.858716  125485871.566699
#
#                                  repcost landcost safecost viewed value  \
# ManageHealth falsemasking, t=7.0    1000        0     1500   145.141286
# ManageHealth falseemland, t=7.0     1000        0     1500   145.141286
# ManageHealth lostfunction, t=7.0    1000        0     1500   145.141286
# StoreEE nocharge, t=7.0              100    10000   5400.0     65.78976
# StoreEE lowcharge, t=7.0             200    10000   5500.0     65.78976
# StoreEE S1P1short, t=7.0             100    10000   5400.0     65.78976
# StoreEE S1P1degr, t=7.0              100    10000   5400.0     65.78976
# StoreEE S1P1break, t=7.0             100    10000   5400.0     65.78976
# StoreEE S1P1nocharge, t=7.0          100    10000   5400.0     65.78976
# DistEE short, t=7.0                  300    10000   5400.0     65.78976
# DistEE degr, t=7.0                   200    10000   5400.0     65.78976
# DistEE break, t=7.0                  200    10000   5400.0     65.78976
# AffectDOF RFshort, t=7.0             800    10000   5500.0     65.78976
# AffectDOF RFopenc, t=7.0             400    10000   5500.0     65.78976
# AffectDOF RFctlbreak, t=7.0          300    10000   5500.0     65.78976
# AffectDOF RFmechbreak, t=7.0         700    10000   5500.0     65.78976
# AffectDOF RFmechfriction, t=7.0      500        0     1500   145.141284
# AffectDOF RFstuck, t=7.0             400    10000   5500.0     65.78976
# CtlDOF noctl, t=7.0                 1000    10000   5500.0     65.78976
# CtlDOF degctl, t=7.0                1200    10000   5500.0     65.78976
# Planpath noloc, t=7.0               1200    10000   7200.0     65.78976
# Planpath degloc, t=7.0              1200    10000   7200.0     65.78976
# HoldPayload break, t=7.0            1500    10000   5500.0     65.78976
# HoldPayload deform, t=7.0           1500    10000   5500.0     65.78976
# nominal                                0        0     1400   145.141284
#
#                                                                              viewed  \
# ManageHealth falsemasking, t=7.0  {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# ManageHealth falseemland, t=7.0   {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# ManageHealth lostfunction, t=7.0  {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# StoreEE nocharge, t=7.0           {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# StoreEE lowcharge, t=7.0          {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# StoreEE S1P1short, t=7.0          {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# StoreEE S1P1degr, t=7.0           {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# StoreEE S1P1break, t=7.0          {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# StoreEE S1P1nocharge, t=7.0       {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# DistEE short, t=7.0               {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# DistEE degr, t=7.0                {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# DistEE break, t=7.0               {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# AffectDOF RFshort, t=7.0          {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# AffectDOF RFopenc, t=7.0          {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# AffectDOF RFctlbreak, t=7.0       {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# AffectDOF RFmechbreak, t=7.0      {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# AffectDOF RFmechfriction, t=7.0   {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# AffectDOF RFstuck, t=7.0          {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# CtlDOF noctl, t=7.0               {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# CtlDOF degctl, t=7.0              {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# Planpath noloc, t=7.0             {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# Planpath degloc, t=7.0            {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# HoldPayload break, t=7.0          {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# HoldPayload deform, t=7.0         {(-80, 70): 0.0010935444016918405, (-80, 80): ...
# nominal                           {(-80, 70): 0.0010935444016918405, (-80, 80): ...
#
#                                       landloc body strikes head strikes  \
# ManageHealth falsemasking, t=7.0      nominal            0            0
# ManageHealth falseemland, t=7.0       nominal            0            0
# ManageHealth lostfunction, t=7.0      nominal            0            0
# StoreEE nocharge, t=7.0           over target       0.0003       0.0002
# StoreEE lowcharge, t=7.0          over target       0.0003       0.0002
# StoreEE S1P1short, t=7.0          over target       0.0003       0.0002
# StoreEE S1P1degr, t=7.0           over target       0.0003       0.0002
# StoreEE S1P1break, t=7.0          over target       0.0003       0.0002
# StoreEE S1P1nocharge, t=7.0       over target       0.0003       0.0002
# DistEE short, t=7.0               over target       0.0003       0.0002
# DistEE degr, t=7.0                over target       0.0003       0.0002
# DistEE break, t=7.0               over target       0.0003       0.0002
# AffectDOF RFshort, t=7.0          over target       0.0003       0.0002
# AffectDOF RFopenc, t=7.0          over target       0.0003       0.0002
# AffectDOF RFctlbreak, t=7.0       over target       0.0003       0.0002
# AffectDOF RFmechbreak, t=7.0      over target       0.0003       0.0002
# AffectDOF RFmechfriction, t=7.0       nominal            0            0
# AffectDOF RFstuck, t=7.0          over target       0.0003       0.0002
# CtlDOF noctl, t=7.0               over target       0.0003       0.0002
# CtlDOF degctl, t=7.0              over target       0.0003       0.0002
# Planpath noloc, t=7.0             over target       0.0003       0.0002
# Planpath degloc, t=7.0            over target       0.0003       0.0002
# HoldPayload break, t=7.0          over target       0.0003       0.0002
# HoldPayload deform, t=7.0         over target       0.0003       0.0002
# nominal                               nominal            0            0
#
#                                  property restrictions  \
# ManageHealth falsemasking, t=7.0                     0
# ManageHealth falseemland, t=7.0                      0
# ManageHealth lostfunction, t=7.0                     0
# StoreEE nocharge, t=7.0                              1
# StoreEE lowcharge, t=7.0                             1
# StoreEE S1P1short, t=7.0                             1
# StoreEE S1P1degr, t=7.0                              1
# StoreEE S1P1break, t=7.0                             1
# StoreEE S1P1nocharge, t=7.0                          1
# DistEE short, t=7.0                                  1
# DistEE degr, t=7.0                                   1
# DistEE break, t=7.0                                  1
# AffectDOF RFshort, t=7.0                             1
# AffectDOF RFopenc, t=7.0                             1
# AffectDOF RFctlbreak, t=7.0                          1
# AffectDOF RFmechbreak, t=7.0                         1
# AffectDOF RFmechfriction, t=7.0                      0
# AffectDOF RFstuck, t=7.0                             1
# CtlDOF noctl, t=7.0                                  1
# CtlDOF degctl, t=7.0                                 1
# Planpath noloc, t=7.0                                1
# Planpath degloc, t=7.0                               1
# HoldPayload break, t=7.0                             1
# HoldPayload deform, t=7.0                            1
# nominal                                              0
#
#                                                                          severities  \
# ManageHealth falsemasking, t=7.0  {'hazardous': 0.0, 'minor': 9.333333333333334e...
# ManageHealth falseemland, t=7.0   {'hazardous': 0.0, 'minor': 4.666666666666667e...
# ManageHealth lostfunction, t=7.0  {'hazardous': 0.0, 'minor': 3.4999999999999996...
# StoreEE nocharge, t=7.0           {'hazardous': 9.32866822183313e-09, 'minor': 9...
# StoreEE lowcharge, t=7.0          {'hazardous': 3.265033877641595e-08, 'minor': ...
# StoreEE S1P1short, t=7.0          {'hazardous': 1.5547780369721885e-08, 'minor':...
# StoreEE S1P1degr, t=7.0           {'hazardous': 1.5547780369721885e-08, 'minor':...
# StoreEE S1P1break, t=7.0          {'hazardous': 1.5547780369721882e-08, 'minor':...
# StoreEE S1P1nocharge, t=7.0       {'hazardous': 2.7986004665499388e-08, 'minor':...
# DistEE short, t=7.0               {'hazardous': 2.3321670554582825e-09, 'minor':...
# DistEE degr, t=7.0                {'hazardous': 3.886945092430471e-09, 'minor': ...
# DistEE break, t=7.0               {'hazardous': 1.5547780369721887e-09, 'minor':...
# AffectDOF RFshort, t=7.0          {'hazardous': 3.1095560739443775e-09, 'minor':...
# AffectDOF RFopenc, t=7.0          {'hazardous': 3.1095560739443775e-09, 'minor':...
# AffectDOF RFctlbreak, t=7.0       {'hazardous': 6.219112147888755e-09, 'minor': ...
# AffectDOF RFmechbreak, t=7.0      {'hazardous': 3.1095560739443775e-09, 'minor':...
# AffectDOF RFmechfriction, t=7.0   {'hazardous': 0.0, 'minor': 2.3333333333333336...
# AffectDOF RFstuck, t=7.0          {'hazardous': 9.32866822183313e-10, 'minor': 9...
# CtlDOF noctl, t=7.0               {'hazardous': 1.3993002332749697e-09, 'minor':...
# CtlDOF degctl, t=7.0              {'hazardous': 5.597200933099879e-09, 'minor': ...
# Planpath noloc, t=7.0             {'hazardous': 1.3993002332749697e-09, 'minor':...
# Planpath degloc, t=7.0            {'hazardous': 5.597200933099879e-09, 'minor': ...
# HoldPayload break, t=7.0          {'hazardous': 1.554778036972188e-10, 'minor': ...
# HoldPayload deform, t=7.0         {'hazardous': 6.219112147888752e-10, 'minor': ...
# nominal                                            {'hazardous': 0.0, 'minor': 1.0}
#
#                                  unsafe flight time
# ManageHealth falsemasking, t=7.0                 15
# ManageHealth falseemland, t=7.0                  15
# ManageHealth lostfunction, t=7.0                 15
# StoreEE nocharge, t=7.0                           6
# StoreEE lowcharge, t=7.0                          7
# StoreEE S1P1short, t=7.0                          6
# StoreEE S1P1degr, t=7.0                           6
# StoreEE S1P1break, t=7.0                          6
# StoreEE S1P1nocharge, t=7.0                       6
# DistEE short, t=7.0                               6
# DistEE degr, t=7.0                                6
# DistEE break, t=7.0                               6
# AffectDOF RFshort, t=7.0                          7
# AffectDOF RFopenc, t=7.0                          7
# AffectDOF RFctlbreak, t=7.0                       7
# AffectDOF RFmechbreak, t=7.0                      7
# AffectDOF RFmechfriction, t=7.0                  15
# AffectDOF RFstuck, t=7.0                          7
# CtlDOF noctl, t=7.0                               7
# CtlDOF degctl, t=7.0                              7
# Planpath noloc, t=7.0                            24
# Planpath degloc, t=7.0                           24
# HoldPayload break, t=7.0                          7
# HoldPayload deform, t=7.0                         7
# nominal                                          14

# %%
scentable = simplefmea[[ 'rate', 'unsafe flight time', 'landloc','cost']]
scentable
# Out:
#                                       rate unsafe flight time      landloc  \
# ManageHealth falsemasking, t=7.0       0.0                 15      nominal
# ManageHealth falseemland, t=7.0        0.0                 15      nominal
# ManageHealth lostfunction, t=7.0       0.0                 15      nominal
# StoreEE nocharge, t=7.0           0.000009                  6  over target
# StoreEE lowcharge, t=7.0          0.000033                  7  over target
# StoreEE S1P1short, t=7.0          0.000016                  6  over target
# StoreEE S1P1degr, t=7.0           0.000016                  6  over target
# StoreEE S1P1break, t=7.0          0.000016                  6  over target
# StoreEE S1P1nocharge, t=7.0       0.000028                  6  over target
# DistEE short, t=7.0               0.000002                  6  over target
# DistEE degr, t=7.0                0.000004                  6  over target
# DistEE break, t=7.0               0.000002                  6  over target
# AffectDOF RFshort, t=7.0          0.000003                  7  over target
# AffectDOF RFopenc, t=7.0          0.000003                  7  over target
# AffectDOF RFctlbreak, t=7.0       0.000006                  7  over target
# AffectDOF RFmechbreak, t=7.0      0.000003                  7  over target
# AffectDOF RFmechfriction, t=7.0   0.000002                 15      nominal
# AffectDOF RFstuck, t=7.0          0.000001                  7  over target
# CtlDOF noctl, t=7.0               0.000001                  7  over target
# CtlDOF degctl, t=7.0              0.000006                  7  over target
# Planpath noloc, t=7.0             0.000001                 24  over target
# Planpath degloc, t=7.0            0.000006                 24  over target
# HoldPayload break, t=7.0               0.0                  7  over target
# HoldPayload deform, t=7.0         0.000001                  7  over target
# nominal                                1.0                 14      nominal
#
#                                          cost
# ManageHealth falsemasking, t=7.0  2354.858714
# ManageHealth falseemland, t=7.0   2354.858714
# ManageHealth lostfunction, t=7.0  2354.858714
# StoreEE nocharge, t=7.0           15434.21024
# StoreEE lowcharge, t=7.0          15634.21024
# StoreEE S1P1short, t=7.0          15434.21024
# StoreEE S1P1degr, t=7.0           15434.21024
# StoreEE S1P1break, t=7.0          15434.21024
# StoreEE S1P1nocharge, t=7.0       15434.21024
# DistEE short, t=7.0               15634.21024
# DistEE degr, t=7.0                15534.21024
# DistEE break, t=7.0               15534.21024
# AffectDOF RFshort, t=7.0          16234.21024
# AffectDOF RFopenc, t=7.0          15834.21024
# AffectDOF RFctlbreak, t=7.0       15734.21024
# AffectDOF RFmechbreak, t=7.0      16134.21024
# AffectDOF RFmechfriction, t=7.0   1854.858716
# AffectDOF RFstuck, t=7.0          15834.21024
# CtlDOF noctl, t=7.0               16434.21024
# CtlDOF degctl, t=7.0              16634.21024
# Planpath noloc, t=7.0             18334.21024
# Planpath degloc, t=7.0            18334.21024
# HoldPayload break, t=7.0          16934.21024
# HoldPayload deform, t=7.0         16934.21024
# nominal                           1254.858716

# %%
print(scentable.to_latex())
# Out:
# \begin{tabular}{lllll}
# \toprule
# {} &      rate & unsafe flight time &      landloc &         cost \\
# \midrule
# ManageHealth falsemasking, t=7.0 &       0.0 &                 15 &      nominal &  2354.858714 \\
# ManageHealth falseemland, t=7.0  &       0.0 &                 15 &      nominal &  2354.858714 \\
# ManageHealth lostfunction, t=7.0 &       0.0 &                 15 &      nominal &  2354.858714 \\
# StoreEE nocharge, t=7.0          &  0.000009 &                  6 &  over target &  15434.21024 \\
# StoreEE lowcharge, t=7.0         &  0.000033 &                  7 &  over target &  15634.21024 \\
# StoreEE S1P1short, t=7.0         &  0.000016 &                  6 &  over target &  15434.21024 \\
# StoreEE S1P1degr, t=7.0          &  0.000016 &                  6 &  over target &  15434.21024 \\
# StoreEE S1P1break, t=7.0         &  0.000016 &                  6 &  over target &  15434.21024 \\
# StoreEE S1P1nocharge, t=7.0      &  0.000028 &                  6 &  over target &  15434.21024 \\
# DistEE short, t=7.0              &  0.000002 &                  6 &  over target &  15634.21024 \\
# DistEE degr, t=7.0               &  0.000004 &                  6 &  over target &  15534.21024 \\
# DistEE break, t=7.0              &  0.000002 &                  6 &  over target &  15534.21024 \\
# AffectDOF RFshort, t=7.0         &  0.000003 &                  7 &  over target &  16234.21024 \\
# AffectDOF RFopenc, t=7.0         &  0.000003 &                  7 &  over target &  15834.21024 \\
# AffectDOF RFctlbreak, t=7.0      &  0.000006 &                  7 &  over target &  15734.21024 \\
# AffectDOF RFmechbreak, t=7.0     &  0.000003 &                  7 &  over target &  16134.21024 \\
# AffectDOF RFmechfriction, t=7.0  &  0.000002 &                 15 &      nominal &  1854.858716 \\
# AffectDOF RFstuck, t=7.0         &  0.000001 &                  7 &  over target &  15834.21024 \\
# CtlDOF noctl, t=7.0              &  0.000001 &                  7 &  over target &  16434.21024 \\
# CtlDOF degctl, t=7.0             &  0.000006 &                  7 &  over target &  16634.21024 \\
# Planpath noloc, t=7.0            &  0.000001 &                 24 &  over target &  18334.21024 \\
# Planpath degloc, t=7.0           &  0.000006 &                 24 &  over target &  18334.21024 \\
# HoldPayload break, t=7.0         &       0.0 &                  7 &  over target &  16934.21024 \\
# HoldPayload deform, t=7.0        &  0.000001 &                  7 &  over target &  16934.21024 \\
# nominal                          &       1.0 &                 14 &      nominal &  1254.858716 \\
# \bottomrule
# \end{tabular}

# %%
sum(scentable["rate"][0:2]) + sum(scentable["rate"][8:11]) + sum(scentable["rate"][15:])
# Out:
# 1.000055517777778

# %%
(sum(scentable["cost"][0:2]) + sum(scentable["cost"][8:11]) + sum(scentable["cost"][15:]))/11
# Out:
# 17272.340681224563

# %%
scentable["rate"][15:]
# Out:
# AffectDOF RFmechbreak, t=7.0       0.000003
# AffectDOF RFmechfriction, t=7.0    0.000002
# AffectDOF RFstuck, t=7.0           0.000001
# CtlDOF noctl, t=7.0                0.000001
# CtlDOF degctl, t=7.0               0.000006
# Planpath noloc, t=7.0              0.000001
# Planpath degloc, t=7.0             0.000006
# HoldPayload break, t=7.0                0.0
# HoldPayload deform, t=7.0          0.000001
# nominal                                 1.0
# Name: rate, dtype: object

# %% [markdown]
# The model can also be queried in terms of the entire design vector using `x_to_mdl` and `x_to_cost`:

# %%
x=[0,2,100,1,1]

# %%
mdl = x_to_mdl(x)

# %%
cost, constraints = x_to_cost(x)
# Out:
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.26it/s]

# %%
cost
# Out:
# -21894739.12195334

# %%
constraints
# Out:
# (-12.78499278499281, False, 0)

# %% [markdown]
# ### Exploring design trade-offs

# %% [markdown]
# Octocopter performance

# %%
x=[0,2,100,1,1]
mdl = x_to_mdl(x)
endresults,resgraph,mdlhist = propagate.nominal(mdl)

# %%
rd.plot.mdlhistvals(mdlhist, fxnflowvals={'StoreEE':['soc'], 'DOFs':['x', 'y', 'elev']})

# %% [markdown]
# Quadcopter performance

# %%
x=[0,0,100,1,1]
mdl = x_to_mdl(x)
endresults,resgraph,mdlhist = propagate.nominal(mdl)

# %%
rd.plot.mdlhistvals(mdlhist, fxnflowvals={'StoreEE':['soc'], 'DOFs':['x', 'y', 'elev']})

# %% [markdown]
# As shown, over the same flight with the same parameters, the quadcopter has a higher state of charge. Thus, as shown below, it can fly lower, resulting in a longer mission while ending at the same state of charge.

# %%
x=[0,0,30,1,1]
mdl = x_to_mdl(x)
endresults,resgraph,mdlhist = propagate.nominal(mdl)
rd.plot.mdlhistvals(mdlhist, fxnflowvals={'StoreEE':['soc'], 'DOFs':['x', 'y', 'elev']})

# %% [markdown]
# ### Trade-off plotting

# %%
explore_tradoffs(loc='urban', filename='tradeoffs_urban.csv')
# Out:
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.07it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.56it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.59it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.53it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.47it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.47it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.38it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.46it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.63it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.61it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.42it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.40it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.68it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.54it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.43it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.40it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.93it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.75it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.14it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.94it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.05it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.05it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.85it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.75it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.42it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.81it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.37it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.87it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.17it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.01it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.85it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.56it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.89it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.40it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.30it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.88it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 17.19it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 17.83it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 19.28it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.19it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.43it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.01it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.55it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.23it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.68it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.06it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.78it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.27it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 19.74it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 18.92it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 19.11it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.37it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.94it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.53it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.35it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.80it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.89it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.65it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.62it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.80it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.10it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.82it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 19.17it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.67it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.96it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.07it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.83it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.07it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.82it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.65it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.10it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.47it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 19.75it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.10it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.82it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.91it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.05it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.10it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.11it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.25it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.33it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.04it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.08it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.13it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.59it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.28it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.28it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.50it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.19it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.25it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.87it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.97it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.79it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.20it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.65it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.38it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.91it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.86it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.32it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.53it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.52it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.38it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.92it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.82it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.09it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.48it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.37it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.21it/s]
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 16.91it/s]
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S1P2lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S1P2lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S1P2lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 17.26it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 19.22it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.06it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.70it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.69it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.62it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.25it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.93it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.54it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.87it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.20it/s]
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 19.77it/s]
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 18.23it/s]
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 18.52it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.96it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.82it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.54it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.94it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.10it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.27it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.02it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.62it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.68it/s]
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.42it/s]
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.01it/s]
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 18.82it/s]
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.90it/s]
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.67it/s]
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S1P2lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S1P2lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S1P2lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.75it/s]
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S1P2lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S1P2lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S1P2lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.36it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.22it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.17it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.67it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.83it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.89it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.28it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.06it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.55it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.51it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.64it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.01it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.37it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 37.54it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.68it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.92it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.85it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.75it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.77it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.47it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.71it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.62it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.53it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.89it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.19it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.82it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.70it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.54it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.05it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.73it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.86it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.90it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.92it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.99it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.70it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.21it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.37it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.22it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.56it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.97it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.99it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.89it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.79it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.46it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.49it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.24it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.77it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.65it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.81it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 37.03it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.28it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.52it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.25it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.22it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.96it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.55it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.39it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.07it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.55it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.21it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.21it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.81it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.95it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.10it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.21it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.67it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.52it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.30it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.07it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.09it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.10it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.46it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.11it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.54it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.58it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.68it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.97it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.44it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.27it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.41it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.78it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.07it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.79it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.50it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.99it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.45it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.47it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.56it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.24it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.99it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.06it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.85it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.84it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.91it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.62it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.43it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.77it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.96it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.89it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.78it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.35it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.54it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.58it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.49it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.99it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.51it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.30it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.04it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S1P2lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.87it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.13it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.49it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.18it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.53it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.83it/s]
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.88it/s]
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S1P2lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S2P2lowcharge', 'S1P1nocharge', 'S1P1lowcharge', 'S2P1nocharge', 'S2P2nocharge', 'S2P1lowcharge', 'S1P2nocharge', 'S1P2lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.16it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.62it/s]
# ...
# 166  -10940506.577259  0  0  1     1
# 167  -10939839.807352  0  0  1     1
# 168   20507059.517907  1  1  0     1
# 169   17000973.189749  1  1  0     1
# 170   13328257.179744  1  1  0     1
# 171   10544213.133421  1  1  0     1
# 172   10556804.788257  1  1  0     1
# 173      53010.152378  1  1  0     1
# 174      57665.031257  1  1  0     1
# 175   -10944050.99931  0  0  0     0
# 176    -10942234.9271  0  0  0     0
# 177  -10940958.674267  0  0  0     0
# 178  -10940061.576357  0  0  1     1
# 179  -10939400.217643  0  0  1     1
# 180   40967997.040055  1  1  0     1
# 181   34432777.972489  1  1  0     1
# 182   -7487497.794933  0  0  0     0
# 183   -9468866.395798  0  0  0     0
# 184    -9456110.36391  0  0  0     0
# 185   -9950688.512685  0  0  0     0
# 186   -9946554.110106  0  0  0     0
# 187  -10946918.860435  0  0  0     0
# 188  -10945127.916562  0  0  0     0
# 189  -10943876.791373  0  0  0     0
# 190  -10943013.200253  0  0  1     1
# 191  -10942383.950934  0  0  1     1
# 192   40337660.122902  1  1  0     1
# 193    35364456.35993  1  1  0     1
# 194   32010159.566475  1  1  0     1
# 195   -9468698.302796  0  0  0     0
# 196   -9455951.328894  0  0  0     0
# 197   -9950541.728142  0  0  0     0
# 198    -9946412.46154  0  0  0     0
# 199  -10946758.021301  0  0  0     0
# 200  -10944971.312147  0  0  0     0
# 201  -10943724.421562  0  0  0     0
# 202  -10942866.477129  0  0  1     1
# 203  -10942242.639003  0  0  1     1
# 204   40513038.648811  1  1  0     1
# 205   37006814.957816  1  1  0     1
# 206   33333950.827952  1  1  0     1
# 207   30549750.547765  1  1  0     1
# 208    30562178.25242  1  1  0     1
# 209   10050053.606402  1  1  0     1
# 210   10054667.737025  1  1  0     1
# 211  -10946290.348834  0  0  0     0
# 212  -10944507.874399  0  0  0     0
# 213  -10943265.218417  0  0  0     0
# 214  -10942412.920672  0  0  1     1
# 215  -10941794.493739  0  0  1     1
# 216   40964811.262278  1  1  0     1
# 217   34429592.194711  1  1  0     1
# 218   -7490683.572711  0  0  0     0
# 219   -9471141.951354  0  0  0     0
# 220   -9458385.919466  0  0  0     0
# 221   -9952736.512685  0  0  0     0
# 222   -9948602.110106  0  0  0     0
# 223  -10948783.971546  0  0  0     0
# 224  -10946993.027673  0  0  0     0
# 225  -10945741.902484  0  0  0     0
# 226  -10944878.311364  0  0  1     1
# 534   10076605.527025  1  1  0     1
# 535  -10928830.948834  0  0  0     0
# 536  -10927048.474399  0  0  0     0
# 537  -10925805.818417  0  0  0     0
# 538  -10924953.520672  0  0  1     1
# 539  -10924335.093739  0  0  1     1
# 540  278653585.148183  1  1  0     1
# 541  272014130.481202  1  1  0     1
# 542   -7406512.977579  0  0  0     0
# 543   -9408898.507297  0  0  0     0
# 544   -9396286.205435  0  0  0     0
# 545   -9896788.804637  0  0  0     0
# 546   -9892735.898569  0  0  0     0
# 547  -10904759.203928  0  0  0     0
# 548  -10903035.455603  0  0  0     0
# 549  -10901851.524119  0  0  0     0
# 550  -10901077.533326  0  0  1     1
# 551   -10900534.14757  0  0  1     1
# 552  277423808.785563  1  1  0     1
# 553  272450327.505177  1  1  0     1
# 554  269095734.447163  1  1  0     1
# 555   -9407339.803183  0  0  0     0
# 556   -9394736.559308  0  0  0     0
# 557   -9895394.970093  0  0  0     0
# 558   -9891347.200004  0  0  0     0
# 559  -10903667.034238  0  0  0     0
# 560  -10901947.520633  0  0  0     0
# 561  -10900762.807085  0  0  0     0
# 562   -10899994.46298  0  0  1     1
# 563  -10899456.488417  0  0  1     1
# 564  277589142.690561  1  1  0     1
# 565  274082644.259962  1  1  0     1
# 566  270409483.897529  1  1  0     1
# 567   71624208.906454  1  1  0     1
# 568   71636308.710746  1  1  0     1
# 569   30105407.329451  1  1  0     1
# 570   30109449.963562  1  1  0     1
# 571  -10903029.203438  0  0  0     0
# 572  -10901313.924552  0  0  0     0
# 573  -10900138.462274  0  0  0     0
# 574  -10899375.764856  0  0  1     1
# 575  -10898843.201486  0  0  1     1

# %%
# Read the dataset of cost model values and constraint validation for a large grid of design variables
grid_results= pd.read_csv('tradeoffs_urban.csv')
#print(grid_results.head())
#print(grid_results.shape)

# Portion of feasible data among the whole dataset
feasible_DS =(grid_results['c_cum'].isin([0]).sum())/len(grid_results)
#print("The portion of feasible design space from the grid results")
#print(feasible_DS)

#Subsetting only feasible data
grid_results_FS = grid_results[(grid_results['c_cum']==0)]
g = sns.pairplot(grid_results_FS, hue="ResPolBat", vars=["Bat", "Rotor","Height","desC","operC","resC"], corner=True, diag_kind="kde",kind="reg")
g.fig.suptitle("Exploration of Design Variables", y=1.08)
# Out:
# Text(0.5, 1.08, 'Exploration of Design Variables')

# %%
g.fig.savefig('tradeoffs.pdf', format="pdf", bbox_inches = 'tight', pad_inches = 0.0)

# %% [markdown]
# ### Optimization/plotting

# %% [markdown]
# ### all-in-one search and pareto plotting

# %% [markdown]
# brute-force search of the space:

# %%
results, opthist_rural, evals, ftime = brute_search(loc='rural')

resultstab = pd.DataFrame(results)
resultstab.columns = resultstab.columns.to_flat_index()
resultstab.to_csv('fullspace_rural.csv')
# Out:
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.39it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.64it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.50it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.26it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.20it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.80it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.87it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.10it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.13it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.78it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.46it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.02it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.86it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.79it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.14it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.27it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.16it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.19it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.41it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.97it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.20it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.62it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.48it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.19it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.43it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.51it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.38it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.12it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.33it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.76it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.59it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.24it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.32it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.16it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.45it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.64it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.68it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.53it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.70it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.97it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.19it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.90it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.57it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.43it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.68it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.90it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.75it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.34it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.00it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.65it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.08it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.36it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.99it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.44it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.61it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.66it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.33it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.24it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.48it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.95it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.38it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.52it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.31it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.87it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.74it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.93it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.57it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.97it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.19it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.81it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.07it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.16it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.65it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.36it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.31it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.76it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.65it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.41it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.17it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.06it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.37it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.09it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.33it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.40it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.40it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.39it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.67it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.59it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.28it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.33it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.57it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.23it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.80it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.61it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.62it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.97it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.03it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.04it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.68it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.32it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.22it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.01it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.30it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.09it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.31it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.40it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.90it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.97it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.80it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.09it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.80it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.01it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.41it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.33it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.40it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.07it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.14it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.72it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.76it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.39it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.17it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.62it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.85it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.91it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.68it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 37.54it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 37.61it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.55it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.77it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.49it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.11it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.63it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.82it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.58it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.58it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.36it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.39it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 37.84it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.21it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.73it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.59it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 37.72it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 39.49it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 38.07it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.41it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.31it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.57it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.56it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.65it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.03it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.63it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.52it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.03it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.79it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.80it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.50it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.01it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.15it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 37.96it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.58it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.66it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.47it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.16it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.96it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.02it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.75it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.46it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.68it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.04it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.45it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.73it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.43it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.22it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 37.71it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.43it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.55it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.33it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.61it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.90it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.53it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.66it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.14it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.91it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.25it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.43it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.24it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.81it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.92it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.02it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 37.20it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 37.09it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 36.31it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.13it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.94it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.88it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.30it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.61it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.40it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.37it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.05it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.50it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.41it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.53it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.75it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.62it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.88it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.93it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.03it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.34it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.01it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.69it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.23it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.88it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.34it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.87it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.35it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.97it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.34it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.83it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.85it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.27it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.70it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.57it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.71it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.56it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.92it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.88it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.96it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.23it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.18it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.23it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.64it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.05it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.10it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.25it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.18it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.35it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.02it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.25it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.85it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.62it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.92it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.15it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.88it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.21it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.23it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.76it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.50it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.79it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.31it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.10it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.36it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.22it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.14it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.78it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.71it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.65it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.79it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.05it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.04it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.31it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.10it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.10it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.22it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.58it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 24.71it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.83it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.94it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.64it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.65it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.32it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.13it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.90it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.29it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.64it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.94it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.78it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.60it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.04it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.07it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 25.23it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.89it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.73it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.38it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.94it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.33it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.15it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.99it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.77it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.88it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.17it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.97it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.53it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.96it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.84it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.67it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 26.80it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.31it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.59it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.46it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 27.57it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.41it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.15it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.03it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.70it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.39it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.38it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.75it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.78it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.38it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.89it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.58it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.24it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.29it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.31it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.05it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.74it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.49it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 35.60it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.94it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.21it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.96it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.33it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.22it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.82it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.94it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.38it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.10it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.27it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.41it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.80it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.67it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.15it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.24it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.10it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.96it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 29.58it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.72it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.12it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.65it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.09it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.76it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.45it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.28it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.45it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.92it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.65it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.39it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.78it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.79it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.33it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.03it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.88it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.08it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.56it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.61it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.61it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.01it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.34it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.78it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.62it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.51it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.67it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.51it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.13it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.94it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.80it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.70it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.69it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.17it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.16it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 31.17it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 28.48it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.79it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.87it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.12it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.46it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.47it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.22it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 32.39it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.97it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 34.09it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 30.12it/s]
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:00<00:00, 33.19it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.50it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.19it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.88it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.99it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.18it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.88it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.41it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.52it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.79it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.20it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.51it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.12it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.85it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.98it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.88it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.02it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.32it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.17it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.07it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.78it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.26it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.93it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.26it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.20it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.46it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.28it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.24it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.03it/s]
# ...
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.74it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.70it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.09it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.66it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.27it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.82it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.05it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.33it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.53it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.14it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.85it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.73it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.16it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 23.09it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.62it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.86it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.30it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 19.61it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.66it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.99it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.42it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.30it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.93it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.68it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.64it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.26it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.80it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.55it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.34it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.47it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.36it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.34it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.94it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.71it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.30it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.37it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.31it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.93it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.69it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.24it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.84it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.76it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.21it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.28it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.01it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.21it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 20.81it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 22.24it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.93it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1lowcharge', 'lowcharge', 'S2P1lowcharge']}
# SCENARIOS COMPLETE: 100%|██████████| 24/24 [00:01<00:00, 21.58it/s]
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# Faults found during the nominal run {'StoreEE': ['S1P1nocharge', 'S1P1lowcharge', 'S2P1lowcharge', 'S2P1nocharge', 'nocharge']}
# SCENARIOS COMPLETE:  67%|██████▋   | 16/24 [00:00<00:00, 19.55it/s]

# %%
opthist_rural

# %%
results, opthist_urban, evals, ftime = brute_search(loc='urban')

resultstab = pd.DataFrame(results)
resultstab.columns = resultstab.columns.to_flat_index()
resultstab.to_csv('fullspace_urban.csv')

# %%
opthist_urban

# %%
results, opthist_conj, evals, ftime = brute_search(loc='congested')

resultstab = pd.DataFrame(results)
resultstab.columns = resultstab.columns.to_flat_index()
resultstab.to_csv('fullspace_congested.csv')

# %%
opthist_conj

# %% [markdown]
# load search results:

# %%
resultstab_rural = pd.read_csv('fullspace_rural.csv')
resultstab_rural = resultstab_rural.drop(labels='Unnamed: 0', axis=1)
resultstab_rural

# %% [markdown]
# Construct pareto front of design, operational, and resilience costs:

# %%
pareto3 = get_3dpareto(resultstab_rural, 0,1,2)

# %%
fig, ax = plot_pareto3(pareto3)

# %%
ax.set_xlabel('$C_D$ (\$)')
ax.set_ylabel('$C_R$ (\$)')
ax.set_zlabel('$C_O$ (\$)')
ax.xaxis.labelpad=10
ax.yaxis.labelpad=10
ax.zaxis.labelpad=10
ax.dist = 12
#ax.set_title('Pareto Front in Rural Scenario')
ax.legend_.remove()
fig

# %%
fig.savefig('pareto_dorcosts_rural.pdf', format="pdf", bbox_inches = 'tight', pad_inches = 0.0)

# %%
resultstab_urban = pd.read_csv('fullspace_urban.csv')
resultstab_urban = resultstab_urban.drop(labels='Unnamed: 0', axis=1)
resultstab_urban

# %%
pareto3_urban = get_3dpareto(resultstab_urban, 0,1,2)

# %%
fig, ax = plot_pareto3(pareto3_urban)
ax.set_xlabel('$C_D$ (\$)')
ax.set_ylabel('$C_R$ (\$)')
ax.set_zlabel('$C_O$ (\$)')
ax.xaxis.labelpad=10
ax.yaxis.labelpad=10
ax.zaxis.labelpad=10
ax.dist = 12
#ax.set_title('Pareto Front in Urban Scenario')
ax.legend_.remove()
#fig.subplots_adjust(top=1, bottom=-0.2, left=-0.2, right=0.9)
fig

# %%
fig.savefig('pareto_dorcosts_urban.pdf', format="pdf", bbox_inches = 'tight', pad_inches = 0.0)

# %%
resultstab_congested = pd.read_csv('fullspace_congested.csv')
resultstab_congested = resultstab_congested .drop(labels='Unnamed: 0', axis=1)
resultstab_congested

# %%
pareto3_congested = get_3dpareto(resultstab_congested, 0,1,2)

# %%
fig, ax = plot_pareto3(pareto3_congested)
ax.set_xlabel('$C_D$ (\$)')
ax.set_ylabel('$C_R$ (\$)')
ax.set_zlabel('$C_O$ (\$)')
ax.xaxis.labelpad=10
ax.yaxis.labelpad=10
ax.zaxis.labelpad=10
ax.dist = 12
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, ['Equal-weight design'], loc='upper center')
#ax.set_title('Pareto Front in Congested Scenario')
fig

# %%
fig.savefig('pareto_dorcosts_congested.pdf', format="pdf", bbox_inches = 'tight', pad_inches = 0.0)

# %% [markdown]
# Construct pareto front of Repair, Landing, and Flight Costs

# %%
resilcosts = resultstab_urban[3:5]
flightcosts = resultstab_urban[5:7].sum()
resilcosts = resilcosts.append(flightcosts, ignore_index=True)

pareto3_resilience = get_3dpareto(resilcosts, 0,1,2)

# %%
fig, ax = plot_pareto3(pareto3_resilience)
ax.set_xlabel('Repair Cost')
ax.set_ylabel('Landing Cost')
ax.set_zlabel('Flight Cost')
ax.set_title('Resilience Pareto Front in Urban Scenario')

# %%
fig.savefig('pareto_resilcosts.pdf', format="pdf", bbox_inches = 'tight', pad_inches = 0.0)

# %% [markdown]
# ### Comparison of Optimization Architectures

# %%
comparison_tab = pd.DataFrame(columns=['Approach', 'X_opt', 'Total Cost', 'D/O Cost', 'Res. Cost', 'D/O Evals', 'Res. Evals', 'Comp. Time'])
comparison_tab

# %% [markdown]
# All-in-one Approach:

# %%
results, opt_hist, num_evals, runtime = brute_search(loc = 'urban')

# %%
x_to_cost([2,0,40,1,1], loc='urban')
#so, need to fix the bilevel frameworks--the AAO is getting to the true min while they are not

# %%
aao_values = {'Approach':'All-in-one'}
aao_values['X_opt'] = opt_hist[-1][1]
aao_values['Total Cost'] = opt_hist[-1][0]
aao_values['D/O Cost'] = x_to_dcost(opt_hist[-1][1][0:2]) + x_to_ocost(opt_hist[-1][1][0:2], opt_hist[-1][1][2:3])[0]
aao_values['Res. Cost'] = x_to_rcost(opt_hist[-1][1][0:2], opt_hist[-1][1][2:3], opt_hist[-1][1][3:5], loc='urban')
aao_values['D/O Evals'] = num_evals
aao_values['Res. Evals'] = num_evals
aao_values['Comp. Time'] = runtime

comparison_tab = comparison_tab.append(aao_values, ignore_index=True)
comparison_tab

# %% [markdown]
# Bi-stage Approach:

# %%
xdes_opt, xoper_opt, xres_opt, desC_opt, operC_opt, resC_opt, num_upper, num_lower, runtime = bistage_optimization(loc='urban')

# %%
bistage_values = {'Approach': 'Bi-stage'}
bistage_values['X_opt'] = xdes_opt+xoper_opt+xres_opt
bistage_values['Total Cost'] = desC_opt+operC_opt[0]+resC_opt
bistage_values['D/O Cost'] = desC_opt+operC_opt[0]
bistage_values['Res. Cost'] = resC_opt
bistage_values['D/O Evals'] = num_upper
bistage_values['Res. Evals'] = num_lower
bistage_values['Comp. Time'] = runtime

comparison_tab = comparison_tab.append(bistage_values, ignore_index=True)
comparison_tab

# %% [markdown]
# Bi-level Approach:

# %%
xdes_opt, xoper_opt, xres_opt, desC_opt, operC_opt, resC_opt, num_upper, num_lower, runtime = bilevel_optimization(loc='urban', decomp = False)

# %%
bilevel_values = {'Approach': 'Bi-level'}
bilevel_values['X_opt'] = xdes_opt+xoper_opt+xres_opt
bilevel_values['Total Cost'] = desC_opt+operC_opt[0]+resC_opt
bilevel_values['D/O Cost'] = desC_opt+operC_opt[0]
bilevel_values['Res. Cost'] = resC_opt
bilevel_values['D/O Evals'] = num_upper
bilevel_values['Res. Evals'] = num_lower
bilevel_values['Comp. Time'] = runtime

comparison_tab = comparison_tab.append(bilevel_values, ignore_index=True)
comparison_tab

# %% [markdown]
# Bi-level Approach with lower-level decomposition:

# %%
xdes_opt, xoper_opt, xres_opt, desC_opt, operC_opt, resC_opt, num_upper, num_lower, runtime = bilevel_optimization(loc='urban', decomp = True)

# %%
bileveldecomp_values = {'Approach': 'Bi-level (Decomp)'}
bileveldecomp_values['X_opt'] = xdes_opt+xoper_opt+xres_opt
bileveldecomp_values['Total Cost'] = desC_opt+operC_opt[0]+resC_opt
bileveldecomp_values['D/O Cost'] = desC_opt+operC_opt[0]
bileveldecomp_values['Res. Cost'] = resC_opt
bileveldecomp_values['D/O Evals'] = num_upper
bileveldecomp_values['Res. Evals'] = num_lower
bileveldecomp_values['Comp. Time'] = runtime

comparison_tab = comparison_tab.append(bileveldecomp_values, ignore_index=True)
comparison_tab

# %%
comparison_tab.to_csv('comparison_table.csv')

# %%
print(comparison_tab.to_latex())

# %%
xres_opt
